# %% [markdown]
# #NLP on sexual harassment cases textual descriptions

# %% [markdown]
# The idea with this notebook is to work on Natural Language Processing tasks to extract features from the DESCRIPTION column of our dataset, to use them as input on a sexual-harassment-category classifier with more than 90% accuracy. Initially the idea is to some EDA and get familiar with the data, and to go through the model building pipeline: preprocessing, feature extraction, parameter tuning, model selection and testing.

# %%
# !pip install polyglot
# !pip install pyicu
# !pip install pycld2
# !pip install morfessor
# !pip install wordcloud
# Out:
# Collecting polyglot
#   Downloading https://files.pythonhosted.org/packages/e7/98/e24e2489114c5112b083714277204d92d372f5bbe00d5507acf40370edb9/polyglot-16.7.4.tar.gz (126kB)
#      |████████████████████████████████| 133kB 8.8MB/s
# Building wheels for collected packages: polyglot
#   Building wheel for polyglot (setup.py) ... done
#   Created wheel for polyglot: filename=polyglot-16.7.4-py2.py3-none-any.whl size=52560 sha256=c3d7d0d6aeb6fedb5991ea64ec5f265915497459c6b17fe7817d9c7c9080d824
#   Stored in directory: /root/.cache/pip/wheels/5e/91/ef/f1369fdc1203b0a9347d4b24f149b83a305f39ab047986d9da
# Successfully built polyglot
# Installing collected packages: polyglot
# Successfully installed polyglot-16.7.4
# Collecting pyicu
#   Downloading https://files.pythonhosted.org/packages/e9/35/211ffb949c68e688ade7d40426de030a24eaec4b6c45330eeb9c0285f43a/PyICU-2.3.1.tar.gz (214kB)
#      |████████████████████████████████| 215kB 9.4MB/s
# Building wheels for collected packages: pyicu
#   Building wheel for pyicu (setup.py) ... done
#   Created wheel for pyicu: filename=PyICU-2.3.1-cp36-cp36m-linux_x86_64.whl size=1172902 sha256=9c1fa0b712d2281b48d2dd42617d52486c3a2f81accb2664473f608b9529ce56
#   Stored in directory: /root/.cache/pip/wheels/3f/45/7e/ccee9f1fe52787595e92641b5645cdf2cb40096749b39b4422
# Successfully built pyicu
# Installing collected packages: pyicu
# Successfully installed pyicu-2.3.1
# Collecting pycld2
#   Downloading https://files.pythonhosted.org/packages/21/77/8525fe5f147bf2819c7c9942c717c4a79b83f8003da1a3847759fb560909/pycld2-0.31.tar.gz (14.3MB)
#      |████████████████████████████████| 14.3MB 7.5MB/s
# Building wheels for collected packages: pycld2
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.31-cp36-cp36m-linux_x86_64.whl size=9825472 sha256=c277095cdb6221bdda3a8b552077f4400eab4822cbf5e64dd90986dbd8001bed
#   Stored in directory: /root/.cache/pip/wheels/7b/44/44/ec4c5e25e095f02aa0e63ef2bf0cc8badda5877330ffa5fbe4
# Successfully built pycld2
# Installing collected packages: pycld2
# Successfully installed pycld2-0.31
# Collecting morfessor
#   Downloading https://files.pythonhosted.org/packages/39/e6/7afea30be2ee4d29ce9de0fa53acbb033163615f849515c0b1956ad074ee/Morfessor-2.0.6-py3-none-any.whl
# Installing collected packages: morfessor
# Successfully installed morfessor-2.0.6
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from wordcloud) (4.3.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from wordcloud) (1.16.5)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->wordcloud) (0.46)

# %%
import re
import numpy as np
import pandas as pd
import folium
import nltk
import spacy
import matplotlib.pyplot as plt
import seaborn as sns
import polyglot

from os import path
from PIL import Image
from itertools import cycle
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.corpus import stopwords as sw
from gensim.corpora.dictionary import Dictionary
from gensim.models.tfidfmodel import TfidfModel
from collections import Counter
from tqdm import tqdm_notebook as tqdm
from collections import defaultdict
from polyglot.text import Text
from wordcloud import WordCloud, STOPWORDS
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn import metrics
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn import svm

# %%
nltk.download('punkt')
nltk.download('words')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')

# !polyglot download embeddings2.en
# !polyglot download ner2.en
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [polyglot_data] Downloading package embeddings2.en to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data] Downloading package ner2.en to /root/polyglot_data...

# %% [markdown]
# ##EDA, Data Preprocessing and Feature Extraction

# %%
def category_desc_to_txt(df, category_list):
  
  #Collect all the descriptions in a text file, one per category(11)
  
  text = ['']*len(category_list)
  df_filtered_list = []
  counter = 0

  for category in category_list:
    df_filtered_list.append(df_train[df_train['CATEGORY'].str.contains(category)==True])

  for index in range(len(df_filtered_list)):
    for description in df_filtered_list[index].DESCRIPTION:
      text[index] = text[index] + ' ' + str(description)
      counter+=1
      if counter == int(report_1.shape[0]*split_rate):
        break

  category_list_names = []
  bad_chars = ['/', ' '] 

  for category in category_list:
    for i in bad_chars:
      category = category.replace(i, '')
    category_list_names.append(category.replace(i, ''))   

  for category, description in zip(category_list_names, text):
    f = open(category+'.txt',"w+")
    f.write(description)
    
  return category_list_names

# %%
#Read dataset and remove NA values
report_1 = pd.read_csv('safecity_reports_28072019.csv')

#Check the number of rows without a location (value==NaN)
print('Shape of df : ', report_1.shape)
print('\nDropping rows without description or location or category.....\n')
report_1 = report_1[pd.notna(report_1['DESCRIPTION'])]
report_1 = report_1[pd.notna(report_1['LONGITUDE'])]
report_1 = report_1[pd.notna(report_1['CATEGORY'])]
print('New shape of df : ', report_1.shape)

categories=[]
for index, row in report_1.iterrows():
    cat_group_list = [i for i in row.CATEGORY.split(',')]
    del(cat_group_list[-1])
    for category in cat_group_list:
      category = [category.lstrip()]
      if category not in categories:
        categories.append(category) #add a new category
      else:
        next
    #replace in the original df with the list. iat[] is to set a single row and 5 is the CATEGORY column index    
    if index == 11604:
      break
    report_1.iat[index, 5] = cat_group_list
    
print("Total number of unique categories : {}\n".format(len(categories)))
counts = [0] * len(categories)
category_list = [cat[0] for cat in categories]

#Split in train and test and create a collection of descriptions for each category
split_rate = 0.8
df_train = report_1.iloc[0:int(report_1.shape[0]*split_rate), :].copy()
df_test = report_1.iloc[int(report_1.shape[0]*split_rate)+1:,: ].copy()
fileNames = category_desc_to_txt(df_train, category_list)
# Out:
# Shape of df :  (12122, 9)
#
# Dropping rows without description or location or category.....
#
# New shape of df :  (11604, 9)
# Total number of unique categories : 14

# %%
# Out:
# [['Touching /Groping'], ['Catcalls/Whistles'], ['Sexual Invites'], ['Stalking'], ['Others'], ['Commenting'], ['Rape / Sexual Assault'], ['North East India Report'], ['Indecent exposure'], ['Chain Snatching'], ['Ogling/Facial Expressions/Staring'], ['Taking pictures'], ['Poor / No Street Lighting'], ['Online Harassment']]

# %% [markdown]
# ### Tokenization, Lemmatization and Stemming
# Top 20 most used words different outputs

# %%
def top20_and_allTokens(filename, stemming=True, lemmatization=True, plot=True):
  
  lemmatizer = WordNetLemmatizer()
  stemmer = PorterStemmer()
  category = open(filename, 'r')
  content = category.read().lower()
  pattern_wd_eng = (r'[A-Za-z]+') 
  
  print('\n', filename)
  
  #Tokenization
  tokens = re.findall(pattern_wd_eng, content)
  no_stops = [t for t in tqdm(tokens) if t not in sw.words('english')]
  
  print('Words and digits eng :\n', re.findall(pattern_wd_eng, content))
  print('\nSet() unique words and digits eng :\n', set(re.findall(pattern_wd_eng, content)))
  print('\nAfter nostop filter :\n', no_stops)
  
  top_20_a = Counter(no_stops).most_common(20)
  print('\nTop 20 most used words after non_stop:\n', top_20_a)
  
  #Lemmatization
  lemmatized = [lemmatizer.lemmatize(word, pos="v") for word in no_stops]
  print('\nAfter lemmatizer :\n', lemmatized) if lemmatization else None
  top_20_b = Counter(lemmatized).most_common(20)
  print('\nTop 20 most used words after lemmatizer:\n', top_20_b) if lemmatization else None
  
  #Stemming
  stemmed = [stemmer.stem(word) for word in lemmatized]
  print('\nAfter stemmer :\n', stemmed) if stemming else None
  top_20 = Counter(stemmed).most_common(20)
  print('\nTop 20 most used words after stemmer:\n', top_20) if stemming else None
  
  top20_token = [word[0] for word in top_20]
  top20_count = [word[1] for word in top_20]
  
  if plot:
    fig, ax = plt.subplots()
    fig.set_size_inches(20, 5)
    plt.bar(labels, values, color='g')
    plt.show()
    
  total_tokens = lemmatized if lemmatization else no_stops
  total_tokens = stemmed if stemming else total_tokens
  
  return total_tokens

# %% [markdown]
# ### Tf_idf

# %%
def top20_tf_idf(category_tokens):
  
  # Build a dicitionary with all the unique tokens merging all categories
  dictionary = Dictionary(category_tokens)

  # Corpus: List(7 items) of list(for each collection) of tuples of word_id and count
  corpus = [dictionary.doc2bow(collection) for collection in category_tokens]

  print('\ncorpus: {}'.format(len(corpus)))
  
  # Create a new TfidfModel using the corpus: tfidf
  tfidf = TfidfModel(corpus)

  print('Top_20 after Term Frequency–Inverse Document Frequency')  
  
  for index, tokens_and_Cnt in enumerate(corpus):
    print('\n', fileNames[index])
    
  # Calculate the tfidf weights of doc: tfidf_weights
    tfidf_weights = tfidf[tokens_and_Cnt]

  # Sort the weights from highest to lowest: sorted_tfidf_weights
    sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)

  # Print the top 5 weighted words
    for term_id, weight in sorted_tfidf_weights[0:20]:
      print(dictionary.get(term_id), weight)
      
  return corpus, dictionary, tfidf

# %%
#With BOTH lemmatization and Stemming
top20_and_allTokens_list = [top20_and_allTokens(fileNames[i]+'.txt', plot=False) for i in range(len(fileNames))]
categories_allTokens = [top20_and_allTokens_list[i] for i in range(len(top20_and_allTokens_list))]
corpus, dictionary, tfidf = top20_tf_idf(categories_allTokens)
# Out:
#  TouchingGroping.txt
# HBox(children=(IntProgress(value=0, max=1079), HTML(value='')))
# Words and digits eng :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'i', 'was', 'travelling', 'with', 'my', 'family', 'and', 'we', 'were', 'in', 'gurgaon', 'a', 'girl', 'with', 'a', 'boy', 'came', 'on', 'bike', 'and', 'the', 'girl', 'was', 'wearing', 'croptop', 'and', 'jeans', 'two', 'boys', 'in', 'a', 'car', 'came', 'behind', 'them', 'and', 'we', 'all', 'stopped', 'on', 'traffic', 'signal', 'and', 'those', 'boys', 'were', 'smoking', 'cigarettes', 'when', 'the', 'boys', 'saw', 'the', 'girl', 'they', 'put', 'their', 'burning', 'cigarettes', 'inside', 'the', 'jeans', 'of', 'the', 'girl', 'from', 'back', 'side', 'and', 'ran', 'away', 'and', 'the', 'girl', 'was', 'screaming', 'of', 'pain', 'i', 'noticed', 'the', 'people', 'standing', 'over', 'there', 'saying', 'that', 'it', 'was', 'the', 'fault', 'of', 'the', 'girl', 'as', 'she', 'was', 'wearing', 'short', 'clothes', 'and', 'her', 'body', 'was', 'uncovered', 'i', 'mean', 'this', 'was', 'seriously', 'so', 'shameful', 'and', 'ridiculous', 'instead', 'of', 'showing', 'sympathy', 'towards', 'that', 'girl', 'everyone', 'standing', 'there', 'was', 'blaming', 'her', 'and', 'her', 'dressing', 'sense', 'why', 'don', 't', 'you', 'teach', 'your', 'sons', 'to', 'behave', 'in', 'respectful', 'manner', 'one', 'similar', 'incindent', 'happened', 'with', 'me', 'when', 'i', 'was', 'in', 'th', 'standard', 'i', 'was', 'wearing', 'short', 'top', 'and', 'skirt', 'and', 'went', 'to', 'my', 'neighbours', 'house', 'with', 'my', 'mom', 'there', 'my', 'aunt', 'told', 'my', 'mom', 'to', 'not', 'allow', 'me', 'to', 'wear', 'these', 'kind', 'of', 'clothes', 'as', 'this', 'will', 'affect', 'their', 'daughters', 'thinking', 'i', 'mean', 'are', 'u', 'guys', 'serious', 'one', 'side', 'you', 'talk', 'about', 'modern', 'india', 'modern', 'society', 'and', 'development', 'and', 'on', 'the', 'other', 'side', 'you', 'are', 'still', 'carrying', 'this', 'orthodox', 'thinking', 'of', 'yours', 'that', 'girls', 'should', 'be', 'covered', 'i', 'want', 'to', 'ask', 'all', 'the', 'girls', 'that', 'don', 't', 'u', 'think', 'babes', 'these', 'guys', 'need', 'to', 'change', 'their', 'thinking', 'and', 'not', 'us', 'to', 'change', 'our', 'dressing', 'style', 'man', 'from', 'passing', 'train', 'squeezed', 'my', 'breasts', 'while', 'train', 'was', 'slowing', 'she', 'does', 'not', 'feels', 'safe', 'during', 'night', 'journeys', 'she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'molesters', 'saw', 'my', 'friend', 'on', 'her', 'vehicle', 'near', 'babari', 'mandi', 'and', 'while', 'they', 'were', 'about', 'to', 'leave', 'they', 'tried', 'to', 'get', 'hold', 'of', 'her', 'pallu', 'while', 'she', 'was', 'on', 'the', 'bike', 'she', 'scolded', 'them', 'but', 'let', 'them', 'go', 'unfortunately', 'okay', 'so', 'this', 'incident', 'happened', 'last', 'year', 'i', 'e', 'when', 'i', 'd', 'finished', 'my', 'classes', 'at', 'vashi', 'and', 'was', 'heading', 'towards', 'the', 'vashi', 'depot', 'to', 'take', 'a', 'bus', 'to', 'my', 'place', 'kharghar', 'navi', 'mumbai', 'so', 'i', 'boarded', 'a', 'numbered', 'bus', 'and', 'took', 'a', 'ladies', 'seat', 'window', 'side', 'i', 'was', 'on', 'a', 'phone', 'call', 'after', 'a', 'few', 'minutes', 'i', 'realised', 'that', 'i', 'was', 'touched', 'near', 'my', 'boobs', 'from', 'behind', 'for', 'an', 'instance', 'i', 'thought', 'it', 'might', 'just', 'be', 'the', 'rod', 'of', 'the', 'seat', 'but',  ...
#
# Set() unique words and digits eng :
#  {'in', 'and', 'amount', 'only', 'company', 'u', 'hesitate', 'screaming', 'even', 'realised', 'window', 'workplace', 'girls', 'some', 'sexual', 'right', 'didn', 'development', 'pedicab', 'walking', 'grabs', 'towards', 'non', 'breasts', 'colour', 'scooty', 'lust', 'sexually', 'style', 'upto', 'fear', 'when', 'bike', 'one', 'posh', 'another', 'up', 'scared', 'happened', 'affect', 'women', 'area', 'don', 'touched', 'them', 'look', 'aunt', 'sat', 'e', 'follows', 'dressing', 'madly', 'get', 'give', 'numbered', 'grab', 'never', 'said', 'carrying', 'forced', 'playing', 'verbal', 'pallu', 'sent', 'harassed', 'dept', 'mandi', 'girl', 'against', 'course', 'vashi', 'sons', 'babari', 'male', 'molesters', 'station', 'instead', 'does', 'had', 'india', 'too', 'go', 'manner', 'respectful', 'allow', 'her', 'thinking', 'need', 'body', 'somebody', 'giving', 'holi', 'money', 'guy', 'feels', 'that', 'bus', 'teach', 'took', 'female', 'thigh', 'd', 'clothes', 'well', 'masked', 'classes', 'a', 'as', 'still', 'react', 'behind', 'official', 'victim', 'celebration', 'orthodox', 'night', 'kept', 'will', 'private', 'old', 'bad', 'lecher', 'second', 'conductor', 'offering', 'similar', 'bar', 'hold', 'asking', 'sure', 'is', 'skirt', 'behave', 't', 'then', 'closed', 'covered', 'cab', 'everyday', 'beer', 'jeans', 'conducted', 'so', 'the', 'thousands', 'who', 'saying', 'speaking', 'years', 'after', 'boys', 'offered', 'place', 'again', 'inappropriate', 'about', 'train', 'time', 'due', 'full', 'society', 'free', 'which', 'happening', 'first', 'incindent', 'caught', 'touch', 'fault', 'andal', 'beside', 'applied', 'why', 'govt', 'tried', 'he', 'croptop', 'ended', 'me', 'minutes', 'tirupati', 'leave', 'seriously', 'disappeared', 'railway', 'not', 'my', 'was', 'want', 'metro', 'sociology', 'shocked', 'sympathy', 'construction', 'myself', 'prostitute', 'iit', 'came', 'us', 'boarded', 'serious', 'queue', 'finished', 'wasn', 'am', 'view', 'depot', 'modern', 'what', 'smoking', 'mine', 'express', 'did', 'couldn', 'take', 'ask', 'year', 'reported', 'last', 'traveling', 'literally', 'yours', 'friends', 'by', 'standing', 'delhi', 'lift', 'are', 'short', 'shirt', 'unsafe', 'kharghar', 'away', 'mumbai', 'it', 'student', 'might', 'heading', 'back', 'talk', 'slapped', 'bikes', 'necessary', 'later', 'showing', 'got', 'there', 'refused', 'intentionally', 'looks', 'survey', 'boobs', 'started', 'th', 'assignment', 'she', 'to', 'for', 'daughters', 'men', 'those', 'you', 'all', 'during', 'hit', 'these', 'i', 's', 'shameful', 'cyclist', 'just', 'hours', 'burning', 'quietly', 'times', 'incident', 'were', 'safe', 'been', 'his', 'wearing', 'on', 'once', 'traffic', 'rod', 'mom', 'gave', 'any', 'casual', 'let', 'we', 'water', 'gurgaon', 'over', 'few', 'decent', 'vehicle', 'guys', 'crowd', 'groping', 'okay', 'ranchi', 'uncovered', 'very', 'went', 'ran', 'stopped', 'poured', 'change', 'felt', 'almost', 'family', 'kind', 'your', 'cigarettes', 'pedestrian', 'near', 'scolded', 'call', 'road', 'noticed', 'point', 'seat', 'they', 'people', 'mean', 'do', 'misery', 'bursted', 'trying', 'employees', 'transgender', 'delay', 'down', 'assaulted', 'matter', 'action', 'contractor', 'pain', 'crowded', 'site', 'of', 'turned', 'our', 'hand', 'their', 'unfortunately', 'navi', 'many', 'mouth', 'angry', 'regular', 'blaming', 'an', 'fortunately', 'at', 'employee', 'auto', 'top', 'expecting', 'while', 'premises', 'way', 'babes', 'blocks', 'faces', 'with', 'someone', 'message', 'should', 'stood', 'wear', 'but', 'bhagalpur', 'neighbours', 'temple', 'phone', 'friend', 'parts', 'traveller', 'other', 'whatever', 'journeys', 'signal', 'be', 'workers', 'ridiculous', 'standard', 'ladies', 'within', 'car', 'office', 'slowing', 'everyone', 'put', 'passing', 'remarks', 'far', 'without', 'most', 'pulled', 'touching', 'from', 'travelling', 'quite', 'instance', 'boy', 'side', 'two', 'has', 'him', 'intentional', 'groped', 'abused', 'thought', 'part', 'squeezed', 'intention', 'think', 'complained', 'staring', 'house', 'out', 'c ...
#
# After nostop filter :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'blocks', 'way', 'grabs', 'expecting', 'quietly', 'give', 'travelling', 'family', 'gurgaon', 'girl', 'boy', 'came', 'bike', 'girl', 'wearing', 'croptop', 'jeans', 'two', 'boys', 'car', 'came', 'behind', 'stopped', 'traffic', 'signal', 'boys', 'smoking', 'cigarettes', 'boys', 'saw', 'girl', 'put', 'burning', 'cigarettes', 'inside', 'jeans', 'girl', 'back', 'side', 'ran', 'away', 'girl', 'screaming', 'pain', 'noticed', 'people', 'standing', 'saying', 'fault', 'girl', 'wearing', 'short', 'clothes', 'body', 'uncovered', 'mean', 'seriously', 'shameful', 'ridiculous', 'instead', 'showing', 'sympathy', 'towards', 'girl', 'everyone', 'standing', 'blaming', 'dressing', 'sense', 'teach', 'sons', 'behave', 'respectful', 'manner', 'one', 'similar', 'incindent', 'happened', 'th', 'standard', 'wearing', 'short', 'top', 'skirt', 'went', 'neighbours', 'house', 'mom', 'aunt', 'told', 'mom', 'allow', 'wear', 'kind', 'clothes', 'affect', 'daughters', 'thinking', 'mean', 'u', 'guys', 'serious', 'one', 'side', 'talk', 'modern', 'india', 'modern', 'society', 'development', 'side', 'still', 'carrying', 'orthodox', 'thinking', 'girls', 'covered', 'want', 'ask', 'girls', 'u', 'think', 'babes', 'guys', 'need', 'change', 'thinking', 'us', 'change', 'dressing', 'style', 'man', 'passing', 'train', 'squeezed', 'breasts', 'train', 'slowing', 'feels', 'safe', 'night', 'journeys', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'tried', 'get', 'hold', 'pallu', 'bike', 'scolded', 'let', 'go', 'unfortunately', 'okay', 'incident', 'happened', 'last', 'year', 'e', 'finished', 'classes', 'vashi', 'heading', 'towards', 'vashi', 'depot', 'take', 'bus', 'place', 'kharghar', 'navi', 'mumbai', 'boarded', 'numbered', 'bus', 'took', 'ladies', 'seat', 'window', 'side', 'phone', 'call', 'minutes', 'realised', 'touched', 'near', 'boobs', 'behind', 'instance', 'thought', 'might', 'rod', 'seat', 'later', 'realised', 'somebody', 'hand', 'trying', 'grab', 'caught', 'hold', 'man', 'hand', 'right', 'turned', 'turned', 'abused', 'asking', 'upto', 'quite', 'shocked', 'sure', 'expecting', 'girl', 'react', 'way', 'men', 'think', 'scared', 'speaking', 'way', 'fear', 'bus', 'conductor', 'came', 'site', 'pulled', 'shirt', 'put', 'bus', 'well', 'later', 'minutes', 'man', 'sat', 'beside', 'started', 'touching', 'thigh', 'bursted', 'even', 'madly', 'minutes', 'back', 'first', 'one', 'happened', 'turned', 'towards', 'without', 'giving', 'second', 'thought', 'literally', 'slapped', 'abused', 'angry', 'angry', 'happening', 'people', 'bus', 'hit', 'even', 'put', 'happened', 'hesitate', 'whatever', 'necessary', 'thought', 'misery', 'ended', 'another', 'lecher', 'staring', 'time', 'complained', 'conductor', 'forced', 'bus', 'intentional', 'inappropriate', 'touching', 'incident', 'happened', 'friend', 'well', 'walking', 'road', 'masked', 'men', 'bikes', 'conducted', 'survey', 'part', 'sociology', 'assignment', 'course', 'offered', 'iit', 'women', 'workers', 'construction', 'site', 'said', 'sexually', 'assaulted', 'crowd', 'thousands', 'tirupati', 'temple', 'male', 'friend', 'harassed', 'queue', 'year', 'old', 'girl', 'playing', 'temple', 'friends', 'time', 'disappeared', 'hours', 'got', 'raped', 'holi', 'celebration', 'male', 'employee', 'applied', 'colour', 'inside', 'female', 'employees', 'mouth', 'poured', 'water', 'within', 'office', 'premises', 'okay', 'reported', 'matter', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'friend', 'mine', 'female', 'sexual', 'harassed', 'workplace', 'old', 'contractor', 'kept', 'giving', 'remarks', 'looks', 'reported', 'time', 'dela ...
#
# Top 20 most used words after non_stop:
#  [('girl', 11), ('bus', 7), ('man', 6), ('happened', 5), ('behind', 4), ('came', 4), ('side', 4), ('one', 4), ('friend', 4), ('touched', 4), ('thought', 4), ('touching', 4), ('time', 4), ('way', 3), ('travelling', 3), ('wearing', 3), ('boys', 3), ('stopped', 3), ('put', 3), ('people', 3)]
#
# After lemmatizer :
#  ['pedicab', 'cyclist', 'follow', 'behind', 'pedestrian', 'block', 'way', 'grab', 'expect', 'quietly', 'give', 'travel', 'family', 'gurgaon', 'girl', 'boy', 'come', 'bike', 'girl', 'wear', 'croptop', 'jeans', 'two', 'boys', 'car', 'come', 'behind', 'stop', 'traffic', 'signal', 'boys', 'smoke', 'cigarettes', 'boys', 'saw', 'girl', 'put', 'burn', 'cigarettes', 'inside', 'jeans', 'girl', 'back', 'side', 'run', 'away', 'girl', 'scream', 'pain', 'notice', 'people', 'stand', 'say', 'fault', 'girl', 'wear', 'short', 'clothe', 'body', 'uncover', 'mean', 'seriously', 'shameful', 'ridiculous', 'instead', 'show', 'sympathy', 'towards', 'girl', 'everyone', 'stand', 'blame', 'dress', 'sense', 'teach', 'sons', 'behave', 'respectful', 'manner', 'one', 'similar', 'incindent', 'happen', 'th', 'standard', 'wear', 'short', 'top', 'skirt', 'go', 'neighbour', 'house', 'mom', 'aunt', 'tell', 'mom', 'allow', 'wear', 'kind', 'clothe', 'affect', 'daughters', 'think', 'mean', 'u', 'guy', 'serious', 'one', 'side', 'talk', 'modern', 'india', 'modern', 'society', 'development', 'side', 'still', 'carry', 'orthodox', 'think', 'girls', 'cover', 'want', 'ask', 'girls', 'u', 'think', 'babes', 'guy', 'need', 'change', 'think', 'us', 'change', 'dress', 'style', 'man', 'pass', 'train', 'squeeze', 'breast', 'train', 'slow', 'feel', 'safe', 'night', 'journey', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'govt', 'official', 'time', 'feel', 'unsafe', 'due', 'overcrowd', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'travel', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'try', 'get', 'hold', 'pallu', 'bike', 'scold', 'let', 'go', 'unfortunately', 'okay', 'incident', 'happen', 'last', 'year', 'e', 'finish', 'class', 'vashi', 'head', 'towards', 'vashi', 'depot', 'take', 'bus', 'place', 'kharghar', 'navi', 'mumbai', 'board', 'number', 'bus', 'take', 'ladies', 'seat', 'window', 'side', 'phone', 'call', 'minutes', 'realise', 'touch', 'near', 'boob', 'behind', 'instance', 'think', 'might', 'rod', 'seat', 'later', 'realise', 'somebody', 'hand', 'try', 'grab', 'catch', 'hold', 'man', 'hand', 'right', 'turn', 'turn', 'abuse', 'ask', 'upto', 'quite', 'shock', 'sure', 'expect', 'girl', 'react', 'way', 'men', 'think', 'scar', 'speak', 'way', 'fear', 'bus', 'conductor', 'come', 'site', 'pull', 'shirt', 'put', 'bus', 'well', 'later', 'minutes', 'man', 'sit', 'beside', 'start', 'touch', 'thigh', 'burst', 'even', 'madly', 'minutes', 'back', 'first', 'one', 'happen', 'turn', 'towards', 'without', 'give', 'second', 'think', 'literally', 'slap', 'abuse', 'angry', 'angry', 'happen', 'people', 'bus', 'hit', 'even', 'put', 'happen', 'hesitate', 'whatever', 'necessary', 'think', 'misery', 'end', 'another', 'lecher', 'star', 'time', 'complain', 'conductor', 'force', 'bus', 'intentional', 'inappropriate', 'touch', 'incident', 'happen', 'friend', 'well', 'walk', 'road', 'mask', 'men', 'bike', 'conduct', 'survey', 'part', 'sociology', 'assignment', 'course', 'offer', 'iit', 'women', 'workers', 'construction', 'site', 'say', 'sexually', 'assault', 'crowd', 'thousands', 'tirupati', 'temple', 'male', 'friend', 'harass', 'queue', 'year', 'old', 'girl', 'play', 'temple', 'friends', 'time', 'disappear', 'hours', 'get', 'rap', 'holi', 'celebration', 'male', 'employee', 'apply', 'colour', 'inside', 'female', 'employees', 'mouth', 'pour', 'water', 'within', 'office', 'premise', 'okay', 'report', 'matter', 'beer', 'bar', 'close', 'two', 'girls', 'hit', 'men', 'refuse', 'go', 'friend', 'mine', 'female', 'sexual', 'harass', 'workplace', 'old', 'contractor', 'keep', 'give', 'remark', 'look', 'report', 'time', 'delay', 'posh', 'dept', 'company', 'offer', 'free', 'cab', 'inappropriate', 'non', 'verbal', 'contact', 'try', 'stop', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time ...
#
# Top 20 most used words after lemmatizer:
#  [('girl', 11), ('touch', 10), ('think', 9), ('bus', 7), ('happen', 6), ('man', 6), ('time', 5), ('try', 5), ('behind', 4), ('give', 4), ('travel', 4), ('come', 4), ('wear', 4), ('side', 4), ('one', 4), ('take', 4), ('friend', 4), ('part', 4), ('way', 3), ('bike', 3)]
#
# After stemmer :
#  ['pedicab', 'cyclist', 'follow', 'behind', 'pedestrian', 'block', 'way', 'grab', 'expect', 'quietli', 'give', 'travel', 'famili', 'gurgaon', 'girl', 'boy', 'come', 'bike', 'girl', 'wear', 'croptop', 'jean', 'two', 'boy', 'car', 'come', 'behind', 'stop', 'traffic', 'signal', 'boy', 'smoke', 'cigarett', 'boy', 'saw', 'girl', 'put', 'burn', 'cigarett', 'insid', 'jean', 'girl', 'back', 'side', 'run', 'away', 'girl', 'scream', 'pain', 'notic', 'peopl', 'stand', 'say', 'fault', 'girl', 'wear', 'short', 'cloth', 'bodi', 'uncov', 'mean', 'serious', 'shame', 'ridicul', 'instead', 'show', 'sympathi', 'toward', 'girl', 'everyon', 'stand', 'blame', 'dress', 'sens', 'teach', 'son', 'behav', 'respect', 'manner', 'one', 'similar', 'incind', 'happen', 'th', 'standard', 'wear', 'short', 'top', 'skirt', 'go', 'neighbour', 'hous', 'mom', 'aunt', 'tell', 'mom', 'allow', 'wear', 'kind', 'cloth', 'affect', 'daughter', 'think', 'mean', 'u', 'guy', 'seriou', 'one', 'side', 'talk', 'modern', 'india', 'modern', 'societi', 'develop', 'side', 'still', 'carri', 'orthodox', 'think', 'girl', 'cover', 'want', 'ask', 'girl', 'u', 'think', 'babe', 'guy', 'need', 'chang', 'think', 'us', 'chang', 'dress', 'style', 'man', 'pass', 'train', 'squeez', 'breast', 'train', 'slow', 'feel', 'safe', 'night', 'journey', 'student', 'regular', 'travel', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'govt', 'offici', 'time', 'feel', 'unsaf', 'due', 'overcrowd', 'area', 'last', 'mani', 'year', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'travel', 'unfortun', 'never', 'take', 'action', 'far', 'molest', 'saw', 'friend', 'vehicl', 'near', 'babari', 'mandi', 'leav', 'tri', 'get', 'hold', 'pallu', 'bike', 'scold', 'let', 'go', 'unfortun', 'okay', 'incid', 'happen', 'last', 'year', 'e', 'finish', 'class', 'vashi', 'head', 'toward', 'vashi', 'depot', 'take', 'bu', 'place', 'kharghar', 'navi', 'mumbai', 'board', 'number', 'bu', 'take', 'ladi', 'seat', 'window', 'side', 'phone', 'call', 'minut', 'realis', 'touch', 'near', 'boob', 'behind', 'instanc', 'think', 'might', 'rod', 'seat', 'later', 'realis', 'somebodi', 'hand', 'tri', 'grab', 'catch', 'hold', 'man', 'hand', 'right', 'turn', 'turn', 'abus', 'ask', 'upto', 'quit', 'shock', 'sure', 'expect', 'girl', 'react', 'way', 'men', 'think', 'scar', 'speak', 'way', 'fear', 'bu', 'conductor', 'come', 'site', 'pull', 'shirt', 'put', 'bu', 'well', 'later', 'minut', 'man', 'sit', 'besid', 'start', 'touch', 'thigh', 'burst', 'even', 'madli', 'minut', 'back', 'first', 'one', 'happen', 'turn', 'toward', 'without', 'give', 'second', 'think', 'liter', 'slap', 'abus', 'angri', 'angri', 'happen', 'peopl', 'bu', 'hit', 'even', 'put', 'happen', 'hesit', 'whatev', 'necessari', 'think', 'miseri', 'end', 'anoth', 'lecher', 'star', 'time', 'complain', 'conductor', 'forc', 'bu', 'intent', 'inappropri', 'touch', 'incid', 'happen', 'friend', 'well', 'walk', 'road', 'mask', 'men', 'bike', 'conduct', 'survey', 'part', 'sociolog', 'assign', 'cours', 'offer', 'iit', 'women', 'worker', 'construct', 'site', 'say', 'sexual', 'assault', 'crowd', 'thousand', 'tirupati', 'templ', 'male', 'friend', 'harass', 'queue', 'year', 'old', 'girl', 'play', 'templ', 'friend', 'time', 'disappear', 'hour', 'get', 'rap', 'holi', 'celebr', 'male', 'employe', 'appli', 'colour', 'insid', 'femal', 'employe', 'mouth', 'pour', 'water', 'within', 'offic', 'premis', 'okay', 'report', 'matter', 'beer', 'bar', 'close', 'two', 'girl', 'hit', 'men', 'refus', 'go', 'friend', 'mine', 'femal', 'sexual', 'harass', 'workplac', 'old', 'contractor', 'keep', 'give', 'remark', 'look', 'report', 'time', 'delay', 'posh', 'dept', 'compani', 'offer', 'free', 'cab', 'inappropri', 'non', 'verbal', 'contact', 'tri', 'stop', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intent', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stand', 'point', 'view', 'give', 'casual', 'look', 'fortun', 'send', 'messag', 'transgend', 'ask', 'money', 'auto', 'stop', 'signal', 'refus', 'sta ...
#
# Top 20 most used words after stemmer:
#  [('girl', 14), ('touch', 10), ('think', 9), ('bu', 7), ('happen', 6), ('man', 6), ('travel', 5), ('time', 5), ('friend', 5), ('tri', 5), ('behind', 4), ('give', 4), ('boy', 4), ('come', 4), ('wear', 4), ('side', 4), ('one', 4), ('take', 4), ('part', 4), ('way', 3)]
#
#  CatcallsWhistles.txt
# HBox(children=(IntProgress(value=0, max=305), HTML(value='')))
# Words and digits eng :
#  ['na', 'sexually', 'assaulting', 'three', 'boys', 'were', 'singing', 'a', 'song', 'as', 'i', 'passed', 'she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'it', 'was', 'during', 'my', 'coaching', 'our', 'classmates', 'used', 'to', 'follow', 'us', 'everywhere', 'we', 'used', 'to', 'go', 'and', 'pass', 'comments', 'on', 'our', 'dressing', 'and', 'our', 'body', 'language', 'it', 'felt', 'very', 'uncomfortable', 'it', 'was', 'around', 'pm', 'i', 'was', 'supposed', 'to', 'receive', 'my', 'female', 'friend', 'and', 'as', 'soon', 'as', 'she', 'came', 'to', 'me', 'a', 'group', 'of', 'grown', 'up', 'men', 'started', 'passing', 'comments', 'i', 'was', 'travelling', 'in', 'the', 'delhi', 'metro', 'and', 'a', 'man', 'was', 'staring', 'at', 'a', 'girl', 'with', 'the', 'intention', 'full', 'of', 'lust', 'after', 'a', 'decent', 'amount', 'of', 'time', 'i', 'couldn', 't', 'take', 'it', 'and', 'i', 'stood', 'in', 'his', 'point', 'of', 'view', 'and', 'gave', 'him', 'a', 'casual', 'look', 'fortunately', 'that', 'sent', 'the', 'message', 'during', 'a', 'party', 'while', 'dancing', 'in', 'college', 'a', 'guy', 'pinched', 'a', 'girl', 'at', 'inappropriate', 'part', 'while', 'coming', 'from', 'classes', 'i', 'saw', 'a', 'group', 'of', 'boys', 'were', 'teasing', 'a', 'girl', 'i', 'witnessed', 'a', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'a', 'man', 'thought', 'i', 'was', 'a', 'prostitute', 'and', 'was', 'offering', 'money', 'for', 'one', 'night', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'few', 'people', 'followed', 'me', 'to', 'my', 'home', 'and', 'also', 'pelted', 'stone', 'at', 'me', 'and', 'comments', 'continuously', 'victim', 'was', 'on', 'hr', 'way', 'to', 'the', 'metro', 'station', 'when', 'a', 'group', 'of', 'boys', 'catcalled', 'and', 'whistled', 'to', 'grab', 'her', 'attention', 'i', 'was', 'walking', 'in', 'the', 'inner', 'circle', 'when', 'a', 'boy', 'used', 'heavy', 'tone', 'to', 'make', 'obscene', 'voices', 'none']
#
# Set() unique words and digits eng :
#  {'delhi', 'coming', 'in', 'inner', 'and', 'are', 'amount', 'unsafe', 'classes', 'a', 'as', 'three', 'it', 'pm', 'student', 'attention', 'official', 'voices', 'taking', 'victim', 'stone', 'obscene', 'group', 'sexual', 'action', 'singing', 'receive', 'college', 'night', 'walking', 'of', 'offering', 'lust', 'our', 'sexually', 'catcalled', 'unfortunately', 'around', 'is', 'many', 'soon', 'regular', 'when', 't', 'none', 'fortunately', 'there', 'at', 'party', 'everyday', 'started', 'so', 'the', 'she', 'witnessed', 'one', 'to', 'for', 'up', 'language', 'while', 'men', 'way', 'years', 'after', 'boys', 'comments', 'inappropriate', 'faces', 'used', 'area', 'everywhere', 'during', 'time', 'with', 'due', 'full', 'message', 'i', 'look', 'stood', 'robbery', 'na', 'but', 'friend', 'dressing', 'pictures', 'times', 'whistled', 'traveller', 'were', 'pelted', 'safe', 'been', 'his', 'pass', 'on', 'grab', 'never', 'supposed', 'govt', 'grown', 'song', 'gave', 'any', 'casual', 'verbal', 'we', 'passing', 'me', 'far', 'sent', 'my', 'passed', 'was', 'girl', 'decent', 'few', 'home', 'metro', 'from', 'travelling', 'circle', 'make', 'station', 'assaulting', 'also', 'boy', 'uncomfortable', 'prostitute', 'followed', 'very', 'came', 'us', 'hr', 'has', 'him', 'go', 'chain', 'thought', 'felt', 'almost', 'part', 'heavy', 'tone', 'view', 'her', 'classmates', 'intention', 'couldn', 'take', 'dancing', 'follow', 'body', 'staring', 'continuously', 'last', 'traveling', 'guy', 'money', 'coaching', 'point', 'feels', 'that', 'man', 'assault', 'overcrowded', 'teasing', 'people', 'pinched', 'saw', 'female'}
#
# After nostop filter :
#  ['na', 'sexually', 'assaulting', 'three', 'boys', 'singing', 'song', 'passed', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'coaching', 'classmates', 'used', 'follow', 'us', 'everywhere', 'used', 'go', 'pass', 'comments', 'dressing', 'body', 'language', 'felt', 'uncomfortable', 'around', 'pm', 'supposed', 'receive', 'female', 'friend', 'soon', 'came', 'group', 'grown', 'men', 'started', 'passing', 'comments', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'party', 'dancing', 'college', 'guy', 'pinched', 'girl', 'inappropriate', 'part', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'witnessed', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'man', 'thought', 'prostitute', 'offering', 'money', 'one', 'night', 'taking', 'pictures', 'taking', 'pictures', 'taking', 'pictures', 'people', 'followed', 'home', 'also', 'pelted', 'stone', 'comments', 'continuously', 'victim', 'hr', 'way', 'metro', 'station', 'group', 'boys', 'catcalled', 'whistled', 'grab', 'attention', 'walking', 'inner', 'circle', 'boy', 'used', 'heavy', 'tone', 'make', 'obscene', 'voices', 'none']
#
# Top 20 most used words after non_stop:
#  [('taking', 4), ('pictures', 4), ('boys', 3), ('used', 3), ('comments', 3), ('group', 3), ('girl', 3), ('never', 2), ('felt', 2), ('assault', 2), ('almost', 2), ('everyday', 2), ('victim', 2), ('take', 2), ('metro', 2), ('man', 2), ('teasing', 2), ('na', 1), ('sexually', 1), ('assaulting', 1)]
#
# After lemmatizer :
#  ['na', 'sexually', 'assault', 'three', 'boys', 'sing', 'song', 'pass', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'govt', 'official', 'time', 'feel', 'unsafe', 'due', 'overcrowd', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'travel', 'unfortunately', 'never', 'take', 'action', 'far', 'coach', 'classmates', 'use', 'follow', 'us', 'everywhere', 'use', 'go', 'pass', 'comment', 'dress', 'body', 'language', 'felt', 'uncomfortable', 'around', 'pm', 'suppose', 'receive', 'female', 'friend', 'soon', 'come', 'group', 'grow', 'men', 'start', 'pass', 'comment', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stand', 'point', 'view', 'give', 'casual', 'look', 'fortunately', 'send', 'message', 'party', 'dance', 'college', 'guy', 'pinch', 'girl', 'inappropriate', 'part', 'come', 'class', 'saw', 'group', 'boys', 'tease', 'girl', 'witness', 'chain', 'robbery', 'take', 'picture', 'verbal', 'tease', 'man', 'think', 'prostitute', 'offer', 'money', 'one', 'night', 'take', 'picture', 'take', 'picture', 'take', 'picture', 'people', 'follow', 'home', 'also', 'pelt', 'stone', 'comment', 'continuously', 'victim', 'hr', 'way', 'metro', 'station', 'group', 'boys', 'catcall', 'whistle', 'grab', 'attention', 'walk', 'inner', 'circle', 'boy', 'use', 'heavy', 'tone', 'make', 'obscene', 'voice', 'none']
#
# Top 20 most used words after lemmatizer:
#  [('take', 6), ('picture', 4), ('assault', 3), ('boys', 3), ('pass', 3), ('use', 3), ('comment', 3), ('group', 3), ('girl', 3), ('never', 2), ('felt', 2), ('almost', 2), ('everyday', 2), ('time', 2), ('victim', 2), ('travel', 2), ('follow', 2), ('come', 2), ('metro', 2), ('man', 2)]
#
# After stemmer :
#  ['na', 'sexual', 'assault', 'three', 'boy', 'sing', 'song', 'pass', 'student', 'regular', 'travel', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'govt', 'offici', 'time', 'feel', 'unsaf', 'due', 'overcrowd', 'area', 'last', 'mani', 'year', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'travel', 'unfortun', 'never', 'take', 'action', 'far', 'coach', 'classmat', 'use', 'follow', 'us', 'everywher', 'use', 'go', 'pass', 'comment', 'dress', 'bodi', 'languag', 'felt', 'uncomfort', 'around', 'pm', 'suppos', 'receiv', 'femal', 'friend', 'soon', 'come', 'group', 'grow', 'men', 'start', 'pass', 'comment', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intent', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stand', 'point', 'view', 'give', 'casual', 'look', 'fortun', 'send', 'messag', 'parti', 'danc', 'colleg', 'guy', 'pinch', 'girl', 'inappropri', 'part', 'come', 'class', 'saw', 'group', 'boy', 'teas', 'girl', 'wit', 'chain', 'robberi', 'take', 'pictur', 'verbal', 'teas', 'man', 'think', 'prostitut', 'offer', 'money', 'one', 'night', 'take', 'pictur', 'take', 'pictur', 'take', 'pictur', 'peopl', 'follow', 'home', 'also', 'pelt', 'stone', 'comment', 'continu', 'victim', 'hr', 'way', 'metro', 'station', 'group', 'boy', 'catcal', 'whistl', 'grab', 'attent', 'walk', 'inner', 'circl', 'boy', 'use', 'heavi', 'tone', 'make', 'obscen', 'voic', 'none']
#
# Top 20 most used words after stemmer:
#  [('take', 6), ('boy', 4), ('pictur', 4), ('assault', 3), ('pass', 3), ('travel', 3), ('use', 3), ('comment', 3), ('group', 3), ('girl', 3), ('sexual', 2), ('never', 2), ('felt', 2), ('almost', 2), ('everyday', 2), ('time', 2), ('victim', 2), ('follow', 2), ('come', 2), ('metro', 2)]
#
#  SexualInvites.txt
# HBox(children=(IntProgress(value=0, max=280), HTML(value='')))
# Words and digits eng :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'sexually', 'assaulting', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'in', 'jaipur', 'my', 'college', 'backpack', 'i', 'worked', 'out', 'and', 'went', 'out', 'for', 'shopping', 'i', 'was', 'pumped', 'up', 'a', 'year', 'old', 'sikh', 'man', 'on', 'a', 'splender', 'bike', 'came', 'to', 'me', 'and', 'directly', 'asked', 'me', 'to', 'have', 'sex', 'with', 'hi', 'at', 'various', 'apps', 'like', 'webchat', 'and', 'all', 'i', 'do', 'showoff', 'little', 'bi', 'and', 'have', 'been', 'approached', 'and', 'asked', 'gay', 'relations', 'until', 'and', 'unless', 'strong', 'punishments', 'live', 'non', 'bailable', 'prison', 'for', 'min', 'years', 'or', 'death', 'punishment', 'rape', 'has', 'happened', 'are', 'happening', 'and', 'will', 'still', 'happen', 'awareness', 'will', 'come', 'when', 'punishments', 'will', 'be', 'in', 'practice', 'i', 'would', 'like', 'to', 'share', 'that', 'about', 'a', 'year', 'ago', 'when', 'i', 'was', 'in', 'manipur', 'there', 'the', 'people', 'were', 'behaving', 'not', 'like', 'normal', 'in', 'the', 'train', 'vellor', 'to', 'bhopal', 'in', 'a', 'beer', 'bar', 'after', 'it', 'closed', 'two', 'girls', 'who', 'were', 'there', 'are', 'hit', 'by', 'some', 'men', 'when', 'she', 'refused', 'to', 'go', 'with', 'them', 'i', 'was', 'travelling', 'in', 'the', 'delhi', 'metro', 'and', 'a', 'man', 'was', 'staring', 'at', 'a', 'girl', 'with', 'the', 'intention', 'full', 'of', 'lust', 'after', 'a', 'decent', 'amount', 'of', 'time', 'i', 'couldn', 't', 'take', 'it', 'and', 'i', 'stood', 'in', 'his', 'point', 'of', 'view', 'and', 'gave', 'him', 'a', 'casual', 'look', 'fortunately', 'that', 'sent', 'the', 'message', 'in', 'bhilwara', 'there', 'is', 'a', 'labour', 'colony', 'where', 'during', 'my', 'visit', 'for', 'apartment', 'hunting', 'some', 'labours', 'bullied', 'my', 'group', 'and', 'showed', 'us', 'knife', 'for', 'just', 'being', 'on', 'the', 'side', 'of', 'the', 'road', 'my', 'project', 'manager', 'has', 'been', 'harassing', 'me', 'repeatedly', 'with', 'sexual', 'invites', 'and', 'immodest', 'talks']
#
# Set() unique words and digits eng :
#  {'showoff', 'delhi', 'being', 'in', 'and', 'are', 'amount', 'project', 'little', 'unsafe', 'a', 'live', 'manager', 'still', 'it', 'until', 'behind', 'official', 'or', 'girls', 'some', 'group', 'sexual', 'harassing', 'pedicab', 'punishment', 'college', 'gay', 'share', 'behaving', 'will', 'grabs', 'old', 'sikh', 'non', 'jaipur', 'punishments', 'of', 'prison', 'invites', 'bar', 'lust', 'sexually', 'is', 'when', 'apps', 't', 'then', 'there', 'refused', 'have', 'fortunately', 'closed', 'visit', 'at', 'beer', 'bike', 'bhopal', 'the', 'she', 'manipur', 'to', 'for', 'who', 'up', 'expecting', 'men', 'way', 'shopping', 'years', 'splender', 'after', 'happened', 'unless', 'blocks', 'min', 'about', 'area', 'all', 'talks', 'labour', 'during', 'hunting', 'backpack', 'train', 'hit', 'time', 'with', 'due', 'them', 'full', 'i', 'message', 'bailable', 'look', 'happening', 'stood', 'bullied', 'webchat', 'cyclist', 'just', 'relations', 'apartment', 'follows', 'quietly', 'times', 'would', 'repeatedly', 'were', 'been', 'his', 'be', 'give', 'on', 'govt', 'gave', 'casual', 'colony', 'me', 'happen', 'worked', 'death', 'sent', 'not', 'my', 'girl', 'was', 'practice', 'decent', 'sex', 'metro', 'various', 'where', 'come', 'rape', 'travelling', 'approached', 'assaulting', 'normal', 'side', 'bi', 'two', 'came', 'us', 'ago', 'has', 'awareness', 'went', 'go', 'him', 'asked', 'hi', 'immodest', 'view', 'her', 'pedestrian', 'intention', 'couldn', 'take', 'bhilwara', 'like', 'labours', 'road', 'pumped', 'staring', 'year', 'out', 'vellor', 'knife', 'point', 'feels', 'that', 'man', 'overcrowded', 'people', 'strong', 'do', 'showed', 'directly', 'by'}
#
# After nostop filter :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'blocks', 'way', 'grabs', 'expecting', 'quietly', 'give', 'sexually', 'assaulting', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'jaipur', 'college', 'backpack', 'worked', 'went', 'shopping', 'pumped', 'year', 'old', 'sikh', 'man', 'splender', 'bike', 'came', 'directly', 'asked', 'sex', 'hi', 'various', 'apps', 'like', 'webchat', 'showoff', 'little', 'bi', 'approached', 'asked', 'gay', 'relations', 'unless', 'strong', 'punishments', 'live', 'non', 'bailable', 'prison', 'min', 'years', 'death', 'punishment', 'rape', 'happened', 'happening', 'still', 'happen', 'awareness', 'come', 'punishments', 'practice', 'would', 'like', 'share', 'year', 'ago', 'manipur', 'people', 'behaving', 'like', 'normal', 'train', 'vellor', 'bhopal', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'bhilwara', 'labour', 'colony', 'visit', 'apartment', 'hunting', 'labours', 'bullied', 'group', 'showed', 'us', 'knife', 'side', 'road', 'project', 'manager', 'harassing', 'repeatedly', 'sexual', 'invites', 'immodest', 'talks']
#
# Top 20 most used words after non_stop:
#  [('like', 3), ('year', 2), ('man', 2), ('asked', 2), ('punishments', 2), ('pedicab', 1), ('cyclist', 1), ('follows', 1), ('behind', 1), ('pedestrian', 1), ('blocks', 1), ('way', 1), ('grabs', 1), ('expecting', 1), ('quietly', 1), ('give', 1), ('sexually', 1), ('assaulting', 1), ('govt', 1), ('official', 1)]
#
# After lemmatizer :
#  ['pedicab', 'cyclist', 'follow', 'behind', 'pedestrian', 'block', 'way', 'grab', 'expect', 'quietly', 'give', 'sexually', 'assault', 'govt', 'official', 'time', 'feel', 'unsafe', 'due', 'overcrowd', 'area', 'jaipur', 'college', 'backpack', 'work', 'go', 'shop', 'pump', 'year', 'old', 'sikh', 'man', 'splender', 'bike', 'come', 'directly', 'ask', 'sex', 'hi', 'various', 'apps', 'like', 'webchat', 'showoff', 'little', 'bi', 'approach', 'ask', 'gay', 'relations', 'unless', 'strong', 'punishments', 'live', 'non', 'bailable', 'prison', 'min', 'years', 'death', 'punishment', 'rape', 'happen', 'happen', 'still', 'happen', 'awareness', 'come', 'punishments', 'practice', 'would', 'like', 'share', 'year', 'ago', 'manipur', 'people', 'behave', 'like', 'normal', 'train', 'vellor', 'bhopal', 'beer', 'bar', 'close', 'two', 'girls', 'hit', 'men', 'refuse', 'go', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stand', 'point', 'view', 'give', 'casual', 'look', 'fortunately', 'send', 'message', 'bhilwara', 'labour', 'colony', 'visit', 'apartment', 'hunt', 'labour', 'bully', 'group', 'show', 'us', 'knife', 'side', 'road', 'project', 'manager', 'harass', 'repeatedly', 'sexual', 'invite', 'immodest', 'talk']
#
# Top 20 most used words after lemmatizer:
#  [('like', 3), ('happen', 3), ('give', 2), ('time', 2), ('go', 2), ('year', 2), ('man', 2), ('come', 2), ('ask', 2), ('punishments', 2), ('labour', 2), ('pedicab', 1), ('cyclist', 1), ('follow', 1), ('behind', 1), ('pedestrian', 1), ('block', 1), ('way', 1), ('grab', 1), ('expect', 1)]
#
# After stemmer :
#  ['pedicab', 'cyclist', 'follow', 'behind', 'pedestrian', 'block', 'way', 'grab', 'expect', 'quietli', 'give', 'sexual', 'assault', 'govt', 'offici', 'time', 'feel', 'unsaf', 'due', 'overcrowd', 'area', 'jaipur', 'colleg', 'backpack', 'work', 'go', 'shop', 'pump', 'year', 'old', 'sikh', 'man', 'splender', 'bike', 'come', 'directli', 'ask', 'sex', 'hi', 'variou', 'app', 'like', 'webchat', 'showoff', 'littl', 'bi', 'approach', 'ask', 'gay', 'relat', 'unless', 'strong', 'punish', 'live', 'non', 'bailabl', 'prison', 'min', 'year', 'death', 'punish', 'rape', 'happen', 'happen', 'still', 'happen', 'awar', 'come', 'punish', 'practic', 'would', 'like', 'share', 'year', 'ago', 'manipur', 'peopl', 'behav', 'like', 'normal', 'train', 'vellor', 'bhopal', 'beer', 'bar', 'close', 'two', 'girl', 'hit', 'men', 'refus', 'go', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intent', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stand', 'point', 'view', 'give', 'casual', 'look', 'fortun', 'send', 'messag', 'bhilwara', 'labour', 'coloni', 'visit', 'apart', 'hunt', 'labour', 'bulli', 'group', 'show', 'us', 'knife', 'side', 'road', 'project', 'manag', 'harass', 'repeatedli', 'sexual', 'invit', 'immodest', 'talk']
#
# Top 20 most used words after stemmer:
#  [('year', 3), ('like', 3), ('punish', 3), ('happen', 3), ('give', 2), ('sexual', 2), ('time', 2), ('go', 2), ('man', 2), ('come', 2), ('ask', 2), ('girl', 2), ('labour', 2), ('pedicab', 1), ('cyclist', 1), ('follow', 1), ('behind', 1), ('pedestrian', 1), ('block', 1), ('way', 1)]
#
#  Stalking.txt
# HBox(children=(IntProgress(value=0, max=759), HTML(value='')))
# Words and digits eng :
#  ['na', 'pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'she', 'works', 'as', 'a', 'field', 'coordinator', 'and', 'around', 'an', 'year', 'back', 'a', 'man', 'followed', 'her', 'and', 'asked', 'her', 'contact', 'details', 'she', 'is', 'student', 'and', 'she', 'doesn', 't', 'feels', 'safe', 'at', 'all', 'at', 'the', 'station', 'and', 'she', 'faces', 'assault', 'almost', 'daily', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'molesters', 'saw', 'my', 'friend', 'on', 'her', 'vehicle', 'near', 'babari', 'mandi', 'and', 'while', 'they', 'were', 'about', 'to', 'leave', 'they', 'tried', 'to', 'get', 'hold', 'of', 'her', 'pallu', 'while', 'she', 'was', 'on', 'the', 'bike', 'she', 'scolded', 'them', 'but', 'let', 'them', 'go', 'unfortunately', 'i', 'was', 'stalked', 'by', 'a', 'man', 'while', 'i', 'was', 'at', 'the', 'cs', 'metro', 'station', 'he', 'followed', 'me', 'till', 'new', 'delhi', 'metro', 'station', 'as', 'soon', 'as', 'i', 'sat', 'in', 'the', 'airport', 'metro', 'the', 'man', 'came', 'and', 'sat', 'on', 'the', 'seat', 'right', 'next', 'to', 'mine', 'i', 'sensed', 'something', 'wrong', 'and', 'rushed', 'to', 'the', 'last', 'compartment', 'of', 'the', 'metro', 'okay', 'so', 'this', 'incident', 'happened', 'last', 'year', 'i', 'e', 'when', 'i', 'd', 'finished', 'my', 'classes', 'at', 'vashi', 'and', 'was', 'heading', 'towards', 'the', 'vashi', 'depot', 'to', 'take', 'a', 'bus', 'to', 'my', 'place', 'kharghar', 'navi', 'mumbai', 'so', 'i', 'boarded', 'a', 'numbered', 'bus', 'and', 'took', 'a', 'ladies', 'seat', 'window', 'side', 'i', 'was', 'on', 'a', 'phone', 'call', 'after', 'a', 'few', 'minutes', 'i', 'realised', 'that', 'i', 'was', 'touched', 'near', 'my', 'boobs', 'from', 'behind', 'for', 'an', 'instance', 'i', 'thought', 'it', 'might', 'just', 'be', 'the', 'rod', 'of', 'the', 'seat', 'but', 'later', 'i', 'realised', 'it', 'wasn', 't', 'it', 'was', 'somebody', 's', 'hand', 'trying', 'to', 'grab', 'me', 'up', 'there', 'i', 'caught', 'hold', 'of', 'the', 'man', 's', 'hand', 'right', 'there', 'turned', 'it', 'turned', 'myself', 'and', 'abused', 'him', 'asking', 'what', 'he', 'was', 'upto', 'he', 'was', 'quite', 'shocked', 'i', 'am', 'sure', 'he', 'wasn', 't', 'expecting', 'a', 'girl', 'to', 'react', 'that', 'way', 'our', 'men', 'think', 'we', 'are', 'scared', 'of', 'speaking', 'out', 'that', 'way', 'but', 'i', 'did', 'i', 'didn', 't', 'fear', 'the', 'bus', 'conductor', 'came', 'to', 'the', 'site', 'and', 'pulled', 'his', 'shirt', 'and', 'put', 'him', 'down', 'the', 'bus', 'well', 'this', 'wasn', 't', 'the', 'only', 'later', 'after', 'minutes', 'a', 'man', 'sat', 'down', 'beside', 'me', 'he', 'started', 'touching', 'my', 'thigh', 'i', 'bursted', 'out', 'on', 'him', 'even', 'madly', 'as', 'it', 'was', 'just', 'minutes', 'back', 'that', 'the', 'first', 'one', 'had', 'happened', 'i', 'turned', 'towards', 'him', 'without', 'giving', 'a', 'second', 'thought', 'i', 'literally', 'slapped', 'him', 'abused', 'him', 'again', 'i', 'was', 'angry', 'angry', 'to', 'what', 'was', 'happening', 'with', 'me', 'the', 'people', 'there', 'in', 'the', 'bus', 'hit', 'him', 'and', 'even', 'he', 'was', 'put', 'down', 'so', 'this', 'happened', 'i', 'didn', 't', 'hesitate', 'to', 'do', 'whatever', 'i', 'did', 'it', 'was', 'necessary', 'i', 'thought', 'my', 'misery', 'ended', 'but', 'there', 'was', 'another', 'lecher', 'who', 'was', 'staring', 'at', 'me', 'for', 'most', 'of', 'the', 'time', 'i', 'complained', 'to', 'the', 'conductor', 'and', 'forced', 'him', 'out', 'of', 'the', 'bus', 'too', 'i', 'was', 'followed', 'and', 'tailed', 'by', 'a', 'partially', 'bald', 'middle', 'aged', 'man', 'wearing', 'an', 'army', 'shirt', 'mi ...
#
# Set() unique words and digits eng :
#  {'delhi', 'thigh', 'in', 'bursted', 'and', 'are', 'shirt', 'amount', 'trying', 'well', 'kirori', 'classes', 'only', 'a', 'kharghar', 'middle', 'down', 'ramjas', 'as', 'mumbai', 'it', 'rushed', 'hesitate', 'react', 'away', 'misery', 'even', 'following', 'behind', 'student', 'realised', 'window', 'might', 'going', 'returning', 'heading', 'victim', 'or', 'job', 'if', 'jogged', 'some', 'back', 'slapped', 'sexual', 'action', 'right', 'didn', 'police', 'pedicab', 'college', 'their', 'neighbour', 'grabs', 'towards', 'works', 'sepoy', 'function', 'old', 'necessary', 'lecher', 'something', 'site', 'of', 'later', 'conductor', 'second', 'seek', 'school', 'drunk', 'turned', 'hold', 'lust', 'our', 'hand', 'till', 'asking', 'sure', 'airport', 'around', 'unfortunately', 'bald', 'next', 'randomly', 'navi', 'is', 'upto', 'many', 'fear', 'angry', 'got', 'soon', 'when', 'an', 't', 'then', 'there', 'fortunately', 'have', 'wrong', 'at', 'everyday', 'boobs', 'started', 'so', 'bike', 'the', 'she', 'ed', 'army', 'one', 'to', 'for', 'who', 'speaking', 'up', 'expecting', 'field', 'while', 'way', 'men', 'another', 'stopping', 'years', 'language', 'after', 'sensed', 'boys', 'scared', 'happened', 'place', 'confirmed', 'blocks', 'again', 'about', 'faces', 'partially', 'used', 'comments', 'you', 'all', 'everywhere', 'area', 'during', 'purposely', 'chance', 'touched', 'time', 'hit', 'barnala', 'with', 'someone', 'them', 'full', 'i', 's', 'message', 'always', 'look', 'happening', 'stood', 'first', 'gone', 'na', 'sly', 'cyclist', 'sat', 'just', 'but', 'hours', 'e', 'tailed', 'temple', 'caught', 'phone', 'follows', 'quietly', 'friend', 'dressing', 'accused', 'madly', 'incident', 'whatever', 'get', 'were', 'attending', 'safe', 'been', 'market', 'his', 'be', 'give', 'beside', 'pass', 'more', 'numbered', 'wearing', 'on', 'details', 'grab', 'created', 'ladies', 'never', 'tried', 'forced', 'playing', 'rod', 'compartment', 'any', 'he', 'daily', 'gave', 'casual', 'let', 'we', 'put', 'ended', 'me', 'minutes', 'leave', 'far', 'pallu', 'disappeared', 'sent', 'close', 'without', 'whole', 'pg', 'most', 'coordinator', 'my', 'mandi', 'was', 'few', 'girl', 'home', 'pulled', 'not', 'touching', 'vehicle', 'decent', 'metro', 'vashi', 'from', 'problem', 'okay', 'shocked', 'babari', 'stalked', 'travelling', 'molesters', 'punjab', 'station', 'quite', 'indecent', 'instance', 'report', 'also', 'uncomfortable', 'side', 'myself', 'had', 'followed', 'very', 'came', 'boarded', 'us', 'has', 'too', 'him', 'go', 'new', 'could', 'asked', 'stopped', 'abused', 'thought', 'felt', 'almost', 'finished', 'wasn', 'aged', 'am', 'part', 'view', 'depot', 'her', 'your', 'commented', 'mine', 'what', 'pedestrian', 'classmates', 'did', 'intention', 'mal', 'survive', 'near', 'scolded', 'call', 'couldn', 'take', 'think', 'complained', 'follow', 'body', 'things', 'somebody', 'staring', 'year', 'giving', 'reported', 'last', 'traveling', 'cs', 'out', 'literally', 'coaching', 'point', 'feels', 'stop', 'contact', 'seat', 'this', 'man', 'they', 'assault', 'that', 'doesn', 'people', 'do', 'bus', 'raped', 'saw', 'took', 'friends', 'by', 'd'}
#
# After nostop filter :
# ...
#
# Top 20 most used words after non_stop:
#  [('taking', 4), ('pictures', 4), ('used', 2), ('bus', 2), ('man', 2), ('offering', 2), ('teasing', 2), ('one', 2), ('friend', 2), ('govt', 1), ('official', 1), ('times', 1), ('feels', 1), ('unsafe', 1), ('due', 1), ('overcrowded', 1), ('area', 1), ('coaching', 1), ('classmates', 1), ('follow', 1)]
#
# After lemmatizer :
#  ['govt', 'official', 'time', 'feel', 'unsafe', 'due', 'overcrowd', 'area', 'coach', 'classmates', 'use', 'follow', 'us', 'everywhere', 'use', 'go', 'pass', 'comment', 'dress', 'body', 'language', 'felt', 'uncomfortable', 'wait', 'bus', 'man', 'come', 'bike', 'offer', 'liftvto', 'young', 'girls', 'come', 'class', 'saw', 'group', 'boys', 'tease', 'girl', 'take', 'picture', 'verbal', 'tease', 'one', 'even', 'inside', 'first', 'class', 'compartment', 'guy', 'star', 'friend', 'try', 'touch', 'man', 'think', 'prostitute', 'offer', 'money', 'one', 'night', 'take', 'picture', 'take', 'picture', 'take', 'picture', 'bad', 'people', 'touch', 'private', 'part', 'ranchi', 'bhagalpur', 'express', 'andal', 'railway', 'station', 'talk', 'objectionable', 'picture', 'friend', 'bus']
#
# Top 20 most used words after lemmatizer:
#  [('picture', 5), ('take', 4), ('use', 2), ('bus', 2), ('man', 2), ('come', 2), ('offer', 2), ('class', 2), ('tease', 2), ('one', 2), ('friend', 2), ('touch', 2), ('govt', 1), ('official', 1), ('time', 1), ('feel', 1), ('unsafe', 1), ('due', 1), ('overcrowd', 1), ('area', 1)]
#
# After stemmer :
#  ['govt', 'offici', 'time', 'feel', 'unsaf', 'due', 'overcrowd', 'area', 'coach', 'classmat', 'use', 'follow', 'us', 'everywher', 'use', 'go', 'pass', 'comment', 'dress', 'bodi', 'languag', 'felt', 'uncomfort', 'wait', 'bu', 'man', 'come', 'bike', 'offer', 'liftvto', 'young', 'girl', 'come', 'class', 'saw', 'group', 'boy', 'teas', 'girl', 'take', 'pictur', 'verbal', 'teas', 'one', 'even', 'insid', 'first', 'class', 'compart', 'guy', 'star', 'friend', 'tri', 'touch', 'man', 'think', 'prostitut', 'offer', 'money', 'one', 'night', 'take', 'pictur', 'take', 'pictur', 'take', 'pictur', 'bad', 'peopl', 'touch', 'privat', 'part', 'ranchi', 'bhagalpur', 'express', 'andal', 'railway', 'station', 'talk', 'objection', 'pictur', 'friend', 'bu']
#
# Top 20 most used words after stemmer:
#  [('pictur', 5), ('take', 4), ('use', 2), ('bu', 2), ('man', 2), ('come', 2), ('offer', 2), ('girl', 2), ('class', 2), ('teas', 2), ('one', 2), ('friend', 2), ('touch', 2), ('govt', 1), ('offici', 1), ('time', 1), ('feel', 1), ('unsaf', 1), ('due', 1), ('overcrowd', 1)]
#
#  PoorNoStreetLighting.txt
# HBox(children=(IntProgress(value=0, max=163), HTML(value='')))
# Words and digits eng :
#  ['she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'i', 'work', 'in', 'a', 'factory', 'in', 'bengaluru', 'rural', 'area', 'the', 'street', 'which', 'leads', 'to', 'the', 'factory', 'where', 'i', 'work', 'has', 'no', 'street', 'lights', 'at', 'all', 'it', 'becomes', 'extremely', 'difficult', 'for', 'those', 'who', 'have', 'to', 'go', 'to', 'work', 'in', 'the', 'night', 'shift', 'sometimes', 'even', 'robbery', 'also', 'takes', 'place', 'by', 'strangers', 'one', 'day', 'a', 'group', 'of', 'people', 'came', 'onto', 'me', 'and', 'i', 'was', 'mugged', 'they', 'took', 'my', 'phone', 'and', 'wallet', 'in', 'a', 'beer', 'bar', 'after', 'it', 'closed', 'two', 'girls', 'who', 'were', 'there', 'are', 'hit', 'by', 'some', 'men', 'when', 'she', 'refused', 'to', 'go', 'with', 'them', 'i', 'was', 'waiting', 'for', 'the', 'bus', 'a', 'man', 'came', 'on', 'a', 'bike', 'and', 'was', 'offering', 'liftvto', 'young', 'girls', 'while', 'coming', 'from', 'classes', 'i', 'saw', 'a', 'group', 'of', 'boys', 'were', 'teasing', 'a', 'girl', 'i', 'witnessed', 'a', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'a', 'gang', 'of', 'goon', 'looted', 'me', 'outside', 'the', 'raniganj', 'station']
#
# Set() unique words and digits eng :
#  {'coming', 'waiting', 'in', 'and', 'are', 'classes', 'a', 'it', 'even', 'onto', 'student', 'difficult', 'taking', 'lights', 'girls', 'some', 'group', 'night', 'of', 'offering', 'bar', 'gang', 'is', 'regular', 'when', 'refused', 'there', 'have', 'closed', 'at', 'extremely', 'everyday', 'beer', 'bike', 'mugged', 'outside', 'the', 'she', 'witnessed', 'one', 'to', 'for', 'who', 'men', 'while', 'strangers', 'after', 'boys', 'place', 'faces', 'those', 'area', 'all', 'factory', 'hit', 'with', 'them', 'i', 'bengaluru', 'which', 'robbery', 'goon', 'but', 'becomes', 'day', 'phone', 'pictures', 'traveller', 'were', 'safe', 'on', 'never', 'young', 'verbal', 'me', 'sometimes', 'my', 'girl', 'was', 'where', 'from', 'work', 'leads', 'station', 'also', 'street', 'two', 'came', 'takes', 'has', 'go', 'looted', 'chain', 'felt', 'almost', 'shift', 'raniganj', 'wallet', 'liftvto', 'man', 'they', 'assault', 'rural', 'teasing', 'people', 'no', 'bus', 'saw', 'took', 'by'}
#
# After nostop filter :
#  ['student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'work', 'factory', 'bengaluru', 'rural', 'area', 'street', 'leads', 'factory', 'work', 'street', 'lights', 'becomes', 'extremely', 'difficult', 'go', 'work', 'night', 'shift', 'sometimes', 'even', 'robbery', 'also', 'takes', 'place', 'strangers', 'one', 'day', 'group', 'people', 'came', 'onto', 'mugged', 'took', 'phone', 'wallet', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'waiting', 'bus', 'man', 'came', 'bike', 'offering', 'liftvto', 'young', 'girls', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'witnessed', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'gang', 'goon', 'looted', 'outside', 'raniganj', 'station']
#
# Top 20 most used words after non_stop:
#  [('work', 3), ('factory', 2), ('street', 2), ('go', 2), ('robbery', 2), ('group', 2), ('came', 2), ('girls', 2), ('teasing', 2), ('student', 1), ('regular', 1), ('traveller', 1), ('never', 1), ('felt', 1), ('safe', 1), ('faces', 1), ('assault', 1), ('almost', 1), ('everyday', 1), ('bengaluru', 1)]
#
# After lemmatizer :
#  ['student', 'regular', 'traveller', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'work', 'factory', 'bengaluru', 'rural', 'area', 'street', 'lead', 'factory', 'work', 'street', 'light', 'become', 'extremely', 'difficult', 'go', 'work', 'night', 'shift', 'sometimes', 'even', 'robbery', 'also', 'take', 'place', 'strangers', 'one', 'day', 'group', 'people', 'come', 'onto', 'mug', 'take', 'phone', 'wallet', 'beer', 'bar', 'close', 'two', 'girls', 'hit', 'men', 'refuse', 'go', 'wait', 'bus', 'man', 'come', 'bike', 'offer', 'liftvto', 'young', 'girls', 'come', 'class', 'saw', 'group', 'boys', 'tease', 'girl', 'witness', 'chain', 'robbery', 'take', 'picture', 'verbal', 'tease', 'gang', 'goon', 'loot', 'outside', 'raniganj', 'station']
#
# Top 20 most used words after lemmatizer:
#  [('work', 3), ('take', 3), ('come', 3), ('factory', 2), ('street', 2), ('go', 2), ('robbery', 2), ('group', 2), ('girls', 2), ('tease', 2), ('student', 1), ('regular', 1), ('traveller', 1), ('never', 1), ('felt', 1), ('safe', 1), ('face', 1), ('assault', 1), ('almost', 1), ('everyday', 1)]
#
# After stemmer :
#  ['student', 'regular', 'travel', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'work', 'factori', 'bengaluru', 'rural', 'area', 'street', 'lead', 'factori', 'work', 'street', 'light', 'becom', 'extrem', 'difficult', 'go', 'work', 'night', 'shift', 'sometim', 'even', 'robberi', 'also', 'take', 'place', 'stranger', 'one', 'day', 'group', 'peopl', 'come', 'onto', 'mug', 'take', 'phone', 'wallet', 'beer', 'bar', 'close', 'two', 'girl', 'hit', 'men', 'refus', 'go', 'wait', 'bu', 'man', 'come', 'bike', 'offer', 'liftvto', 'young', 'girl', 'come', 'class', 'saw', 'group', 'boy', 'teas', 'girl', 'wit', 'chain', 'robberi', 'take', 'pictur', 'verbal', 'teas', 'gang', 'goon', 'loot', 'outsid', 'raniganj', 'station']
#
# Top 20 most used words after stemmer:
#  [('work', 3), ('take', 3), ('come', 3), ('girl', 3), ('factori', 2), ('street', 2), ('go', 2), ('robberi', 2), ('group', 2), ('teas', 2), ('student', 1), ('regular', 1), ('travel', 1), ('never', 1), ('felt', 1), ('safe', 1), ('face', 1), ('assault', 1), ('almost', 1), ('everyday', 1)]
#
#  OnlineHarassment.txt
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Words and digits eng :
#  []
#
# Set() unique words and digits eng :
#  set()
#
# After nostop filter :
#  []
#
# Top 20 most used words after non_stop:
#  []
#
# After lemmatizer :
#  []
#
# Top 20 most used words after lemmatizer:
#  []
#
# After stemmer :
#  []
#
# Top 20 most used words after stemmer:
#  []
#
# corpus: 14
# Top_20 after Term Frequency–Inverse Document Frequency
#
#  TouchingGroping
# touch 0.320094587328357
# think 0.1584567489134669
# happen 0.15618966003780863
# behind 0.1280378349313428
# wear 0.1280378349313428
# bu 0.1232441380438076
# minut 0.12130428991292244
# put 0.12130428991292244
# turn 0.12130428991292244
# chang 0.10967583320462704
# cigarett 0.10967583320462704
# cloth 0.10967583320462704
# grope 0.10967583320462704
# jean 0.10967583320462704
# manner 0.10967583320462704
# mean 0.10967583320462704
# modern 0.10967583320462704
# mom 0.10967583320462704
# short 0.10967583320462704
# signal 0.10967583320462704
#
#  CatcallsWhistles
# pictur 0.22048054906576722
# circl 0.17168130484352545
# heavi 0.17168130484352545
# inner 0.17168130484352545
# sing 0.17168130484352545
# song 0.17168130484352545
# three 0.17168130484352545
# tone 0.17168130484352545
# voic 0.17168130484352545
# pass 0.16536041179932542
# comment 0.16536041179932542
# group 0.16536041179932542
# use 0.16536041179932542
# boy 0.1456210406733341
# victim 0.1339617772226735
# teas 0.1339617772226735
# attent 0.12658928995179483
# catcal 0.12658928995179483
# danc 0.12658928995179483
# grow 0.12658928995179483
#
#  SexualInvites
# like 0.33291559689299727
# punish 0.33291559689299727
# labour 0.2219437312619982
# happen 0.15803534343184633
# ago 0.1109718656309991
# apart 0.1109718656309991
# app 0.1109718656309991
# approach 0.1109718656309991
# awar 0.1109718656309991
# backpack 0.1109718656309991
# bailabl 0.1109718656309991
# bhilwara 0.1109718656309991
# bhopal 0.1109718656309991
# bi 0.1109718656309991
# bulli 0.1109718656309991
# coloni 0.1109718656309991
# death 0.1109718656309991
# directli 0.1109718656309991
# gay 0.1109718656309991
# hi 0.1109718656309991
#
#  Stalking
# bu 0.187206719549439
# later 0.17017726365444288
# stop 0.17017726365444288
# might 0.1612275944684305
# minut 0.1612275944684305
# seat 0.1612275944684305
# turn 0.1612275944684305
# stalk 0.1612275944684305
# happen 0.13839622207818392
# back 0.12763294774083217
# behind 0.12763294774083217
# sit 0.12763294774083217
# way 0.11374493108409656
# abus 0.10748506297895365
# angri 0.10748506297895365
# conductor 0.10748506297895365
# put 0.10748506297895365
# realis 0.10748506297895365
# right 0.10748506297895365
# shirt 0.10748506297895365
#
#  Others
# rickshaw 0.35390607175258887
# employe 0.20657863210263824
# accept 0.17695303587629443
# adhoc 0.17695303587629443
# alon 0.17695303587629443
# atm 0.17695303587629443
# cabin 0.17695303587629443
# coffe 0.17695303587629443
# discuss 0.17695303587629443
# fb 0.17695303587629443
# issu 0.17695303587629443
# know 0.17695303587629443
# misunderstand 0.17695303587629443
# noth 0.17695303587629443
# professor 0.17695303587629443
# regard 0.17695303587629443
# request 0.17695303587629443
# senior 0.17695303587629443
# ask 0.13807527379024273
# lot 0.13047640327996587
#
#  Commenting
# comment 0.29600962536594355
# victim 0.22481561104292228
# indec 0.20181209913855358
# pass 0.14800481268297178
# back 0.13454139942570237
# employe 0.13454139942570237
# sit 0.13454139942570237
# someon 0.13454139942570237
# make 0.13454139942570237
# badli 0.11524671664780145
# counter 0.11524671664780145
# omment 0.11524671664780145
# rude 0.11524671664780145
# ticket 0.11524671664780145
# unbear 0.11524671664780145
# weird 0.11524671664780145
# word 0.11524671664780145
# also 0.11100360951222883
# group 0.11100360951222883
# pictur 0.11100360951222883
#
#  RapeSexualAssault
# rap 0.43223241081469244
# dump 0.3702456373115499
# minor 0.3702456373115499
# tribal 0.3702456373115499
# pictur 0.35661408275375467
# disappear 0.21611620540734622
# hour 0.21611620540734622
# play 0.21611620540734622
# templ 0.21611620540734622
# old 0.17575594833269395
# get 0.14445010080859458
# take 0.10150124260606741
# year 0.097244844489428
# friend 0.06198677350314248
# men 0.06198677350314248
# sexual 0.06198677350314248
# assault 0.04720525631916659
# time 0.04720525631916659
# girl 0.020793904756833362
#
#  NorthEastIndiaReport
# assign 0.2905226390682259
# conduct 0.2905226390682259
# construct 0.2905226390682259
# cours 0.2905226390682259
# iit 0.2905226390682259
# sociolog 0.2905226390682259
# survey 0.2905226390682259
# women 0.2905226390682259
# worker 0.2905226390682259
# say 0.2299870622766384
# site 0.2299870622766384
# bar 0.1537212550438555
# beer 0.1537212550438555
# refus 0.1537212550438555
# close 0.10348625205369194
# offer 0.10348625205369194
# part 0.10348625205369194
# two 0.10348625205369194
# hit 0.08355013496084203
# men 0.06596523343135893
#
#  Indecentexposure
# tie 0.42379296190144855
# ac 0.21189648095072428
# bag 0.21189648095072428
# bellandur 0.21189648095072428
# bmtc 0.21189648095072428
# escap 0.21189648095072428
# hide 0.21189648095072428
# innoc 0.21189648095072428
# masturb 0.21189648095072428
# petrol 0.21189648095072428
# plastic 0.21189648095072428
# pretend 0.21189648095072428
# start 0.16534141094314914
# scream 0.15624196875299903
# pump 0.15624196875299903
# age 0.15624196875299903
# middl 0.15624196875299903
# rush 0.15624196875299903
# lot 0.15624196875299903
# sinc 0.15624196875299903
#
#  ChainSnatching
# snatch 0.5981155253745097
# chain 0.4492395559344219
# biker 0.2703895247446002
# road 0.1578291603758374
# two 0.14203536590619398
# flee 0.1351947623723001
# gold 0.1351947623723001
# helmet 0.1351947623723001
# injur 0.1351947623723001
# morn 0.1351947623723001
# motorbik 0.1351947623723001
# rider 0.1351947623723001
# thu 0.1351947623723001
# today 0.1351947623723001
# woman 0.1351947623723001
# aunt 0.09968592089575162
# polic 0.09968592089575162
# cross 0.09968592089575162
# gang 0.09968592089575162
# loot 0.09968592089575162
#
#  OglingFacialExpressionsStaring
# everi 0.3124063088070828
# comment 0.2507535494334026
# pass 0.20060283954672212
# crowd 0.18235479152422726
# sometim 0.18235479152422726
# andheri 0.1562031544035414
# bridg 0.1562031544035414
# cheap 0.1562031544035414
# chest 0.1562031544035414
# connect 0.1562031544035414
# multipl 0.1562031544035414
# past 0.1562031544035414
# person 0.1562031544035414
# reason 0.1562031544035414
# almost 0.1504521296600416
# victim 0.12188427965850952
# danc 0.11517646852810831
# grow 0.11517646852810831
# parti 0.11517646852810831
# pinch 0.11517646852810831
#
#  Takingpictures
# pictur 0.3931338700937953
# touch 0.28589762770678834
# objection 0.2448968349611832
# teas 0.1910913670973598
# andal 0.18057479512654814
# bad 0.18057479512654814
# bhagalpur 0.18057479512654814
# ranchi 0.18057479512654814
# compart 0.18057479512654814
# bu 0.15725354803751815
# class 0.15725354803751815
# use 0.15725354803751815
# first 0.14294881385339417
# privat 0.14294881385339417
# railway 0.14294881385339417
# talk 0.14294881385339417
# liftvto 0.14294881385339417
# wait 0.14294881385339417
# young 0.14294881385339417
# offer 0.1286440796692702
#
#  PoorNoStreetLighting
# factori 0.3522592182852092
# street 0.3522592182852092
# work 0.25082666774228746
# becom 0.1761296091426046
# bengaluru 0.1761296091426046
# difficult 0.1761296091426046
# extrem 0.1761296091426046
# lead 0.1761296091426046
# light 0.1761296091426046
# mug 0.1761296091426046
# onto 0.1761296091426046
# rural 0.1761296091426046
# shift 0.1761296091426046
# stranger 0.1761296091426046
# wallet 0.1761296091426046
# robberi 0.16721777849485828
# teas 0.13743275940139713
# gang 0.12986924919501686
# loot 0.12986924919501686
# outsid 0.12986924919501686
#
#  OnlineHarassment

# %%
#Without stemming
top20_and_allTokens_list = [top20_and_allTokens(fileNames[i]+'.txt', stemming=False, plot=False) for i in range(len(fileNames))]
categories_allTokens = [top20_and_allTokens_list[i] for i in range(len(top20_and_allTokens_list))]
corpus, dictionary, tfidf = top20_tf_idf(categories_allTokens)
# Out:
#  TouchingGroping.txt
# HBox(children=(IntProgress(value=0, max=1079), HTML(value='')))
# Words and digits eng :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'i', 'was', 'travelling', 'with', 'my', 'family', 'and', 'we', 'were', 'in', 'gurgaon', 'a', 'girl', 'with', 'a', 'boy', 'came', 'on', 'bike', 'and', 'the', 'girl', 'was', 'wearing', 'croptop', 'and', 'jeans', 'two', 'boys', 'in', 'a', 'car', 'came', 'behind', 'them', 'and', 'we', 'all', 'stopped', 'on', 'traffic', 'signal', 'and', 'those', 'boys', 'were', 'smoking', 'cigarettes', 'when', 'the', 'boys', 'saw', 'the', 'girl', 'they', 'put', 'their', 'burning', 'cigarettes', 'inside', 'the', 'jeans', 'of', 'the', 'girl', 'from', 'back', 'side', 'and', 'ran', 'away', 'and', 'the', 'girl', 'was', 'screaming', 'of', 'pain', 'i', 'noticed', 'the', 'people', 'standing', 'over', 'there', 'saying', 'that', 'it', 'was', 'the', 'fault', 'of', 'the', 'girl', 'as', 'she', 'was', 'wearing', 'short', 'clothes', 'and', 'her', 'body', 'was', 'uncovered', 'i', 'mean', 'this', 'was', 'seriously', 'so', 'shameful', 'and', 'ridiculous', 'instead', 'of', 'showing', 'sympathy', 'towards', 'that', 'girl', 'everyone', 'standing', 'there', 'was', 'blaming', 'her', 'and', 'her', 'dressing', 'sense', 'why', 'don', 't', 'you', 'teach', 'your', 'sons', 'to', 'behave', 'in', 'respectful', 'manner', 'one', 'similar', 'incindent', 'happened', 'with', 'me', 'when', 'i', 'was', 'in', 'th', 'standard', 'i', 'was', 'wearing', 'short', 'top', 'and', 'skirt', 'and', 'went', 'to', 'my', 'neighbours', 'house', 'with', 'my', 'mom', 'there', 'my', 'aunt', 'told', 'my', 'mom', 'to', 'not', 'allow', 'me', 'to', 'wear', 'these', 'kind', 'of', 'clothes', 'as', 'this', 'will', 'affect', 'their', 'daughters', 'thinking', 'i', 'mean', 'are', 'u', 'guys', 'serious', 'one', 'side', 'you', 'talk', 'about', 'modern', 'india', 'modern', 'society', 'and', 'development', 'and', 'on', 'the', 'other', 'side', 'you', 'are', 'still', 'carrying', 'this', 'orthodox', 'thinking', 'of', 'yours', 'that', 'girls', 'should', 'be', 'covered', 'i', 'want', 'to', 'ask', 'all', 'the', 'girls', 'that', 'don', 't', 'u', 'think', 'babes', 'these', 'guys', 'need', 'to', 'change', 'their', 'thinking', 'and', 'not', 'us', 'to', 'change', 'our', 'dressing', 'style', 'man', 'from', 'passing', 'train', 'squeezed', 'my', 'breasts', 'while', 'train', 'was', 'slowing', 'she', 'does', 'not', 'feels', 'safe', 'during', 'night', 'journeys', 'she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'molesters', 'saw', 'my', 'friend', 'on', 'her', 'vehicle', 'near', 'babari', 'mandi', 'and', 'while', 'they', 'were', 'about', 'to', 'leave', 'they', 'tried', 'to', 'get', 'hold', 'of', 'her', 'pallu', 'while', 'she', 'was', 'on', 'the', 'bike', 'she', 'scolded', 'them', 'but', 'let', 'them', 'go', 'unfortunately', 'okay', 'so', 'this', 'incident', 'happened', 'last', 'year', 'i', 'e', 'when', 'i', 'd', 'finished', 'my', 'classes', 'at', 'vashi', 'and', 'was', 'heading', 'towards', 'the', 'vashi', 'depot', 'to', 'take', 'a', 'bus', 'to', 'my', 'place', 'kharghar', 'navi', 'mumbai', 'so', 'i', 'boarded', 'a', 'numbered', 'bus', 'and', 'took', 'a', 'ladies', 'seat', 'window', 'side', 'i', 'was', 'on', 'a', 'phone', 'call', 'after', 'a', 'few', 'minutes', 'i', 'realised', 'that', 'i', 'was', 'touched', 'near', 'my', 'boobs', 'from', 'behind', 'for', 'an', 'instance', 'i', 'thought', 'it', 'might', 'just', 'be', 'the', 'rod', 'of', 'the', 'seat', 'but',  ...
#
# Set() unique words and digits eng :
#  {'in', 'and', 'amount', 'only', 'company', 'u', 'hesitate', 'screaming', 'even', 'realised', 'window', 'workplace', 'girls', 'some', 'sexual', 'right', 'didn', 'development', 'pedicab', 'walking', 'grabs', 'towards', 'non', 'breasts', 'colour', 'scooty', 'lust', 'sexually', 'style', 'upto', 'fear', 'when', 'bike', 'one', 'posh', 'another', 'up', 'scared', 'happened', 'affect', 'women', 'area', 'don', 'touched', 'them', 'look', 'aunt', 'sat', 'e', 'follows', 'dressing', 'madly', 'get', 'give', 'numbered', 'grab', 'never', 'said', 'carrying', 'forced', 'playing', 'verbal', 'pallu', 'sent', 'harassed', 'dept', 'mandi', 'girl', 'against', 'course', 'vashi', 'sons', 'babari', 'male', 'molesters', 'station', 'instead', 'does', 'had', 'india', 'too', 'go', 'manner', 'respectful', 'allow', 'her', 'thinking', 'need', 'body', 'somebody', 'giving', 'holi', 'money', 'guy', 'feels', 'that', 'bus', 'teach', 'took', 'female', 'thigh', 'd', 'clothes', 'well', 'masked', 'classes', 'a', 'as', 'still', 'react', 'behind', 'official', 'victim', 'celebration', 'orthodox', 'night', 'kept', 'will', 'private', 'old', 'bad', 'lecher', 'second', 'conductor', 'offering', 'similar', 'bar', 'hold', 'asking', 'sure', 'is', 'skirt', 'behave', 't', 'then', 'closed', 'covered', 'cab', 'everyday', 'beer', 'jeans', 'conducted', 'so', 'the', 'thousands', 'who', 'saying', 'speaking', 'years', 'after', 'boys', 'offered', 'place', 'again', 'inappropriate', 'about', 'train', 'time', 'due', 'full', 'society', 'free', 'which', 'happening', 'first', 'incindent', 'caught', 'touch', 'fault', 'andal', 'beside', 'applied', 'why', 'govt', 'tried', 'he', 'croptop', 'ended', 'me', 'minutes', 'tirupati', 'leave', 'seriously', 'disappeared', 'railway', 'not', 'my', 'was', 'want', 'metro', 'sociology', 'shocked', 'sympathy', 'construction', 'myself', 'prostitute', 'iit', 'came', 'us', 'boarded', 'serious', 'queue', 'finished', 'wasn', 'am', 'view', 'depot', 'modern', 'what', 'smoking', 'mine', 'express', 'did', 'couldn', 'take', 'ask', 'year', 'reported', 'last', 'traveling', 'literally', 'yours', 'friends', 'by', 'standing', 'delhi', 'lift', 'are', 'short', 'shirt', 'unsafe', 'kharghar', 'away', 'mumbai', 'it', 'student', 'might', 'heading', 'back', 'talk', 'slapped', 'bikes', 'necessary', 'later', 'showing', 'got', 'there', 'refused', 'intentionally', 'looks', 'survey', 'boobs', 'started', 'th', 'assignment', 'she', 'to', 'for', 'daughters', 'men', 'those', 'you', 'all', 'during', 'hit', 'these', 'i', 's', 'shameful', 'cyclist', 'just', 'hours', 'burning', 'quietly', 'times', 'incident', 'were', 'safe', 'been', 'his', 'wearing', 'on', 'once', 'traffic', 'rod', 'mom', 'gave', 'any', 'casual', 'let', 'we', 'water', 'gurgaon', 'over', 'few', 'decent', 'vehicle', 'guys', 'crowd', 'groping', 'okay', 'ranchi', 'uncovered', 'very', 'went', 'ran', 'stopped', 'poured', 'change', 'felt', 'almost', 'family', 'kind', 'your', 'cigarettes', 'pedestrian', 'near', 'scolded', 'call', 'road', 'noticed', 'point', 'seat', 'they', 'people', 'mean', 'do', 'misery', 'bursted', 'trying', 'employees', 'transgender', 'delay', 'down', 'assaulted', 'matter', 'action', 'contractor', 'pain', 'crowded', 'site', 'of', 'turned', 'our', 'hand', 'their', 'unfortunately', 'navi', 'many', 'mouth', 'angry', 'regular', 'blaming', 'an', 'fortunately', 'at', 'employee', 'auto', 'top', 'expecting', 'while', 'premises', 'way', 'babes', 'blocks', 'faces', 'with', 'someone', 'message', 'should', 'stood', 'wear', 'but', 'bhagalpur', 'neighbours', 'temple', 'phone', 'friend', 'parts', 'traveller', 'other', 'whatever', 'journeys', 'signal', 'be', 'workers', 'ridiculous', 'standard', 'ladies', 'within', 'car', 'office', 'slowing', 'everyone', 'put', 'passing', 'remarks', 'far', 'without', 'most', 'pulled', 'touching', 'from', 'travelling', 'quite', 'instance', 'boy', 'side', 'two', 'has', 'him', 'intentional', 'groped', 'abused', 'thought', 'part', 'squeezed', 'intention', 'think', 'complained', 'staring', 'house', 'out', 'c ...
#
# After nostop filter :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'blocks', 'way', 'grabs', 'expecting', 'quietly', 'give', 'travelling', 'family', 'gurgaon', 'girl', 'boy', 'came', 'bike', 'girl', 'wearing', 'croptop', 'jeans', 'two', 'boys', 'car', 'came', 'behind', 'stopped', 'traffic', 'signal', 'boys', 'smoking', 'cigarettes', 'boys', 'saw', 'girl', 'put', 'burning', 'cigarettes', 'inside', 'jeans', 'girl', 'back', 'side', 'ran', 'away', 'girl', 'screaming', 'pain', 'noticed', 'people', 'standing', 'saying', 'fault', 'girl', 'wearing', 'short', 'clothes', 'body', 'uncovered', 'mean', 'seriously', 'shameful', 'ridiculous', 'instead', 'showing', 'sympathy', 'towards', 'girl', 'everyone', 'standing', 'blaming', 'dressing', 'sense', 'teach', 'sons', 'behave', 'respectful', 'manner', 'one', 'similar', 'incindent', 'happened', 'th', 'standard', 'wearing', 'short', 'top', 'skirt', 'went', 'neighbours', 'house', 'mom', 'aunt', 'told', 'mom', 'allow', 'wear', 'kind', 'clothes', 'affect', 'daughters', 'thinking', 'mean', 'u', 'guys', 'serious', 'one', 'side', 'talk', 'modern', 'india', 'modern', 'society', 'development', 'side', 'still', 'carrying', 'orthodox', 'thinking', 'girls', 'covered', 'want', 'ask', 'girls', 'u', 'think', 'babes', 'guys', 'need', 'change', 'thinking', 'us', 'change', 'dressing', 'style', 'man', 'passing', 'train', 'squeezed', 'breasts', 'train', 'slowing', 'feels', 'safe', 'night', 'journeys', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'tried', 'get', 'hold', 'pallu', 'bike', 'scolded', 'let', 'go', 'unfortunately', 'okay', 'incident', 'happened', 'last', 'year', 'e', 'finished', 'classes', 'vashi', 'heading', 'towards', 'vashi', 'depot', 'take', 'bus', 'place', 'kharghar', 'navi', 'mumbai', 'boarded', 'numbered', 'bus', 'took', 'ladies', 'seat', 'window', 'side', 'phone', 'call', 'minutes', 'realised', 'touched', 'near', 'boobs', 'behind', 'instance', 'thought', 'might', 'rod', 'seat', 'later', 'realised', 'somebody', 'hand', 'trying', 'grab', 'caught', 'hold', 'man', 'hand', 'right', 'turned', 'turned', 'abused', 'asking', 'upto', 'quite', 'shocked', 'sure', 'expecting', 'girl', 'react', 'way', 'men', 'think', 'scared', 'speaking', 'way', 'fear', 'bus', 'conductor', 'came', 'site', 'pulled', 'shirt', 'put', 'bus', 'well', 'later', 'minutes', 'man', 'sat', 'beside', 'started', 'touching', 'thigh', 'bursted', 'even', 'madly', 'minutes', 'back', 'first', 'one', 'happened', 'turned', 'towards', 'without', 'giving', 'second', 'thought', 'literally', 'slapped', 'abused', 'angry', 'angry', 'happening', 'people', 'bus', 'hit', 'even', 'put', 'happened', 'hesitate', 'whatever', 'necessary', 'thought', 'misery', 'ended', 'another', 'lecher', 'staring', 'time', 'complained', 'conductor', 'forced', 'bus', 'intentional', 'inappropriate', 'touching', 'incident', 'happened', 'friend', 'well', 'walking', 'road', 'masked', 'men', 'bikes', 'conducted', 'survey', 'part', 'sociology', 'assignment', 'course', 'offered', 'iit', 'women', 'workers', 'construction', 'site', 'said', 'sexually', 'assaulted', 'crowd', 'thousands', 'tirupati', 'temple', 'male', 'friend', 'harassed', 'queue', 'year', 'old', 'girl', 'playing', 'temple', 'friends', 'time', 'disappeared', 'hours', 'got', 'raped', 'holi', 'celebration', 'male', 'employee', 'applied', 'colour', 'inside', 'female', 'employees', 'mouth', 'poured', 'water', 'within', 'office', 'premises', 'okay', 'reported', 'matter', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'friend', 'mine', 'female', 'sexual', 'harassed', 'workplace', 'old', 'contractor', 'kept', 'giving', 'remarks', 'looks', 'reported', 'time', 'dela ...
#
# Top 20 most used words after non_stop:
#  [('girl', 11), ('bus', 7), ('man', 6), ('happened', 5), ('behind', 4), ('came', 4), ('side', 4), ('one', 4), ('friend', 4), ('touched', 4), ('thought', 4), ('touching', 4), ('time', 4), ('way', 3), ('travelling', 3), ('wearing', 3), ('boys', 3), ('stopped', 3), ('put', 3), ('people', 3)]
#
# After lemmatizer :
#  ['pedicab', 'cyclist', 'follow', 'behind', 'pedestrian', 'block', 'way', 'grab', 'expect', 'quietly', 'give', 'travel', 'family', 'gurgaon', 'girl', 'boy', 'come', 'bike', 'girl', 'wear', 'croptop', 'jeans', 'two', 'boys', 'car', 'come', 'behind', 'stop', 'traffic', 'signal', 'boys', 'smoke', 'cigarettes', 'boys', 'saw', 'girl', 'put', 'burn', 'cigarettes', 'inside', 'jeans', 'girl', 'back', 'side', 'run', 'away', 'girl', 'scream', 'pain', 'notice', 'people', 'stand', 'say', 'fault', 'girl', 'wear', 'short', 'clothe', 'body', 'uncover', 'mean', 'seriously', 'shameful', 'ridiculous', 'instead', 'show', 'sympathy', 'towards', 'girl', 'everyone', 'stand', 'blame', 'dress', 'sense', 'teach', 'sons', 'behave', 'respectful', 'manner', 'one', 'similar', 'incindent', 'happen', 'th', 'standard', 'wear', 'short', 'top', 'skirt', 'go', 'neighbour', 'house', 'mom', 'aunt', 'tell', 'mom', 'allow', 'wear', 'kind', 'clothe', 'affect', 'daughters', 'think', 'mean', 'u', 'guy', 'serious', 'one', 'side', 'talk', 'modern', 'india', 'modern', 'society', 'development', 'side', 'still', 'carry', 'orthodox', 'think', 'girls', 'cover', 'want', 'ask', 'girls', 'u', 'think', 'babes', 'guy', 'need', 'change', 'think', 'us', 'change', 'dress', 'style', 'man', 'pass', 'train', 'squeeze', 'breast', 'train', 'slow', 'feel', 'safe', 'night', 'journey', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'govt', 'official', 'time', 'feel', 'unsafe', 'due', 'overcrowd', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'travel', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'try', 'get', 'hold', 'pallu', 'bike', 'scold', 'let', 'go', 'unfortunately', 'okay', 'incident', 'happen', 'last', 'year', 'e', 'finish', 'class', 'vashi', 'head', 'towards', 'vashi', 'depot', 'take', 'bus', 'place', 'kharghar', 'navi', 'mumbai', 'board', 'number', 'bus', 'take', 'ladies', 'seat', 'window', 'side', 'phone', 'call', 'minutes', 'realise', 'touch', 'near', 'boob', 'behind', 'instance', 'think', 'might', 'rod', 'seat', 'later', 'realise', 'somebody', 'hand', 'try', 'grab', 'catch', 'hold', 'man', 'hand', 'right', 'turn', 'turn', 'abuse', 'ask', 'upto', 'quite', 'shock', 'sure', 'expect', 'girl', 'react', 'way', 'men', 'think', 'scar', 'speak', 'way', 'fear', 'bus', 'conductor', 'come', 'site', 'pull', 'shirt', 'put', 'bus', 'well', 'later', 'minutes', 'man', 'sit', 'beside', 'start', 'touch', 'thigh', 'burst', 'even', 'madly', 'minutes', 'back', 'first', 'one', 'happen', 'turn', 'towards', 'without', 'give', 'second', 'think', 'literally', 'slap', 'abuse', 'angry', 'angry', 'happen', 'people', 'bus', 'hit', 'even', 'put', 'happen', 'hesitate', 'whatever', 'necessary', 'think', 'misery', 'end', 'another', 'lecher', 'star', 'time', 'complain', 'conductor', 'force', 'bus', 'intentional', 'inappropriate', 'touch', 'incident', 'happen', 'friend', 'well', 'walk', 'road', 'mask', 'men', 'bike', 'conduct', 'survey', 'part', 'sociology', 'assignment', 'course', 'offer', 'iit', 'women', 'workers', 'construction', 'site', 'say', 'sexually', 'assault', 'crowd', 'thousands', 'tirupati', 'temple', 'male', 'friend', 'harass', 'queue', 'year', 'old', 'girl', 'play', 'temple', 'friends', 'time', 'disappear', 'hours', 'get', 'rap', 'holi', 'celebration', 'male', 'employee', 'apply', 'colour', 'inside', 'female', 'employees', 'mouth', 'pour', 'water', 'within', 'office', 'premise', 'okay', 'report', 'matter', 'beer', 'bar', 'close', 'two', 'girls', 'hit', 'men', 'refuse', 'go', 'friend', 'mine', 'female', 'sexual', 'harass', 'workplace', 'old', 'contractor', 'keep', 'give', 'remark', 'look', 'report', 'time', 'delay', 'posh', 'dept', 'company', 'offer', 'free', 'cab', 'inappropriate', 'non', 'verbal', 'contact', 'try', 'stop', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time ...
#
# Top 20 most used words after lemmatizer:
#  [('girl', 11), ('touch', 10), ('think', 9), ('bus', 7), ('happen', 6), ('man', 6), ('time', 5), ('try', 5), ('behind', 4), ('give', 4), ('travel', 4), ('come', 4), ('wear', 4), ('side', 4), ('one', 4), ('take', 4), ('friend', 4), ('part', 4), ('way', 3), ('bike', 3)]
#
#  CatcallsWhistles.txt
# HBox(children=(IntProgress(value=0, max=305), HTML(value='')))
# Words and digits eng :
#  ['na', 'sexually', 'assaulting', 'three', 'boys', 'were', 'singing', 'a', 'song', 'as', 'i', 'passed', 'she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'it', 'was', 'during', 'my', 'coaching', 'our', 'classmates', 'used', 'to', 'follow', 'us', 'everywhere', 'we', 'used', 'to', 'go', 'and', 'pass', 'comments', 'on', 'our', 'dressing', 'and', 'our', 'body', 'language', 'it', 'felt', 'very', 'uncomfortable', 'it', 'was', 'around', 'pm', 'i', 'was', 'supposed', 'to', 'receive', 'my', 'female', 'friend', 'and', 'as', 'soon', 'as', 'she', 'came', 'to', 'me', 'a', 'group', 'of', 'grown', 'up', 'men', 'started', 'passing', 'comments', 'i', 'was', 'travelling', 'in', 'the', 'delhi', 'metro', 'and', 'a', 'man', 'was', 'staring', 'at', 'a', 'girl', 'with', 'the', 'intention', 'full', 'of', 'lust', 'after', 'a', 'decent', 'amount', 'of', 'time', 'i', 'couldn', 't', 'take', 'it', 'and', 'i', 'stood', 'in', 'his', 'point', 'of', 'view', 'and', 'gave', 'him', 'a', 'casual', 'look', 'fortunately', 'that', 'sent', 'the', 'message', 'during', 'a', 'party', 'while', 'dancing', 'in', 'college', 'a', 'guy', 'pinched', 'a', 'girl', 'at', 'inappropriate', 'part', 'while', 'coming', 'from', 'classes', 'i', 'saw', 'a', 'group', 'of', 'boys', 'were', 'teasing', 'a', 'girl', 'i', 'witnessed', 'a', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'a', 'man', 'thought', 'i', 'was', 'a', 'prostitute', 'and', 'was', 'offering', 'money', 'for', 'one', 'night', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'few', 'people', 'followed', 'me', 'to', 'my', 'home', 'and', 'also', 'pelted', 'stone', 'at', 'me', 'and', 'comments', 'continuously', 'victim', 'was', 'on', 'hr', 'way', 'to', 'the', 'metro', 'station', 'when', 'a', 'group', 'of', 'boys', 'catcalled', 'and', 'whistled', 'to', 'grab', 'her', 'attention', 'i', 'was', 'walking', 'in', 'the', 'inner', 'circle', 'when', 'a', 'boy', 'used', 'heavy', 'tone', 'to', 'make', 'obscene', 'voices', 'none']
#
# Set() unique words and digits eng :
#  {'delhi', 'coming', 'in', 'inner', 'and', 'are', 'amount', 'unsafe', 'classes', 'a', 'as', 'three', 'it', 'pm', 'student', 'attention', 'official', 'voices', 'taking', 'victim', 'stone', 'obscene', 'group', 'sexual', 'action', 'singing', 'receive', 'college', 'night', 'walking', 'of', 'offering', 'lust', 'our', 'sexually', 'catcalled', 'unfortunately', 'around', 'is', 'many', 'soon', 'regular', 'when', 't', 'none', 'fortunately', 'there', 'at', 'party', 'everyday', 'started', 'so', 'the', 'she', 'witnessed', 'one', 'to', 'for', 'up', 'language', 'while', 'men', 'way', 'years', 'after', 'boys', 'comments', 'inappropriate', 'faces', 'used', 'area', 'everywhere', 'during', 'time', 'with', 'due', 'full', 'message', 'i', 'look', 'stood', 'robbery', 'na', 'but', 'friend', 'dressing', 'pictures', 'times', 'whistled', 'traveller', 'were', 'pelted', 'safe', 'been', 'his', 'pass', 'on', 'grab', 'never', 'supposed', 'govt', 'grown', 'song', 'gave', 'any', 'casual', 'verbal', 'we', 'passing', 'me', 'far', 'sent', 'my', 'passed', 'was', 'girl', 'decent', 'few', 'home', 'metro', 'from', 'travelling', 'circle', 'make', 'station', 'assaulting', 'also', 'boy', 'uncomfortable', 'prostitute', 'followed', 'very', 'came', 'us', 'hr', 'has', 'him', 'go', 'chain', 'thought', 'felt', 'almost', 'part', 'heavy', 'tone', 'view', 'her', 'classmates', 'intention', 'couldn', 'take', 'dancing', 'follow', 'body', 'staring', 'continuously', 'last', 'traveling', 'guy', 'money', 'coaching', 'point', 'feels', 'that', 'man', 'assault', 'overcrowded', 'teasing', 'people', 'pinched', 'saw', 'female'}
#
# After nostop filter :
#  ['na', 'sexually', 'assaulting', 'three', 'boys', 'singing', 'song', 'passed', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'coaching', 'classmates', 'used', 'follow', 'us', 'everywhere', 'used', 'go', 'pass', 'comments', 'dressing', 'body', 'language', 'felt', 'uncomfortable', 'around', 'pm', 'supposed', 'receive', 'female', 'friend', 'soon', 'came', 'group', 'grown', 'men', 'started', 'passing', 'comments', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'party', 'dancing', 'college', 'guy', 'pinched', 'girl', 'inappropriate', 'part', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'witnessed', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'man', 'thought', 'prostitute', 'offering', 'money', 'one', 'night', 'taking', 'pictures', 'taking', 'pictures', 'taking', 'pictures', 'people', 'followed', 'home', 'also', 'pelted', 'stone', 'comments', 'continuously', 'victim', 'hr', 'way', 'metro', 'station', 'group', 'boys', 'catcalled', 'whistled', 'grab', 'attention', 'walking', 'inner', 'circle', 'boy', 'used', 'heavy', 'tone', 'make', 'obscene', 'voices', 'none']
#
# Top 20 most used words after non_stop:
#  [('taking', 4), ('pictures', 4), ('boys', 3), ('used', 3), ('comments', 3), ('group', 3), ('girl', 3), ('never', 2), ('felt', 2), ('assault', 2), ('almost', 2), ('everyday', 2), ('victim', 2), ('take', 2), ('metro', 2), ('man', 2), ('teasing', 2), ('na', 1), ('sexually', 1), ('assaulting', 1)]
#
# After lemmatizer :
#  ['na', 'sexually', 'assault', 'three', 'boys', 'sing', 'song', 'pass', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'govt', 'official', 'time', 'feel', 'unsafe', 'due', 'overcrowd', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'travel', 'unfortunately', 'never', 'take', 'action', 'far', 'coach', 'classmates', 'use', 'follow', 'us', 'everywhere', 'use', 'go', 'pass', 'comment', 'dress', 'body', 'language', 'felt', 'uncomfortable', 'around', 'pm', 'suppose', 'receive', 'female', 'friend', 'soon', 'come', 'group', 'grow', 'men', 'start', 'pass', 'comment', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stand', 'point', 'view', 'give', 'casual', 'look', 'fortunately', 'send', 'message', 'party', 'dance', 'college', 'guy', 'pinch', 'girl', 'inappropriate', 'part', 'come', 'class', 'saw', 'group', 'boys', 'tease', 'girl', 'witness', 'chain', 'robbery', 'take', 'picture', 'verbal', 'tease', 'man', 'think', 'prostitute', 'offer', 'money', 'one', 'night', 'take', 'picture', 'take', 'picture', 'take', 'picture', 'people', 'follow', 'home', 'also', 'pelt', 'stone', 'comment', 'continuously', 'victim', 'hr', 'way', 'metro', 'station', 'group', 'boys', 'catcall', 'whistle', 'grab', 'attention', 'walk', 'inner', 'circle', 'boy', 'use', 'heavy', 'tone', 'make', 'obscene', 'voice', 'none']
#
# Top 20 most used words after lemmatizer:
#  [('take', 6), ('picture', 4), ('assault', 3), ('boys', 3), ('pass', 3), ('use', 3), ('comment', 3), ('group', 3), ('girl', 3), ('never', 2), ('felt', 2), ('almost', 2), ('everyday', 2), ('time', 2), ('victim', 2), ('travel', 2), ('follow', 2), ('come', 2), ('metro', 2), ('man', 2)]
#
#  SexualInvites.txt
# HBox(children=(IntProgress(value=0, max=280), HTML(value='')))
# Words and digits eng :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'sexually', 'assaulting', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'in', 'jaipur', 'my', 'college', 'backpack', 'i', 'worked', 'out', 'and', 'went', 'out', 'for', 'shopping', 'i', 'was', 'pumped', 'up', 'a', 'year', 'old', 'sikh', 'man', 'on', 'a', 'splender', 'bike', 'came', 'to', 'me', 'and', 'directly', 'asked', 'me', 'to', 'have', 'sex', 'with', 'hi', 'at', 'various', 'apps', 'like', 'webchat', 'and', 'all', 'i', 'do', 'showoff', 'little', 'bi', 'and', 'have', 'been', 'approached', 'and', 'asked', 'gay', 'relations', 'until', 'and', 'unless', 'strong', 'punishments', 'live', 'non', 'bailable', 'prison', 'for', 'min', 'years', 'or', 'death', 'punishment', 'rape', 'has', 'happened', 'are', 'happening', 'and', 'will', 'still', 'happen', 'awareness', 'will', 'come', 'when', 'punishments', 'will', 'be', 'in', 'practice', 'i', 'would', 'like', 'to', 'share', 'that', 'about', 'a', 'year', 'ago', 'when', 'i', 'was', 'in', 'manipur', 'there', 'the', 'people', 'were', 'behaving', 'not', 'like', 'normal', 'in', 'the', 'train', 'vellor', 'to', 'bhopal', 'in', 'a', 'beer', 'bar', 'after', 'it', 'closed', 'two', 'girls', 'who', 'were', 'there', 'are', 'hit', 'by', 'some', 'men', 'when', 'she', 'refused', 'to', 'go', 'with', 'them', 'i', 'was', 'travelling', 'in', 'the', 'delhi', 'metro', 'and', 'a', 'man', 'was', 'staring', 'at', 'a', 'girl', 'with', 'the', 'intention', 'full', 'of', 'lust', 'after', 'a', 'decent', 'amount', 'of', 'time', 'i', 'couldn', 't', 'take', 'it', 'and', 'i', 'stood', 'in', 'his', 'point', 'of', 'view', 'and', 'gave', 'him', 'a', 'casual', 'look', 'fortunately', 'that', 'sent', 'the', 'message', 'in', 'bhilwara', 'there', 'is', 'a', 'labour', 'colony', 'where', 'during', 'my', 'visit', 'for', 'apartment', 'hunting', 'some', 'labours', 'bullied', 'my', 'group', 'and', 'showed', 'us', 'knife', 'for', 'just', 'being', 'on', 'the', 'side', 'of', 'the', 'road', 'my', 'project', 'manager', 'has', 'been', 'harassing', 'me', 'repeatedly', 'with', 'sexual', 'invites', 'and', 'immodest', 'talks']
#
# Set() unique words and digits eng :
#  {'showoff', 'delhi', 'being', 'in', 'and', 'are', 'amount', 'project', 'little', 'unsafe', 'a', 'live', 'manager', 'still', 'it', 'until', 'behind', 'official', 'or', 'girls', 'some', 'group', 'sexual', 'harassing', 'pedicab', 'punishment', 'college', 'gay', 'share', 'behaving', 'will', 'grabs', 'old', 'sikh', 'non', 'jaipur', 'punishments', 'of', 'prison', 'invites', 'bar', 'lust', 'sexually', 'is', 'when', 'apps', 't', 'then', 'there', 'refused', 'have', 'fortunately', 'closed', 'visit', 'at', 'beer', 'bike', 'bhopal', 'the', 'she', 'manipur', 'to', 'for', 'who', 'up', 'expecting', 'men', 'way', 'shopping', 'years', 'splender', 'after', 'happened', 'unless', 'blocks', 'min', 'about', 'area', 'all', 'talks', 'labour', 'during', 'hunting', 'backpack', 'train', 'hit', 'time', 'with', 'due', 'them', 'full', 'i', 'message', 'bailable', 'look', 'happening', 'stood', 'bullied', 'webchat', 'cyclist', 'just', 'relations', 'apartment', 'follows', 'quietly', 'times', 'would', 'repeatedly', 'were', 'been', 'his', 'be', 'give', 'on', 'govt', 'gave', 'casual', 'colony', 'me', 'happen', 'worked', 'death', 'sent', 'not', 'my', 'girl', 'was', 'practice', 'decent', 'sex', 'metro', 'various', 'where', 'come', 'rape', 'travelling', 'approached', 'assaulting', 'normal', 'side', 'bi', 'two', 'came', 'us', 'ago', 'has', 'awareness', 'went', 'go', 'him', 'asked', 'hi', 'immodest', 'view', 'her', 'pedestrian', 'intention', 'couldn', 'take', 'bhilwara', 'like', 'labours', 'road', 'pumped', 'staring', 'year', 'out', 'vellor', 'knife', 'point', 'feels', 'that', 'man', 'overcrowded', 'people', 'strong', 'do', 'showed', 'directly', 'by'}
#
# After nostop filter :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'blocks', 'way', 'grabs', 'expecting', 'quietly', 'give', 'sexually', 'assaulting', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'jaipur', 'college', 'backpack', 'worked', 'went', 'shopping', 'pumped', 'year', 'old', 'sikh', 'man', 'splender', 'bike', 'came', 'directly', 'asked', 'sex', 'hi', 'various', 'apps', 'like', 'webchat', 'showoff', 'little', 'bi', 'approached', 'asked', 'gay', 'relations', 'unless', 'strong', 'punishments', 'live', 'non', 'bailable', 'prison', 'min', 'years', 'death', 'punishment', 'rape', 'happened', 'happening', 'still', 'happen', 'awareness', 'come', 'punishments', 'practice', 'would', 'like', 'share', 'year', 'ago', 'manipur', 'people', 'behaving', 'like', 'normal', 'train', 'vellor', 'bhopal', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'bhilwara', 'labour', 'colony', 'visit', 'apartment', 'hunting', 'labours', 'bullied', 'group', 'showed', 'us', 'knife', 'side', 'road', 'project', 'manager', 'harassing', 'repeatedly', 'sexual', 'invites', 'immodest', 'talks']
#
# Top 20 most used words after non_stop:
#  [('like', 3), ('year', 2), ('man', 2), ('asked', 2), ('punishments', 2), ('pedicab', 1), ('cyclist', 1), ('follows', 1), ('behind', 1), ('pedestrian', 1), ('blocks', 1), ('way', 1), ('grabs', 1), ('expecting', 1), ('quietly', 1), ('give', 1), ('sexually', 1), ('assaulting', 1), ('govt', 1), ('official', 1)]
#
# After lemmatizer :
#  ['pedicab', 'cyclist', 'follow', 'behind', 'pedestrian', 'block', 'way', 'grab', 'expect', 'quietly', 'give', 'sexually', 'assault', 'govt', 'official', 'time', 'feel', 'unsafe', 'due', 'overcrowd', 'area', 'jaipur', 'college', 'backpack', 'work', 'go', 'shop', 'pump', 'year', 'old', 'sikh', 'man', 'splender', 'bike', 'come', 'directly', 'ask', 'sex', 'hi', 'various', 'apps', 'like', 'webchat', 'showoff', 'little', 'bi', 'approach', 'ask', 'gay', 'relations', 'unless', 'strong', 'punishments', 'live', 'non', 'bailable', 'prison', 'min', 'years', 'death', 'punishment', 'rape', 'happen', 'happen', 'still', 'happen', 'awareness', 'come', 'punishments', 'practice', 'would', 'like', 'share', 'year', 'ago', 'manipur', 'people', 'behave', 'like', 'normal', 'train', 'vellor', 'bhopal', 'beer', 'bar', 'close', 'two', 'girls', 'hit', 'men', 'refuse', 'go', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stand', 'point', 'view', 'give', 'casual', 'look', 'fortunately', 'send', 'message', 'bhilwara', 'labour', 'colony', 'visit', 'apartment', 'hunt', 'labour', 'bully', 'group', 'show', 'us', 'knife', 'side', 'road', 'project', 'manager', 'harass', 'repeatedly', 'sexual', 'invite', 'immodest', 'talk']
#
# Top 20 most used words after lemmatizer:
#  [('like', 3), ('happen', 3), ('give', 2), ('time', 2), ('go', 2), ('year', 2), ('man', 2), ('come', 2), ('ask', 2), ('punishments', 2), ('labour', 2), ('pedicab', 1), ('cyclist', 1), ('follow', 1), ('behind', 1), ('pedestrian', 1), ('block', 1), ('way', 1), ('grab', 1), ('expect', 1)]
#
#  Stalking.txt
# HBox(children=(IntProgress(value=0, max=759), HTML(value='')))
# Words and digits eng :
#  ['na', 'pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'she', 'works', 'as', 'a', 'field', 'coordinator', 'and', 'around', 'an', 'year', 'back', 'a', 'man', 'followed', 'her', 'and', 'asked', 'her', 'contact', 'details', 'she', 'is', 'student', 'and', 'she', 'doesn', 't', 'feels', 'safe', 'at', 'all', 'at', 'the', 'station', 'and', 'she', 'faces', 'assault', 'almost', 'daily', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'molesters', 'saw', 'my', 'friend', 'on', 'her', 'vehicle', 'near', 'babari', 'mandi', 'and', 'while', 'they', 'were', 'about', 'to', 'leave', 'they', 'tried', 'to', 'get', 'hold', 'of', 'her', 'pallu', 'while', 'she', 'was', 'on', 'the', 'bike', 'she', 'scolded', 'them', 'but', 'let', 'them', 'go', 'unfortunately', 'i', 'was', 'stalked', 'by', 'a', 'man', 'while', 'i', 'was', 'at', 'the', 'cs', 'metro', 'station', 'he', 'followed', 'me', 'till', 'new', 'delhi', 'metro', 'station', 'as', 'soon', 'as', 'i', 'sat', 'in', 'the', 'airport', 'metro', 'the', 'man', 'came', 'and', 'sat', 'on', 'the', 'seat', 'right', 'next', 'to', 'mine', 'i', 'sensed', 'something', 'wrong', 'and', 'rushed', 'to', 'the', 'last', 'compartment', 'of', 'the', 'metro', 'okay', 'so', 'this', 'incident', 'happened', 'last', 'year', 'i', 'e', 'when', 'i', 'd', 'finished', 'my', 'classes', 'at', 'vashi', 'and', 'was', 'heading', 'towards', 'the', 'vashi', 'depot', 'to', 'take', 'a', 'bus', 'to', 'my', 'place', 'kharghar', 'navi', 'mumbai', 'so', 'i', 'boarded', 'a', 'numbered', 'bus', 'and', 'took', 'a', 'ladies', 'seat', 'window', 'side', 'i', 'was', 'on', 'a', 'phone', 'call', 'after', 'a', 'few', 'minutes', 'i', 'realised', 'that', 'i', 'was', 'touched', 'near', 'my', 'boobs', 'from', 'behind', 'for', 'an', 'instance', 'i', 'thought', 'it', 'might', 'just', 'be', 'the', 'rod', 'of', 'the', 'seat', 'but', 'later', 'i', 'realised', 'it', 'wasn', 't', 'it', 'was', 'somebody', 's', 'hand', 'trying', 'to', 'grab', 'me', 'up', 'there', 'i', 'caught', 'hold', 'of', 'the', 'man', 's', 'hand', 'right', 'there', 'turned', 'it', 'turned', 'myself', 'and', 'abused', 'him', 'asking', 'what', 'he', 'was', 'upto', 'he', 'was', 'quite', 'shocked', 'i', 'am', 'sure', 'he', 'wasn', 't', 'expecting', 'a', 'girl', 'to', 'react', 'that', 'way', 'our', 'men', 'think', 'we', 'are', 'scared', 'of', 'speaking', 'out', 'that', 'way', 'but', 'i', 'did', 'i', 'didn', 't', 'fear', 'the', 'bus', 'conductor', 'came', 'to', 'the', 'site', 'and', 'pulled', 'his', 'shirt', 'and', 'put', 'him', 'down', 'the', 'bus', 'well', 'this', 'wasn', 't', 'the', 'only', 'later', 'after', 'minutes', 'a', 'man', 'sat', 'down', 'beside', 'me', 'he', 'started', 'touching', 'my', 'thigh', 'i', 'bursted', 'out', 'on', 'him', 'even', 'madly', 'as', 'it', 'was', 'just', 'minutes', 'back', 'that', 'the', 'first', 'one', 'had', 'happened', 'i', 'turned', 'towards', 'him', 'without', 'giving', 'a', 'second', 'thought', 'i', 'literally', 'slapped', 'him', 'abused', 'him', 'again', 'i', 'was', 'angry', 'angry', 'to', 'what', 'was', 'happening', 'with', 'me', 'the', 'people', 'there', 'in', 'the', 'bus', 'hit', 'him', 'and', 'even', 'he', 'was', 'put', 'down', 'so', 'this', 'happened', 'i', 'didn', 't', 'hesitate', 'to', 'do', 'whatever', 'i', 'did', 'it', 'was', 'necessary', 'i', 'thought', 'my', 'misery', 'ended', 'but', 'there', 'was', 'another', 'lecher', 'who', 'was', 'staring', 'at', 'me', 'for', 'most', 'of', 'the', 'time', 'i', 'complained', 'to', 'the', 'conductor', 'and', 'forced', 'him', 'out', 'of', 'the', 'bus', 'too', 'i', 'was', 'followed', 'and', 'tailed', 'by', 'a', 'partially', 'bald', 'middle', 'aged', 'man', 'wearing', 'an', 'army', 'shirt', 'mi ...
#
# Set() unique words and digits eng :
#  {'delhi', 'thigh', 'in', 'bursted', 'and', 'are', 'shirt', 'amount', 'trying', 'well', 'kirori', 'classes', 'only', 'a', 'kharghar', 'middle', 'down', 'ramjas', 'as', 'mumbai', 'it', 'rushed', 'hesitate', 'react', 'away', 'misery', 'even', 'following', 'behind', 'student', 'realised', 'window', 'might', 'going', 'returning', 'heading', 'victim', 'or', 'job', 'if', 'jogged', 'some', 'back', 'slapped', 'sexual', 'action', 'right', 'didn', 'police', 'pedicab', 'college', 'their', 'neighbour', 'grabs', 'towards', 'works', 'sepoy', 'function', 'old', 'necessary', 'lecher', 'something', 'site', 'of', 'later', 'conductor', 'second', 'seek', 'school', 'drunk', 'turned', 'hold', 'lust', 'our', 'hand', 'till', 'asking', 'sure', 'airport', 'around', 'unfortunately', 'bald', 'next', 'randomly', 'navi', 'is', 'upto', 'many', 'fear', 'angry', 'got', 'soon', 'when', 'an', 't', 'then', 'there', 'fortunately', 'have', 'wrong', 'at', 'everyday', 'boobs', 'started', 'so', 'bike', 'the', 'she', 'ed', 'army', 'one', 'to', 'for', 'who', 'speaking', 'up', 'expecting', 'field', 'while', 'way', 'men', 'another', 'stopping', 'years', 'language', 'after', 'sensed', 'boys', 'scared', 'happened', 'place', 'confirmed', 'blocks', 'again', 'about', 'faces', 'partially', 'used', 'comments', 'you', 'all', 'everywhere', 'area', 'during', 'purposely', 'chance', 'touched', 'time', 'hit', 'barnala', 'with', 'someone', 'them', 'full', 'i', 's', 'message', 'always', 'look', 'happening', 'stood', 'first', 'gone', 'na', 'sly', 'cyclist', 'sat', 'just', 'but', 'hours', 'e', 'tailed', 'temple', 'caught', 'phone', 'follows', 'quietly', 'friend', 'dressing', 'accused', 'madly', 'incident', 'whatever', 'get', 'were', 'attending', 'safe', 'been', 'market', 'his', 'be', 'give', 'beside', 'pass', 'more', 'numbered', 'wearing', 'on', 'details', 'grab', 'created', 'ladies', 'never', 'tried', 'forced', 'playing', 'rod', 'compartment', 'any', 'he', 'daily', 'gave', 'casual', 'let', 'we', 'put', 'ended', 'me', 'minutes', 'leave', 'far', 'pallu', 'disappeared', 'sent', 'close', 'without', 'whole', 'pg', 'most', 'coordinator', 'my', 'mandi', 'was', 'few', 'girl', 'home', 'pulled', 'not', 'touching', 'vehicle', 'decent', 'metro', 'vashi', 'from', 'problem', 'okay', 'shocked', 'babari', 'stalked', 'travelling', 'molesters', 'punjab', 'station', 'quite', 'indecent', 'instance', 'report', 'also', 'uncomfortable', 'side', 'myself', 'had', 'followed', 'very', 'came', 'boarded', 'us', 'has', 'too', 'him', 'go', 'new', 'could', 'asked', 'stopped', 'abused', 'thought', 'felt', 'almost', 'finished', 'wasn', 'aged', 'am', 'part', 'view', 'depot', 'her', 'your', 'commented', 'mine', 'what', 'pedestrian', 'classmates', 'did', 'intention', 'mal', 'survive', 'near', 'scolded', 'call', 'couldn', 'take', 'think', 'complained', 'follow', 'body', 'things', 'somebody', 'staring', 'year', 'giving', 'reported', 'last', 'traveling', 'cs', 'out', 'literally', 'coaching', 'point', 'feels', 'stop', 'contact', 'seat', 'this', 'man', 'they', 'assault', 'that', 'doesn', 'people', 'do', 'bus', 'raped', 'saw', 'took', 'friends', 'by', 'd'}
#
# After nostop filter :
#  ['na', 'pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'blocks', 'way', 'grabs', 'expecting', 'quietly', 'give', 'works', 'field', 'coordinator', 'around', 'year', 'back', 'man', 'followed', 'asked', 'contact', 'details', 'student', 'feels', 'safe', 'station', 'faces', 'assault', 'almost', 'daily', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'tried', 'get', 'hold', 'pallu', 'bike', 'scolded', 'let', 'go', 'unfortunately', 'stalked', 'man', 'cs', 'metro', 'station', 'followed', 'till', 'new', 'delhi', 'metro', 'station', 'soon', 'sat', 'airport', 'metro', 'man', 'came', 'sat', 'seat', 'right', 'next', 'mine', 'sensed', 'something', 'wrong', 'rushed', 'last', 'compartment', 'metro', 'okay', 'incident', 'happened', 'last', 'year', 'e', 'finished', 'classes', 'vashi', 'heading', 'towards', 'vashi', 'depot', 'take', 'bus', 'place', 'kharghar', 'navi', 'mumbai', 'boarded', 'numbered', 'bus', 'took', 'ladies', 'seat', 'window', 'side', 'phone', 'call', 'minutes', 'realised', 'touched', 'near', 'boobs', 'behind', 'instance', 'thought', 'might', 'rod', 'seat', 'later', 'realised', 'somebody', 'hand', 'trying', 'grab', 'caught', 'hold', 'man', 'hand', 'right', 'turned', 'turned', 'abused', 'asking', 'upto', 'quite', 'shocked', 'sure', 'expecting', 'girl', 'react', 'way', 'men', 'think', 'scared', 'speaking', 'way', 'fear', 'bus', 'conductor', 'came', 'site', 'pulled', 'shirt', 'put', 'bus', 'well', 'later', 'minutes', 'man', 'sat', 'beside', 'started', 'touching', 'thigh', 'bursted', 'even', 'madly', 'minutes', 'back', 'first', 'one', 'happened', 'turned', 'towards', 'without', 'giving', 'second', 'thought', 'literally', 'slapped', 'abused', 'angry', 'angry', 'happening', 'people', 'bus', 'hit', 'even', 'put', 'happened', 'hesitate', 'whatever', 'necessary', 'thought', 'misery', 'ended', 'another', 'lecher', 'staring', 'time', 'complained', 'conductor', 'forced', 'bus', 'followed', 'tailed', 'partially', 'bald', 'middle', 'aged', 'man', 'wearing', 'army', 'shirt', 'might', 'police', 'sepoy', 'purposely', 'jogged', 'behind', 'stopped', 'sly', 'part', 'even', 'confirmed', 'ed', 'stopping', 'randomly', 'coaching', 'classmates', 'used', 'follow', 'us', 'everywhere', 'used', 'go', 'pass', 'comments', 'dressing', 'body', 'language', 'felt', 'uncomfortable', 'year', 'old', 'girl', 'playing', 'temple', 'friends', 'time', 'disappeared', 'hours', 'got', 'raped', 'people', 'following', 'way', 'back', 'home', 'returning', 'job', 'place', 'market', 'barnala', 'punjab', 'could', 'report', 'area', 'survive', 'whole', 'area', 'reported', 'might', 'gone', 'away', 'later', 'created', 'problem', 'us', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'neighbour', 'always', 'seek', 'chance', 'get', 'close', 'victim', 'stalked', 'bus', 'stop', 'home', 'accused', 'going', 'school', 'someone', 'commented', 'indecent', 'things', 'victim', 'also', 'stalked', 'later', 'boys', 'drunk', 'following', 'near', 'bus', 'stop', 'kirori', 'mal', 'college', 'returning', 'pg', 'attending', 'function', 'ramjas', 'college']
#
# Top 20 most used words after non_stop:
#  [('bus', 8), ('man', 7), ('metro', 5), ('way', 4), ('later', 4), ('behind', 3), ('year', 3), ('back', 3), ('followed', 3), ('station', 3), ('last', 3), ('victim', 3), ('take', 3), ('near', 3), ('stalked', 3), ('sat', 3), ('seat', 3), ('happened', 3), ('minutes', 3), ('thought', 3)]
#
# After lemmatizer :
#  ['na', 'pedicab', 'cyclist', 'follow', 'behind', 'pedestrian', 'block', 'way', 'grab', 'expect', 'quietly', 'give', 'work', 'field', 'coordinator', 'around', 'year', 'back', 'man', 'follow', 'ask', 'contact', 'detail', 'student', 'feel', 'safe', 'station', 'face', 'assault', 'almost', 'daily', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'travel', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'try', 'get', 'hold', 'pallu', 'bike', 'scold', 'let', 'go', 'unfortunately', 'stalk', 'man', 'cs', 'metro', 'station', 'follow', 'till', 'new', 'delhi', 'metro', 'station', 'soon', 'sit', 'airport', 'metro', 'man', 'come', 'sit', 'seat', 'right', 'next', 'mine', 'sense', 'something', 'wrong', 'rush', 'last', 'compartment', 'metro', 'okay', 'incident', 'happen', 'last', 'year', 'e', 'finish', 'class', 'vashi', 'head', 'towards', 'vashi', 'depot', 'take', 'bus', 'place', 'kharghar', 'navi', 'mumbai', 'board', 'number', 'bus', 'take', 'ladies', 'seat', 'window', 'side', 'phone', 'call', 'minutes', 'realise', 'touch', 'near', 'boob', 'behind', 'instance', 'think', 'might', 'rod', 'seat', 'later', 'realise', 'somebody', 'hand', 'try', 'grab', 'catch', 'hold', 'man', 'hand', 'right', 'turn', 'turn', 'abuse', 'ask', 'upto', 'quite', 'shock', 'sure', 'expect', 'girl', 'react', 'way', 'men', 'think', 'scar', 'speak', 'way', 'fear', 'bus', 'conductor', 'come', 'site', 'pull', 'shirt', 'put', 'bus', 'well', 'later', 'minutes', 'man', 'sit', 'beside', 'start', 'touch', 'thigh', 'burst', 'even', 'madly', 'minutes', 'back', 'first', 'one', 'happen', 'turn', 'towards', 'without', 'give', 'second', 'think', 'literally', 'slap', 'abuse', 'angry', 'angry', 'happen', 'people', 'bus', 'hit', 'even', 'put', 'happen', 'hesitate', 'whatever', 'necessary', 'think', 'misery', 'end', 'another', 'lecher', 'star', 'time', 'complain', 'conductor', 'force', 'bus', 'follow', 'tail', 'partially', 'bald', 'middle', 'age', 'man', 'wear', 'army', 'shirt', 'might', 'police', 'sepoy', 'purposely', 'jog', 'behind', 'stop', 'sly', 'part', 'even', 'confirm', 'ed', 'stop', 'randomly', 'coach', 'classmates', 'use', 'follow', 'us', 'everywhere', 'use', 'go', 'pass', 'comment', 'dress', 'body', 'language', 'felt', 'uncomfortable', 'year', 'old', 'girl', 'play', 'temple', 'friends', 'time', 'disappear', 'hours', 'get', 'rap', 'people', 'follow', 'way', 'back', 'home', 'return', 'job', 'place', 'market', 'barnala', 'punjab', 'could', 'report', 'area', 'survive', 'whole', 'area', 'report', 'might', 'go', 'away', 'later', 'create', 'problem', 'us', 'travel', 'delhi', 'metro', 'man', 'star', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stand', 'point', 'view', 'give', 'casual', 'look', 'fortunately', 'send', 'message', 'neighbour', 'always', 'seek', 'chance', 'get', 'close', 'victim', 'stalk', 'bus', 'stop', 'home', 'accuse', 'go', 'school', 'someone', 'comment', 'indecent', 'things', 'victim', 'also', 'stalk', 'later', 'boys', 'drink', 'follow', 'near', 'bus', 'stop', 'kirori', 'mal', 'college', 'return', 'pg', 'attend', 'function', 'ramjas', 'college']
#
# Top 20 most used words after lemmatizer:
#  [('bus', 8), ('follow', 7), ('man', 7), ('metro', 5), ('way', 4), ('take', 4), ('go', 4), ('happen', 4), ('think', 4), ('later', 4), ('stop', 4), ('behind', 3), ('give', 3), ('year', 3), ('back', 3), ('station', 3), ('last', 3), ('victim', 3), ('near', 3), ('get', 3)]
#
#  Others.txt
# HBox(children=(IntProgress(value=0, max=136), HTML(value='')))
# Words and digits eng :
#  ['i', 'got', 'this', 'issue', 'known', 'from', 'my', 'senior', 'in', 'my', 'college', 'one', 'of', 'the', 'adhoc', 'professors', 'used', 'to', 'ask', 'his', 'girl', 'students', 'why', 'they', 'are', 'not', 'accepting', 'their', 'friend', 'request', 'in', 'fb', 'and', 'sometimes', 'to', 'go', 'out', 'for', 'coffee', 'and', 'asks', 'to', 'come', 'alone', 'in', 'his', 'cabin', 'to', 'discuss', 'things', 'during', 'holi', 'celebration', 'a', 'male', 'employee', 'applied', 'colour', 'inside', 'a', 'female', 'employees', 'mouth', 'and', 'poured', 'water', 'over', 'her', 'within', 'the', 'office', 'premises', 'she', 'was', 'not', 'okay', 'with', 'it', 'and', 'reported', 'the', 'matter', 'i', 'saw', 'a', 'man', 'who', 'does', 'nothing', 'but', 'due', 'to', 'some', 'kind', 'of', 'misunderstanding', 'regarding', 'atm', 'a', 'lot', 'of', 'people', 'hit', 'him', 'he', 'was', 'following', 'me', 'since', 'days', 'i', 'was', 'on', 'a', 'rickshaw', 'with', 'my', 'friend', 'two', 'boys', 'on', 'a', 'bike', 'came', 'near', 'our', 'rickshaw', 'and', 'tried', 'to', 'snatch', 'my', 'phone', 'from', 'my', 'hand']
#
# Set() unique words and digits eng :
# ...
#
# Set() unique words and digits eng :
#  {'coming', 'waiting', 'in', 'and', 'are', 'unsafe', 'classes', 'a', 'it', 'official', 'taking', 'girls', 'group', 'night', 'private', 'bad', 'of', 'offering', 'our', 'is', 'when', 'then', 'there', 'at', 'bike', 'the', 'she', 'one', 'to', 'for', 'language', 'while', 'boys', 'comments', 'used', 'area', 'everywhere', 'during', 'touched', 'due', 'i', 'first', 'bhagalpur', 'picture', 'touch', 'friend', 'dressing', 'pictures', 'parts', 'objectionable', 'times', 'talking', 'were', 'andal', 'pass', 'on', 'young', 'evening', 'govt', 'tried', 'compartment', 'verbal', 'we', 'railway', 'my', 'girl', 'was', 'few', 'from', 'ranchi', 'station', 'uncomfortable', 'prostitute', 'very', 'came', 'us', 'go', 'thought', 'felt', 'her', 'express', 'classmates', 'class', 'follow', 'body', 'staring', 'liftvto', 'money', 'guy', 'coaching', 'feels', 'man', 'overcrowded', 'teasing', 'people', 'inside', 'bus', 'saw'}
#
# After nostop filter :
#  ['govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'coaching', 'classmates', 'used', 'follow', 'us', 'everywhere', 'used', 'go', 'pass', 'comments', 'dressing', 'body', 'language', 'felt', 'uncomfortable', 'waiting', 'bus', 'man', 'came', 'bike', 'offering', 'liftvto', 'young', 'girls', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'taking', 'pictures', 'verbal', 'teasing', 'one', 'evening', 'inside', 'first', 'class', 'compartment', 'guy', 'staring', 'friend', 'tried', 'touch', 'man', 'thought', 'prostitute', 'offering', 'money', 'one', 'night', 'taking', 'pictures', 'taking', 'pictures', 'taking', 'pictures', 'bad', 'people', 'touched', 'private', 'parts', 'ranchi', 'bhagalpur', 'express', 'andal', 'railway', 'station', 'talking', 'objectionable', 'picture', 'friend', 'bus']
#
# Top 20 most used words after non_stop:
#  [('taking', 4), ('pictures', 4), ('used', 2), ('bus', 2), ('man', 2), ('offering', 2), ('teasing', 2), ('one', 2), ('friend', 2), ('govt', 1), ('official', 1), ('times', 1), ('feels', 1), ('unsafe', 1), ('due', 1), ('overcrowded', 1), ('area', 1), ('coaching', 1), ('classmates', 1), ('follow', 1)]
#
# After lemmatizer :
#  ['govt', 'official', 'time', 'feel', 'unsafe', 'due', 'overcrowd', 'area', 'coach', 'classmates', 'use', 'follow', 'us', 'everywhere', 'use', 'go', 'pass', 'comment', 'dress', 'body', 'language', 'felt', 'uncomfortable', 'wait', 'bus', 'man', 'come', 'bike', 'offer', 'liftvto', 'young', 'girls', 'come', 'class', 'saw', 'group', 'boys', 'tease', 'girl', 'take', 'picture', 'verbal', 'tease', 'one', 'even', 'inside', 'first', 'class', 'compartment', 'guy', 'star', 'friend', 'try', 'touch', 'man', 'think', 'prostitute', 'offer', 'money', 'one', 'night', 'take', 'picture', 'take', 'picture', 'take', 'picture', 'bad', 'people', 'touch', 'private', 'part', 'ranchi', 'bhagalpur', 'express', 'andal', 'railway', 'station', 'talk', 'objectionable', 'picture', 'friend', 'bus']
#
# Top 20 most used words after lemmatizer:
#  [('picture', 5), ('take', 4), ('use', 2), ('bus', 2), ('man', 2), ('come', 2), ('offer', 2), ('class', 2), ('tease', 2), ('one', 2), ('friend', 2), ('touch', 2), ('govt', 1), ('official', 1), ('time', 1), ('feel', 1), ('unsafe', 1), ('due', 1), ('overcrowd', 1), ('area', 1)]
#
#  PoorNoStreetLighting.txt
# HBox(children=(IntProgress(value=0, max=163), HTML(value='')))
# Words and digits eng :
#  ['she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'i', 'work', 'in', 'a', 'factory', 'in', 'bengaluru', 'rural', 'area', 'the', 'street', 'which', 'leads', 'to', 'the', 'factory', 'where', 'i', 'work', 'has', 'no', 'street', 'lights', 'at', 'all', 'it', 'becomes', 'extremely', 'difficult', 'for', 'those', 'who', 'have', 'to', 'go', 'to', 'work', 'in', 'the', 'night', 'shift', 'sometimes', 'even', 'robbery', 'also', 'takes', 'place', 'by', 'strangers', 'one', 'day', 'a', 'group', 'of', 'people', 'came', 'onto', 'me', 'and', 'i', 'was', 'mugged', 'they', 'took', 'my', 'phone', 'and', 'wallet', 'in', 'a', 'beer', 'bar', 'after', 'it', 'closed', 'two', 'girls', 'who', 'were', 'there', 'are', 'hit', 'by', 'some', 'men', 'when', 'she', 'refused', 'to', 'go', 'with', 'them', 'i', 'was', 'waiting', 'for', 'the', 'bus', 'a', 'man', 'came', 'on', 'a', 'bike', 'and', 'was', 'offering', 'liftvto', 'young', 'girls', 'while', 'coming', 'from', 'classes', 'i', 'saw', 'a', 'group', 'of', 'boys', 'were', 'teasing', 'a', 'girl', 'i', 'witnessed', 'a', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'a', 'gang', 'of', 'goon', 'looted', 'me', 'outside', 'the', 'raniganj', 'station']
#
# Set() unique words and digits eng :
#  {'coming', 'waiting', 'in', 'and', 'are', 'classes', 'a', 'it', 'even', 'onto', 'student', 'difficult', 'taking', 'lights', 'girls', 'some', 'group', 'night', 'of', 'offering', 'bar', 'gang', 'is', 'regular', 'when', 'refused', 'there', 'have', 'closed', 'at', 'extremely', 'everyday', 'beer', 'bike', 'mugged', 'outside', 'the', 'she', 'witnessed', 'one', 'to', 'for', 'who', 'men', 'while', 'strangers', 'after', 'boys', 'place', 'faces', 'those', 'area', 'all', 'factory', 'hit', 'with', 'them', 'i', 'bengaluru', 'which', 'robbery', 'goon', 'but', 'becomes', 'day', 'phone', 'pictures', 'traveller', 'were', 'safe', 'on', 'never', 'young', 'verbal', 'me', 'sometimes', 'my', 'girl', 'was', 'where', 'from', 'work', 'leads', 'station', 'also', 'street', 'two', 'came', 'takes', 'has', 'go', 'looted', 'chain', 'felt', 'almost', 'shift', 'raniganj', 'wallet', 'liftvto', 'man', 'they', 'assault', 'rural', 'teasing', 'people', 'no', 'bus', 'saw', 'took', 'by'}
#
# After nostop filter :
#  ['student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'work', 'factory', 'bengaluru', 'rural', 'area', 'street', 'leads', 'factory', 'work', 'street', 'lights', 'becomes', 'extremely', 'difficult', 'go', 'work', 'night', 'shift', 'sometimes', 'even', 'robbery', 'also', 'takes', 'place', 'strangers', 'one', 'day', 'group', 'people', 'came', 'onto', 'mugged', 'took', 'phone', 'wallet', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'waiting', 'bus', 'man', 'came', 'bike', 'offering', 'liftvto', 'young', 'girls', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'witnessed', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'gang', 'goon', 'looted', 'outside', 'raniganj', 'station']
#
# Top 20 most used words after non_stop:
#  [('work', 3), ('factory', 2), ('street', 2), ('go', 2), ('robbery', 2), ('group', 2), ('came', 2), ('girls', 2), ('teasing', 2), ('student', 1), ('regular', 1), ('traveller', 1), ('never', 1), ('felt', 1), ('safe', 1), ('faces', 1), ('assault', 1), ('almost', 1), ('everyday', 1), ('bengaluru', 1)]
#
# After lemmatizer :
#  ['student', 'regular', 'traveller', 'never', 'felt', 'safe', 'face', 'assault', 'almost', 'everyday', 'work', 'factory', 'bengaluru', 'rural', 'area', 'street', 'lead', 'factory', 'work', 'street', 'light', 'become', 'extremely', 'difficult', 'go', 'work', 'night', 'shift', 'sometimes', 'even', 'robbery', 'also', 'take', 'place', 'strangers', 'one', 'day', 'group', 'people', 'come', 'onto', 'mug', 'take', 'phone', 'wallet', 'beer', 'bar', 'close', 'two', 'girls', 'hit', 'men', 'refuse', 'go', 'wait', 'bus', 'man', 'come', 'bike', 'offer', 'liftvto', 'young', 'girls', 'come', 'class', 'saw', 'group', 'boys', 'tease', 'girl', 'witness', 'chain', 'robbery', 'take', 'picture', 'verbal', 'tease', 'gang', 'goon', 'loot', 'outside', 'raniganj', 'station']
#
# Top 20 most used words after lemmatizer:
#  [('work', 3), ('take', 3), ('come', 3), ('factory', 2), ('street', 2), ('go', 2), ('robbery', 2), ('group', 2), ('girls', 2), ('tease', 2), ('student', 1), ('regular', 1), ('traveller', 1), ('never', 1), ('felt', 1), ('safe', 1), ('face', 1), ('assault', 1), ('almost', 1), ('everyday', 1)]
#
#  OnlineHarassment.txt
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Words and digits eng :
#  []
#
# Set() unique words and digits eng :
#  set()
#
# After nostop filter :
#  []
#
# Top 20 most used words after non_stop:
#  []
#
# After lemmatizer :
#  []
#
# Top 20 most used words after lemmatizer:
#  []
#
# corpus: 14
# Top_20 after Term Frequency–Inverse Document Frequency
#
#  TouchingGroping
# touch 0.31755098302308
# think 0.15719758588887306
# happen 0.15494851224137815
# behind 0.127020393209232
# wear 0.127020393209232
# bus 0.12226478902467905
# minutes 0.12034035573132204
# private 0.12034035573132204
# put 0.12034035573132204
# turn 0.12034035573132204
# change 0.10880430356130333
# cigarettes 0.10880430356130333
# clothe 0.10880430356130333
# grope 0.10880430356130333
# jeans 0.10880430356130333
# manner 0.10880430356130333
# mean 0.10880430356130333
# modern 0.10880430356130333
# mom 0.10880430356130333
# short 0.10880430356130333
#
#  CatcallsWhistles
# picture 0.21878938141077772
# circle 0.17036444550628224
# heavy 0.17036444550628224
# inner 0.17036444550628224
# sing 0.17036444550628224
# song 0.17036444550628224
# three 0.17036444550628224
# tone 0.17036444550628224
# voice 0.17036444550628224
# pass 0.16409203605808328
# comment 0.16409203605808328
# group 0.16409203605808328
# use 0.16409203605808328
# victim 0.13293424066398904
# tease 0.13293424066398904
# boy 0.12561830310718794
# attention 0.12561830310718794
# catcall 0.12561830310718794
# dance 0.12561830310718794
# grow 0.12561830310718794
#
#  SexualInvites
# like 0.3409606471504083
# labour 0.2273070981002722
# punishments 0.2273070981002722
# happen 0.16185433627033763
# ago 0.1136535490501361
# apartment 0.1136535490501361
# approach 0.1136535490501361
# apps 0.1136535490501361
# awareness 0.1136535490501361
# backpack 0.1136535490501361
# bailable 0.1136535490501361
# bhilwara 0.1136535490501361
# bhopal 0.1136535490501361
# bi 0.1136535490501361
# bully 0.1136535490501361
# colony 0.1136535490501361
# death 0.1136535490501361
# directly 0.1136535490501361
# gay 0.1136535490501361
# hi 0.1136535490501361
#
#  Stalking
# bus 0.18678877856779588
# later 0.16979734111322076
# stop 0.16979734111322076
# might 0.16086765215833462
# minutes 0.16086765215833462
# seat 0.16086765215833462
# turn 0.16086765215833462
# stalk 0.16086765215833462
# happen 0.13808725104845665
# back 0.1273480058349156
# behind 0.1273480058349156
# sit 0.1273480058349156
# way 0.11349099432227182
# abuse 0.10724510143888974
# angry 0.10724510143888974
# conductor 0.10724510143888974
# put 0.10724510143888974
# realise 0.10724510143888974
# right 0.10724510143888974
# shirt 0.10724510143888974
#
#  Others
# rickshaw 0.34860200402328506
# accept 0.17430100201164253
# adhoc 0.17430100201164253
# alone 0.17430100201164253
# atm 0.17430100201164253
# cabin 0.17430100201164253
# coffee 0.17430100201164253
# days 0.17430100201164253
# discuss 0.17430100201164253
# fb 0.17430100201164253
# issue 0.17430100201164253
# know 0.17430100201164253
# misunderstand 0.17430100201164253
# nothing 0.17430100201164253
# professors 0.17430100201164253
# regard 0.17430100201164253
# request 0.17430100201164253
# senior 0.17430100201164253
# students 0.17430100201164253
# ask 0.13600590945213215
#
#  Commenting
# comment 0.2947336352685598
# victim 0.22384651251082754
# indecent 0.2009421604001944
# pass 0.1473668176342799
# back 0.13396144026679627
# sit 0.13396144026679627
# someone 0.13396144026679627
# make 0.13396144026679627
# badly 0.114749929865896
# counter 0.114749929865896
# goons 0.114749929865896
# omments 0.114749929865896
# rude 0.114749929865896
# ticket 0.114749929865896
# unbearable 0.114749929865896
# weird 0.114749929865896
# word 0.114749929865896
# also 0.11052511322570992
# group 0.11052511322570992
# picture 0.11052511322570992
#
#  RapeSexualAssault
# rap 0.4202112563829673
# dump 0.35994844563310635
# minor 0.35994844563310635
# tribal 0.35994844563310635
# picture 0.34669600892576313
# disappear 0.21010562819148365
# friends 0.21010562819148365
# hours 0.21010562819148365
# play 0.21010562819148365
# temple 0.21010562819148365
# old 0.17086786186731454
# get 0.14043268581135865
# year 0.14043268581135865
# take 0.0986783119746515
# sexually 0.07632756998441859
# men 0.060262810749860875
# assault 0.045892393928462734
# time 0.045892393928462734
# girl 0.04205008885138354
#
#  NorthEastIndiaReport
# assignment 0.2886216586490629
# conduct 0.2886216586490629
# construction 0.2886216586490629
# course 0.2886216586490629
# iit 0.2886216586490629
# sociology 0.2886216586490629
# survey 0.2886216586490629
# women 0.2886216586490629
# workers 0.2886216586490629
# say 0.22848218505450205
# site 0.22848218505450205
# bar 0.15271540883240448
# beer 0.15271540883240448
# refuse 0.15271540883240448
# close 0.10280910916583445
# girls 0.10280910916583445
# offer 0.10280910916583445
# part 0.10280910916583445
# two 0.10280910916583445
# hit 0.08300344031739398
#
#  Indecentexposure
# tie 0.41732438153277573
# ac 0.20866219076638787
# bag 0.20866219076638787
# bellandur 0.20866219076638787
# bmtc 0.20866219076638787
# escape 0.20866219076638787
# hide 0.20866219076638787
# innocent 0.20866219076638787
# masturbate 0.20866219076638787
# petrol 0.20866219076638787
# plastic 0.20866219076638787
# pretend 0.20866219076638787
# privates 0.20866219076638787
# start 0.16281771588187005
# scream 0.15385716338175393
# pump 0.15385716338175393
# age 0.15385716338175393
# middle 0.15385716338175393
# rush 0.15385716338175393
# lot 0.15385716338175393
#
#  ChainSnatching
# snatch 0.6079322100303567
# chain 0.45661278546692663
# road 0.16041956144582561
# two 0.14436654832485113
# biker 0.1374136720862722
# bikers 0.1374136720862722
# flee 0.1374136720862722
# gold 0.1374136720862722
# helmet 0.1374136720862722
# injure 0.1374136720862722
# morning 0.1374136720862722
# motorbike 0.1374136720862722
# rider 0.1374136720862722
# thus 0.1374136720862722
# today 0.1374136720862722
# woman 0.1374136720862722
# aunt 0.10132203500505944
# police 0.10132203500505944
# cross 0.10132203500505944
# gang 0.10132203500505944
#
#  OglingFacialExpressionsStaring
# every 0.30667133699007604
# comment 0.24615036281881025
# pass 0.1969202902550482
# crowd 0.17900722919720208
# sometimes 0.17900722919720208
# andheri 0.15333566849503802
# bridge 0.15333566849503802
# cheap 0.15333566849503802
# chest 0.15333566849503802
# connect 0.15333566849503802
# multiple 0.15333566849503802
# past 0.15333566849503802
# person 0.15333566849503802
# railways 0.15333566849503802
# reason 0.15333566849503802
# almost 0.14769021769128615
# victim 0.11964679952743647
# dance 0.11306212646019904
# grow 0.11306212646019904
# party 0.11306212646019904
#
#  Takingpictures
# picture 0.38335754170439906
# touch 0.2787880161804549
# objectionable 0.23880681814443555
# tease 0.18633936758971947
# andal 0.17608431839508795
# bad 0.17608431839508795
# bhagalpur 0.17608431839508795
# express 0.17608431839508795
# private 0.17608431839508795
# railway 0.17608431839508795
# ranchi 0.17608431839508795
# compartment 0.17608431839508795
# bus 0.15334301668175965
# class 0.15334301668175965
# use 0.15334301668175965
# first 0.13939400809022745
# talk 0.13939400809022745
# liftvto 0.13939400809022745
# wait 0.13939400809022745
# young 0.13939400809022745
#
#  PoorNoStreetLighting
# factory 0.3473921020289489
# street 0.3473921020289489
# work 0.2473610308229332
# become 0.17369605101447444
# bengaluru 0.17369605101447444
# difficult 0.17369605101447444
# extremely 0.17369605101447444
# lead 0.17369605101447444
# light 0.17369605101447444
# mug 0.17369605101447444
# onto 0.17369605101447444
# rural 0.17369605101447444
# shift 0.17369605101447444
# strangers 0.17369605101447444
# wallet 0.17369605101447444
# robbery 0.16490735388195546
# tease 0.13553387022347457
# gang 0.1280748639777261
# goon 0.1280748639777261
# loot 0.1280748639777261
#
#  OnlineHarassment

# %%
#Without lemmatization nor stemming
top20_and_allTokens_list = [top20_and_allTokens(fileNames[i]+'.txt', stemming=False, lemmatization=False, plot=False) for i in range(len(fileNames))]
categories_allTokens = [top20_and_allTokens_list[i] for i in range(len(top20_and_allTokens_list))]
corpus, dictionary, tfidf = top20_tf_idf(categories_allTokens)
# Out:
#  TouchingGroping.txt
# HBox(children=(IntProgress(value=0, max=1079), HTML(value='')))
# Words and digits eng :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'i', 'was', 'travelling', 'with', 'my', 'family', 'and', 'we', 'were', 'in', 'gurgaon', 'a', 'girl', 'with', 'a', 'boy', 'came', 'on', 'bike', 'and', 'the', 'girl', 'was', 'wearing', 'croptop', 'and', 'jeans', 'two', 'boys', 'in', 'a', 'car', 'came', 'behind', 'them', 'and', 'we', 'all', 'stopped', 'on', 'traffic', 'signal', 'and', 'those', 'boys', 'were', 'smoking', 'cigarettes', 'when', 'the', 'boys', 'saw', 'the', 'girl', 'they', 'put', 'their', 'burning', 'cigarettes', 'inside', 'the', 'jeans', 'of', 'the', 'girl', 'from', 'back', 'side', 'and', 'ran', 'away', 'and', 'the', 'girl', 'was', 'screaming', 'of', 'pain', 'i', 'noticed', 'the', 'people', 'standing', 'over', 'there', 'saying', 'that', 'it', 'was', 'the', 'fault', 'of', 'the', 'girl', 'as', 'she', 'was', 'wearing', 'short', 'clothes', 'and', 'her', 'body', 'was', 'uncovered', 'i', 'mean', 'this', 'was', 'seriously', 'so', 'shameful', 'and', 'ridiculous', 'instead', 'of', 'showing', 'sympathy', 'towards', 'that', 'girl', 'everyone', 'standing', 'there', 'was', 'blaming', 'her', 'and', 'her', 'dressing', 'sense', 'why', 'don', 't', 'you', 'teach', 'your', 'sons', 'to', 'behave', 'in', 'respectful', 'manner', 'one', 'similar', 'incindent', 'happened', 'with', 'me', 'when', 'i', 'was', 'in', 'th', 'standard', 'i', 'was', 'wearing', 'short', 'top', 'and', 'skirt', 'and', 'went', 'to', 'my', 'neighbours', 'house', 'with', 'my', 'mom', 'there', 'my', 'aunt', 'told', 'my', 'mom', 'to', 'not', 'allow', 'me', 'to', 'wear', 'these', 'kind', 'of', 'clothes', 'as', 'this', 'will', 'affect', 'their', 'daughters', 'thinking', 'i', 'mean', 'are', 'u', 'guys', 'serious', 'one', 'side', 'you', 'talk', 'about', 'modern', 'india', 'modern', 'society', 'and', 'development', 'and', 'on', 'the', 'other', 'side', 'you', 'are', 'still', 'carrying', 'this', 'orthodox', 'thinking', 'of', 'yours', 'that', 'girls', 'should', 'be', 'covered', 'i', 'want', 'to', 'ask', 'all', 'the', 'girls', 'that', 'don', 't', 'u', 'think', 'babes', 'these', 'guys', 'need', 'to', 'change', 'their', 'thinking', 'and', 'not', 'us', 'to', 'change', 'our', 'dressing', 'style', 'man', 'from', 'passing', 'train', 'squeezed', 'my', 'breasts', 'while', 'train', 'was', 'slowing', 'she', 'does', 'not', 'feels', 'safe', 'during', 'night', 'journeys', 'she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'molesters', 'saw', 'my', 'friend', 'on', 'her', 'vehicle', 'near', 'babari', 'mandi', 'and', 'while', 'they', 'were', 'about', 'to', 'leave', 'they', 'tried', 'to', 'get', 'hold', 'of', 'her', 'pallu', 'while', 'she', 'was', 'on', 'the', 'bike', 'she', 'scolded', 'them', 'but', 'let', 'them', 'go', 'unfortunately', 'okay', 'so', 'this', 'incident', 'happened', 'last', 'year', 'i', 'e', 'when', 'i', 'd', 'finished', 'my', 'classes', 'at', 'vashi', 'and', 'was', 'heading', 'towards', 'the', 'vashi', 'depot', 'to', 'take', 'a', 'bus', 'to', 'my', 'place', 'kharghar', 'navi', 'mumbai', 'so', 'i', 'boarded', 'a', 'numbered', 'bus', 'and', 'took', 'a', 'ladies', 'seat', 'window', 'side', 'i', 'was', 'on', 'a', 'phone', 'call', 'after', 'a', 'few', 'minutes', 'i', 'realised', 'that', 'i', 'was', 'touched', 'near', 'my', 'boobs', 'from', 'behind', 'for', 'an', 'instance', 'i', 'thought', 'it', 'might', 'just', 'be', 'the', 'rod', 'of', 'the', 'seat', 'but',  ...
#
# Set() unique words and digits eng :
#  {'in', 'and', 'amount', 'only', 'company', 'u', 'hesitate', 'screaming', 'even', 'realised', 'window', 'workplace', 'girls', 'some', 'sexual', 'right', 'didn', 'development', 'pedicab', 'walking', 'grabs', 'towards', 'non', 'breasts', 'colour', 'scooty', 'lust', 'sexually', 'style', 'upto', 'fear', 'when', 'bike', 'one', 'posh', 'another', 'up', 'scared', 'happened', 'affect', 'women', 'area', 'don', 'touched', 'them', 'look', 'aunt', 'sat', 'e', 'follows', 'dressing', 'madly', 'get', 'give', 'numbered', 'grab', 'never', 'said', 'carrying', 'forced', 'playing', 'verbal', 'pallu', 'sent', 'harassed', 'dept', 'mandi', 'girl', 'against', 'course', 'vashi', 'sons', 'babari', 'male', 'molesters', 'station', 'instead', 'does', 'had', 'india', 'too', 'go', 'manner', 'respectful', 'allow', 'her', 'thinking', 'need', 'body', 'somebody', 'giving', 'holi', 'money', 'guy', 'feels', 'that', 'bus', 'teach', 'took', 'female', 'thigh', 'd', 'clothes', 'well', 'masked', 'classes', 'a', 'as', 'still', 'react', 'behind', 'official', 'victim', 'celebration', 'orthodox', 'night', 'kept', 'will', 'private', 'old', 'bad', 'lecher', 'second', 'conductor', 'offering', 'similar', 'bar', 'hold', 'asking', 'sure', 'is', 'skirt', 'behave', 't', 'then', 'closed', 'covered', 'cab', 'everyday', 'beer', 'jeans', 'conducted', 'so', 'the', 'thousands', 'who', 'saying', 'speaking', 'years', 'after', 'boys', 'offered', 'place', 'again', 'inappropriate', 'about', 'train', 'time', 'due', 'full', 'society', 'free', 'which', 'happening', 'first', 'incindent', 'caught', 'touch', 'fault', 'andal', 'beside', 'applied', 'why', 'govt', 'tried', 'he', 'croptop', 'ended', 'me', 'minutes', 'tirupati', 'leave', 'seriously', 'disappeared', 'railway', 'not', 'my', 'was', 'want', 'metro', 'sociology', 'shocked', 'sympathy', 'construction', 'myself', 'prostitute', 'iit', 'came', 'us', 'boarded', 'serious', 'queue', 'finished', 'wasn', 'am', 'view', 'depot', 'modern', 'what', 'smoking', 'mine', 'express', 'did', 'couldn', 'take', 'ask', 'year', 'reported', 'last', 'traveling', 'literally', 'yours', 'friends', 'by', 'standing', 'delhi', 'lift', 'are', 'short', 'shirt', 'unsafe', 'kharghar', 'away', 'mumbai', 'it', 'student', 'might', 'heading', 'back', 'talk', 'slapped', 'bikes', 'necessary', 'later', 'showing', 'got', 'there', 'refused', 'intentionally', 'looks', 'survey', 'boobs', 'started', 'th', 'assignment', 'she', 'to', 'for', 'daughters', 'men', 'those', 'you', 'all', 'during', 'hit', 'these', 'i', 's', 'shameful', 'cyclist', 'just', 'hours', 'burning', 'quietly', 'times', 'incident', 'were', 'safe', 'been', 'his', 'wearing', 'on', 'once', 'traffic', 'rod', 'mom', 'gave', 'any', 'casual', 'let', 'we', 'water', 'gurgaon', 'over', 'few', 'decent', 'vehicle', 'guys', 'crowd', 'groping', 'okay', 'ranchi', 'uncovered', 'very', 'went', 'ran', 'stopped', 'poured', 'change', 'felt', 'almost', 'family', 'kind', 'your', 'cigarettes', 'pedestrian', 'near', 'scolded', 'call', 'road', 'noticed', 'point', 'seat', 'they', 'people', 'mean', 'do', 'misery', 'bursted', 'trying', 'employees', 'transgender', 'delay', 'down', 'assaulted', 'matter', 'action', 'contractor', 'pain', 'crowded', 'site', 'of', 'turned', 'our', 'hand', 'their', 'unfortunately', 'navi', 'many', 'mouth', 'angry', 'regular', 'blaming', 'an', 'fortunately', 'at', 'employee', 'auto', 'top', 'expecting', 'while', 'premises', 'way', 'babes', 'blocks', 'faces', 'with', 'someone', 'message', 'should', 'stood', 'wear', 'but', 'bhagalpur', 'neighbours', 'temple', 'phone', 'friend', 'parts', 'traveller', 'other', 'whatever', 'journeys', 'signal', 'be', 'workers', 'ridiculous', 'standard', 'ladies', 'within', 'car', 'office', 'slowing', 'everyone', 'put', 'passing', 'remarks', 'far', 'without', 'most', 'pulled', 'touching', 'from', 'travelling', 'quite', 'instance', 'boy', 'side', 'two', 'has', 'him', 'intentional', 'groped', 'abused', 'thought', 'part', 'squeezed', 'intention', 'think', 'complained', 'staring', 'house', 'out', 'c ...
#
# After nostop filter :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'blocks', 'way', 'grabs', 'expecting', 'quietly', 'give', 'travelling', 'family', 'gurgaon', 'girl', 'boy', 'came', 'bike', 'girl', 'wearing', 'croptop', 'jeans', 'two', 'boys', 'car', 'came', 'behind', 'stopped', 'traffic', 'signal', 'boys', 'smoking', 'cigarettes', 'boys', 'saw', 'girl', 'put', 'burning', 'cigarettes', 'inside', 'jeans', 'girl', 'back', 'side', 'ran', 'away', 'girl', 'screaming', 'pain', 'noticed', 'people', 'standing', 'saying', 'fault', 'girl', 'wearing', 'short', 'clothes', 'body', 'uncovered', 'mean', 'seriously', 'shameful', 'ridiculous', 'instead', 'showing', 'sympathy', 'towards', 'girl', 'everyone', 'standing', 'blaming', 'dressing', 'sense', 'teach', 'sons', 'behave', 'respectful', 'manner', 'one', 'similar', 'incindent', 'happened', 'th', 'standard', 'wearing', 'short', 'top', 'skirt', 'went', 'neighbours', 'house', 'mom', 'aunt', 'told', 'mom', 'allow', 'wear', 'kind', 'clothes', 'affect', 'daughters', 'thinking', 'mean', 'u', 'guys', 'serious', 'one', 'side', 'talk', 'modern', 'india', 'modern', 'society', 'development', 'side', 'still', 'carrying', 'orthodox', 'thinking', 'girls', 'covered', 'want', 'ask', 'girls', 'u', 'think', 'babes', 'guys', 'need', 'change', 'thinking', 'us', 'change', 'dressing', 'style', 'man', 'passing', 'train', 'squeezed', 'breasts', 'train', 'slowing', 'feels', 'safe', 'night', 'journeys', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'tried', 'get', 'hold', 'pallu', 'bike', 'scolded', 'let', 'go', 'unfortunately', 'okay', 'incident', 'happened', 'last', 'year', 'e', 'finished', 'classes', 'vashi', 'heading', 'towards', 'vashi', 'depot', 'take', 'bus', 'place', 'kharghar', 'navi', 'mumbai', 'boarded', 'numbered', 'bus', 'took', 'ladies', 'seat', 'window', 'side', 'phone', 'call', 'minutes', 'realised', 'touched', 'near', 'boobs', 'behind', 'instance', 'thought', 'might', 'rod', 'seat', 'later', 'realised', 'somebody', 'hand', 'trying', 'grab', 'caught', 'hold', 'man', 'hand', 'right', 'turned', 'turned', 'abused', 'asking', 'upto', 'quite', 'shocked', 'sure', 'expecting', 'girl', 'react', 'way', 'men', 'think', 'scared', 'speaking', 'way', 'fear', 'bus', 'conductor', 'came', 'site', 'pulled', 'shirt', 'put', 'bus', 'well', 'later', 'minutes', 'man', 'sat', 'beside', 'started', 'touching', 'thigh', 'bursted', 'even', 'madly', 'minutes', 'back', 'first', 'one', 'happened', 'turned', 'towards', 'without', 'giving', 'second', 'thought', 'literally', 'slapped', 'abused', 'angry', 'angry', 'happening', 'people', 'bus', 'hit', 'even', 'put', 'happened', 'hesitate', 'whatever', 'necessary', 'thought', 'misery', 'ended', 'another', 'lecher', 'staring', 'time', 'complained', 'conductor', 'forced', 'bus', 'intentional', 'inappropriate', 'touching', 'incident', 'happened', 'friend', 'well', 'walking', 'road', 'masked', 'men', 'bikes', 'conducted', 'survey', 'part', 'sociology', 'assignment', 'course', 'offered', 'iit', 'women', 'workers', 'construction', 'site', 'said', 'sexually', 'assaulted', 'crowd', 'thousands', 'tirupati', 'temple', 'male', 'friend', 'harassed', 'queue', 'year', 'old', 'girl', 'playing', 'temple', 'friends', 'time', 'disappeared', 'hours', 'got', 'raped', 'holi', 'celebration', 'male', 'employee', 'applied', 'colour', 'inside', 'female', 'employees', 'mouth', 'poured', 'water', 'within', 'office', 'premises', 'okay', 'reported', 'matter', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'friend', 'mine', 'female', 'sexual', 'harassed', 'workplace', 'old', 'contractor', 'kept', 'giving', 'remarks', 'looks', 'reported', 'time', 'dela ...
#
# Top 20 most used words after non_stop:
#  [('girl', 11), ('bus', 7), ('man', 6), ('happened', 5), ('behind', 4), ('came', 4), ('side', 4), ('one', 4), ('friend', 4), ('touched', 4), ('thought', 4), ('touching', 4), ('time', 4), ('way', 3), ('travelling', 3), ('wearing', 3), ('boys', 3), ('stopped', 3), ('put', 3), ('people', 3)]
#
#  CatcallsWhistles.txt
# HBox(children=(IntProgress(value=0, max=305), HTML(value='')))
# Words and digits eng :
#  ['na', 'sexually', 'assaulting', 'three', 'boys', 'were', 'singing', 'a', 'song', 'as', 'i', 'passed', 'she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'it', 'was', 'during', 'my', 'coaching', 'our', 'classmates', 'used', 'to', 'follow', 'us', 'everywhere', 'we', 'used', 'to', 'go', 'and', 'pass', 'comments', 'on', 'our', 'dressing', 'and', 'our', 'body', 'language', 'it', 'felt', 'very', 'uncomfortable', 'it', 'was', 'around', 'pm', 'i', 'was', 'supposed', 'to', 'receive', 'my', 'female', 'friend', 'and', 'as', 'soon', 'as', 'she', 'came', 'to', 'me', 'a', 'group', 'of', 'grown', 'up', 'men', 'started', 'passing', 'comments', 'i', 'was', 'travelling', 'in', 'the', 'delhi', 'metro', 'and', 'a', 'man', 'was', 'staring', 'at', 'a', 'girl', 'with', 'the', 'intention', 'full', 'of', 'lust', 'after', 'a', 'decent', 'amount', 'of', 'time', 'i', 'couldn', 't', 'take', 'it', 'and', 'i', 'stood', 'in', 'his', 'point', 'of', 'view', 'and', 'gave', 'him', 'a', 'casual', 'look', 'fortunately', 'that', 'sent', 'the', 'message', 'during', 'a', 'party', 'while', 'dancing', 'in', 'college', 'a', 'guy', 'pinched', 'a', 'girl', 'at', 'inappropriate', 'part', 'while', 'coming', 'from', 'classes', 'i', 'saw', 'a', 'group', 'of', 'boys', 'were', 'teasing', 'a', 'girl', 'i', 'witnessed', 'a', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'a', 'man', 'thought', 'i', 'was', 'a', 'prostitute', 'and', 'was', 'offering', 'money', 'for', 'one', 'night', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'few', 'people', 'followed', 'me', 'to', 'my', 'home', 'and', 'also', 'pelted', 'stone', 'at', 'me', 'and', 'comments', 'continuously', 'victim', 'was', 'on', 'hr', 'way', 'to', 'the', 'metro', 'station', 'when', 'a', 'group', 'of', 'boys', 'catcalled', 'and', 'whistled', 'to', 'grab', 'her', 'attention', 'i', 'was', 'walking', 'in', 'the', 'inner', 'circle', 'when', 'a', 'boy', 'used', 'heavy', 'tone', 'to', 'make', 'obscene', 'voices', 'none']
#
# Set() unique words and digits eng :
#  {'delhi', 'coming', 'in', 'inner', 'and', 'are', 'amount', 'unsafe', 'classes', 'a', 'as', 'three', 'it', 'pm', 'student', 'attention', 'official', 'voices', 'taking', 'victim', 'stone', 'obscene', 'group', 'sexual', 'action', 'singing', 'receive', 'college', 'night', 'walking', 'of', 'offering', 'lust', 'our', 'sexually', 'catcalled', 'unfortunately', 'around', 'is', 'many', 'soon', 'regular', 'when', 't', 'none', 'fortunately', 'there', 'at', 'party', 'everyday', 'started', 'so', 'the', 'she', 'witnessed', 'one', 'to', 'for', 'up', 'language', 'while', 'men', 'way', 'years', 'after', 'boys', 'comments', 'inappropriate', 'faces', 'used', 'area', 'everywhere', 'during', 'time', 'with', 'due', 'full', 'message', 'i', 'look', 'stood', 'robbery', 'na', 'but', 'friend', 'dressing', 'pictures', 'times', 'whistled', 'traveller', 'were', 'pelted', 'safe', 'been', 'his', 'pass', 'on', 'grab', 'never', 'supposed', 'govt', 'grown', 'song', 'gave', 'any', 'casual', 'verbal', 'we', 'passing', 'me', 'far', 'sent', 'my', 'passed', 'was', 'girl', 'decent', 'few', 'home', 'metro', 'from', 'travelling', 'circle', 'make', 'station', 'assaulting', 'also', 'boy', 'uncomfortable', 'prostitute', 'followed', 'very', 'came', 'us', 'hr', 'has', 'him', 'go', 'chain', 'thought', 'felt', 'almost', 'part', 'heavy', 'tone', 'view', 'her', 'classmates', 'intention', 'couldn', 'take', 'dancing', 'follow', 'body', 'staring', 'continuously', 'last', 'traveling', 'guy', 'money', 'coaching', 'point', 'feels', 'that', 'man', 'assault', 'overcrowded', 'teasing', 'people', 'pinched', 'saw', 'female'}
#
# After nostop filter :
#  ['na', 'sexually', 'assaulting', 'three', 'boys', 'singing', 'song', 'passed', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'coaching', 'classmates', 'used', 'follow', 'us', 'everywhere', 'used', 'go', 'pass', 'comments', 'dressing', 'body', 'language', 'felt', 'uncomfortable', 'around', 'pm', 'supposed', 'receive', 'female', 'friend', 'soon', 'came', 'group', 'grown', 'men', 'started', 'passing', 'comments', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'party', 'dancing', 'college', 'guy', 'pinched', 'girl', 'inappropriate', 'part', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'witnessed', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'man', 'thought', 'prostitute', 'offering', 'money', 'one', 'night', 'taking', 'pictures', 'taking', 'pictures', 'taking', 'pictures', 'people', 'followed', 'home', 'also', 'pelted', 'stone', 'comments', 'continuously', 'victim', 'hr', 'way', 'metro', 'station', 'group', 'boys', 'catcalled', 'whistled', 'grab', 'attention', 'walking', 'inner', 'circle', 'boy', 'used', 'heavy', 'tone', 'make', 'obscene', 'voices', 'none']
#
# Top 20 most used words after non_stop:
#  [('taking', 4), ('pictures', 4), ('boys', 3), ('used', 3), ('comments', 3), ('group', 3), ('girl', 3), ('never', 2), ('felt', 2), ('assault', 2), ('almost', 2), ('everyday', 2), ('victim', 2), ('take', 2), ('metro', 2), ('man', 2), ('teasing', 2), ('na', 1), ('sexually', 1), ('assaulting', 1)]
#
#  SexualInvites.txt
# HBox(children=(IntProgress(value=0, max=280), HTML(value='')))
# Words and digits eng :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'sexually', 'assaulting', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'in', 'jaipur', 'my', 'college', 'backpack', 'i', 'worked', 'out', 'and', 'went', 'out', 'for', 'shopping', 'i', 'was', 'pumped', 'up', 'a', 'year', 'old', 'sikh', 'man', 'on', 'a', 'splender', 'bike', 'came', 'to', 'me', 'and', 'directly', 'asked', 'me', 'to', 'have', 'sex', 'with', 'hi', 'at', 'various', 'apps', 'like', 'webchat', 'and', 'all', 'i', 'do', 'showoff', 'little', 'bi', 'and', 'have', 'been', 'approached', 'and', 'asked', 'gay', 'relations', 'until', 'and', 'unless', 'strong', 'punishments', 'live', 'non', 'bailable', 'prison', 'for', 'min', 'years', 'or', 'death', 'punishment', 'rape', 'has', 'happened', 'are', 'happening', 'and', 'will', 'still', 'happen', 'awareness', 'will', 'come', 'when', 'punishments', 'will', 'be', 'in', 'practice', 'i', 'would', 'like', 'to', 'share', 'that', 'about', 'a', 'year', 'ago', 'when', 'i', 'was', 'in', 'manipur', 'there', 'the', 'people', 'were', 'behaving', 'not', 'like', 'normal', 'in', 'the', 'train', 'vellor', 'to', 'bhopal', 'in', 'a', 'beer', 'bar', 'after', 'it', 'closed', 'two', 'girls', 'who', 'were', 'there', 'are', 'hit', 'by', 'some', 'men', 'when', 'she', 'refused', 'to', 'go', 'with', 'them', 'i', 'was', 'travelling', 'in', 'the', 'delhi', 'metro', 'and', 'a', 'man', 'was', 'staring', 'at', 'a', 'girl', 'with', 'the', 'intention', 'full', 'of', 'lust', 'after', 'a', 'decent', 'amount', 'of', 'time', 'i', 'couldn', 't', 'take', 'it', 'and', 'i', 'stood', 'in', 'his', 'point', 'of', 'view', 'and', 'gave', 'him', 'a', 'casual', 'look', 'fortunately', 'that', 'sent', 'the', 'message', 'in', 'bhilwara', 'there', 'is', 'a', 'labour', 'colony', 'where', 'during', 'my', 'visit', 'for', 'apartment', 'hunting', 'some', 'labours', 'bullied', 'my', 'group', 'and', 'showed', 'us', 'knife', 'for', 'just', 'being', 'on', 'the', 'side', 'of', 'the', 'road', 'my', 'project', 'manager', 'has', 'been', 'harassing', 'me', 'repeatedly', 'with', 'sexual', 'invites', 'and', 'immodest', 'talks']
#
# Set() unique words and digits eng :
#  {'showoff', 'delhi', 'being', 'in', 'and', 'are', 'amount', 'project', 'little', 'unsafe', 'a', 'live', 'manager', 'still', 'it', 'until', 'behind', 'official', 'or', 'girls', 'some', 'group', 'sexual', 'harassing', 'pedicab', 'punishment', 'college', 'gay', 'share', 'behaving', 'will', 'grabs', 'old', 'sikh', 'non', 'jaipur', 'punishments', 'of', 'prison', 'invites', 'bar', 'lust', 'sexually', 'is', 'when', 'apps', 't', 'then', 'there', 'refused', 'have', 'fortunately', 'closed', 'visit', 'at', 'beer', 'bike', 'bhopal', 'the', 'she', 'manipur', 'to', 'for', 'who', 'up', 'expecting', 'men', 'way', 'shopping', 'years', 'splender', 'after', 'happened', 'unless', 'blocks', 'min', 'about', 'area', 'all', 'talks', 'labour', 'during', 'hunting', 'backpack', 'train', 'hit', 'time', 'with', 'due', 'them', 'full', 'i', 'message', 'bailable', 'look', 'happening', 'stood', 'bullied', 'webchat', 'cyclist', 'just', 'relations', 'apartment', 'follows', 'quietly', 'times', 'would', 'repeatedly', 'were', 'been', 'his', 'be', 'give', 'on', 'govt', 'gave', 'casual', 'colony', 'me', 'happen', 'worked', 'death', 'sent', 'not', 'my', 'girl', 'was', 'practice', 'decent', 'sex', 'metro', 'various', 'where', 'come', 'rape', 'travelling', 'approached', 'assaulting', 'normal', 'side', 'bi', 'two', 'came', 'us', 'ago', 'has', 'awareness', 'went', 'go', 'him', 'asked', 'hi', 'immodest', 'view', 'her', 'pedestrian', 'intention', 'couldn', 'take', 'bhilwara', 'like', 'labours', 'road', 'pumped', 'staring', 'year', 'out', 'vellor', 'knife', 'point', 'feels', 'that', 'man', 'overcrowded', 'people', 'strong', 'do', 'showed', 'directly', 'by'}
#
# After nostop filter :
#  ['pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'blocks', 'way', 'grabs', 'expecting', 'quietly', 'give', 'sexually', 'assaulting', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'jaipur', 'college', 'backpack', 'worked', 'went', 'shopping', 'pumped', 'year', 'old', 'sikh', 'man', 'splender', 'bike', 'came', 'directly', 'asked', 'sex', 'hi', 'various', 'apps', 'like', 'webchat', 'showoff', 'little', 'bi', 'approached', 'asked', 'gay', 'relations', 'unless', 'strong', 'punishments', 'live', 'non', 'bailable', 'prison', 'min', 'years', 'death', 'punishment', 'rape', 'happened', 'happening', 'still', 'happen', 'awareness', 'come', 'punishments', 'practice', 'would', 'like', 'share', 'year', 'ago', 'manipur', 'people', 'behaving', 'like', 'normal', 'train', 'vellor', 'bhopal', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'bhilwara', 'labour', 'colony', 'visit', 'apartment', 'hunting', 'labours', 'bullied', 'group', 'showed', 'us', 'knife', 'side', 'road', 'project', 'manager', 'harassing', 'repeatedly', 'sexual', 'invites', 'immodest', 'talks']
#
# Top 20 most used words after non_stop:
#  [('like', 3), ('year', 2), ('man', 2), ('asked', 2), ('punishments', 2), ('pedicab', 1), ('cyclist', 1), ('follows', 1), ('behind', 1), ('pedestrian', 1), ('blocks', 1), ('way', 1), ('grabs', 1), ('expecting', 1), ('quietly', 1), ('give', 1), ('sexually', 1), ('assaulting', 1), ('govt', 1), ('official', 1)]
#
#  Stalking.txt
# HBox(children=(IntProgress(value=0, max=759), HTML(value='')))
# Words and digits eng :
#  ['na', 'pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'and', 'then', 'blocks', 'her', 'way', 'and', 'grabs', 'her', 'expecting', 'her', 'to', 'just', 'quietly', 'give', 'in', 'she', 'works', 'as', 'a', 'field', 'coordinator', 'and', 'around', 'an', 'year', 'back', 'a', 'man', 'followed', 'her', 'and', 'asked', 'her', 'contact', 'details', 'she', 'is', 'student', 'and', 'she', 'doesn', 't', 'feels', 'safe', 'at', 'all', 'at', 'the', 'station', 'and', 'she', 'faces', 'assault', 'almost', 'daily', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'molesters', 'saw', 'my', 'friend', 'on', 'her', 'vehicle', 'near', 'babari', 'mandi', 'and', 'while', 'they', 'were', 'about', 'to', 'leave', 'they', 'tried', 'to', 'get', 'hold', 'of', 'her', 'pallu', 'while', 'she', 'was', 'on', 'the', 'bike', 'she', 'scolded', 'them', 'but', 'let', 'them', 'go', 'unfortunately', 'i', 'was', 'stalked', 'by', 'a', 'man', 'while', 'i', 'was', 'at', 'the', 'cs', 'metro', 'station', 'he', 'followed', 'me', 'till', 'new', 'delhi', 'metro', 'station', 'as', 'soon', 'as', 'i', 'sat', 'in', 'the', 'airport', 'metro', 'the', 'man', 'came', 'and', 'sat', 'on', 'the', 'seat', 'right', 'next', 'to', 'mine', 'i', 'sensed', 'something', 'wrong', 'and', 'rushed', 'to', 'the', 'last', 'compartment', 'of', 'the', 'metro', 'okay', 'so', 'this', 'incident', 'happened', 'last', 'year', 'i', 'e', 'when', 'i', 'd', 'finished', 'my', 'classes', 'at', 'vashi', 'and', 'was', 'heading', 'towards', 'the', 'vashi', 'depot', 'to', 'take', 'a', 'bus', 'to', 'my', 'place', 'kharghar', 'navi', 'mumbai', 'so', 'i', 'boarded', 'a', 'numbered', 'bus', 'and', 'took', 'a', 'ladies', 'seat', 'window', 'side', 'i', 'was', 'on', 'a', 'phone', 'call', 'after', 'a', 'few', 'minutes', 'i', 'realised', 'that', 'i', 'was', 'touched', 'near', 'my', 'boobs', 'from', 'behind', 'for', 'an', 'instance', 'i', 'thought', 'it', 'might', 'just', 'be', 'the', 'rod', 'of', 'the', 'seat', 'but', 'later', 'i', 'realised', 'it', 'wasn', 't', 'it', 'was', 'somebody', 's', 'hand', 'trying', 'to', 'grab', 'me', 'up', 'there', 'i', 'caught', 'hold', 'of', 'the', 'man', 's', 'hand', 'right', 'there', 'turned', 'it', 'turned', 'myself', 'and', 'abused', 'him', 'asking', 'what', 'he', 'was', 'upto', 'he', 'was', 'quite', 'shocked', 'i', 'am', 'sure', 'he', 'wasn', 't', 'expecting', 'a', 'girl', 'to', 'react', 'that', 'way', 'our', 'men', 'think', 'we', 'are', 'scared', 'of', 'speaking', 'out', 'that', 'way', 'but', 'i', 'did', 'i', 'didn', 't', 'fear', 'the', 'bus', 'conductor', 'came', 'to', 'the', 'site', 'and', 'pulled', 'his', 'shirt', 'and', 'put', 'him', 'down', 'the', 'bus', 'well', 'this', 'wasn', 't', 'the', 'only', 'later', 'after', 'minutes', 'a', 'man', 'sat', 'down', 'beside', 'me', 'he', 'started', 'touching', 'my', 'thigh', 'i', 'bursted', 'out', 'on', 'him', 'even', 'madly', 'as', 'it', 'was', 'just', 'minutes', 'back', 'that', 'the', 'first', 'one', 'had', 'happened', 'i', 'turned', 'towards', 'him', 'without', 'giving', 'a', 'second', 'thought', 'i', 'literally', 'slapped', 'him', 'abused', 'him', 'again', 'i', 'was', 'angry', 'angry', 'to', 'what', 'was', 'happening', 'with', 'me', 'the', 'people', 'there', 'in', 'the', 'bus', 'hit', 'him', 'and', 'even', 'he', 'was', 'put', 'down', 'so', 'this', 'happened', 'i', 'didn', 't', 'hesitate', 'to', 'do', 'whatever', 'i', 'did', 'it', 'was', 'necessary', 'i', 'thought', 'my', 'misery', 'ended', 'but', 'there', 'was', 'another', 'lecher', 'who', 'was', 'staring', 'at', 'me', 'for', 'most', 'of', 'the', 'time', 'i', 'complained', 'to', 'the', 'conductor', 'and', 'forced', 'him', 'out', 'of', 'the', 'bus', 'too', 'i', 'was', 'followed', 'and', 'tailed', 'by', 'a', 'partially', 'bald', 'middle', 'aged', 'man', 'wearing', 'an', 'army', 'shirt', 'mi ...
#
# Set() unique words and digits eng :
#  {'delhi', 'thigh', 'in', 'bursted', 'and', 'are', 'shirt', 'amount', 'trying', 'well', 'kirori', 'classes', 'only', 'a', 'kharghar', 'middle', 'down', 'ramjas', 'as', 'mumbai', 'it', 'rushed', 'hesitate', 'react', 'away', 'misery', 'even', 'following', 'behind', 'student', 'realised', 'window', 'might', 'going', 'returning', 'heading', 'victim', 'or', 'job', 'if', 'jogged', 'some', 'back', 'slapped', 'sexual', 'action', 'right', 'didn', 'police', 'pedicab', 'college', 'their', 'neighbour', 'grabs', 'towards', 'works', 'sepoy', 'function', 'old', 'necessary', 'lecher', 'something', 'site', 'of', 'later', 'conductor', 'second', 'seek', 'school', 'drunk', 'turned', 'hold', 'lust', 'our', 'hand', 'till', 'asking', 'sure', 'airport', 'around', 'unfortunately', 'bald', 'next', 'randomly', 'navi', 'is', 'upto', 'many', 'fear', 'angry', 'got', 'soon', 'when', 'an', 't', 'then', 'there', 'fortunately', 'have', 'wrong', 'at', 'everyday', 'boobs', 'started', 'so', 'bike', 'the', 'she', 'ed', 'army', 'one', 'to', 'for', 'who', 'speaking', 'up', 'expecting', 'field', 'while', 'way', 'men', 'another', 'stopping', 'years', 'language', 'after', 'sensed', 'boys', 'scared', 'happened', 'place', 'confirmed', 'blocks', 'again', 'about', 'faces', 'partially', 'used', 'comments', 'you', 'all', 'everywhere', 'area', 'during', 'purposely', 'chance', 'touched', 'time', 'hit', 'barnala', 'with', 'someone', 'them', 'full', 'i', 's', 'message', 'always', 'look', 'happening', 'stood', 'first', 'gone', 'na', 'sly', 'cyclist', 'sat', 'just', 'but', 'hours', 'e', 'tailed', 'temple', 'caught', 'phone', 'follows', 'quietly', 'friend', 'dressing', 'accused', 'madly', 'incident', 'whatever', 'get', 'were', 'attending', 'safe', 'been', 'market', 'his', 'be', 'give', 'beside', 'pass', 'more', 'numbered', 'wearing', 'on', 'details', 'grab', 'created', 'ladies', 'never', 'tried', 'forced', 'playing', 'rod', 'compartment', 'any', 'he', 'daily', 'gave', 'casual', 'let', 'we', 'put', 'ended', 'me', 'minutes', 'leave', 'far', 'pallu', 'disappeared', 'sent', 'close', 'without', 'whole', 'pg', 'most', 'coordinator', 'my', 'mandi', 'was', 'few', 'girl', 'home', 'pulled', 'not', 'touching', 'vehicle', 'decent', 'metro', 'vashi', 'from', 'problem', 'okay', 'shocked', 'babari', 'stalked', 'travelling', 'molesters', 'punjab', 'station', 'quite', 'indecent', 'instance', 'report', 'also', 'uncomfortable', 'side', 'myself', 'had', 'followed', 'very', 'came', 'boarded', 'us', 'has', 'too', 'him', 'go', 'new', 'could', 'asked', 'stopped', 'abused', 'thought', 'felt', 'almost', 'finished', 'wasn', 'aged', 'am', 'part', 'view', 'depot', 'her', 'your', 'commented', 'mine', 'what', 'pedestrian', 'classmates', 'did', 'intention', 'mal', 'survive', 'near', 'scolded', 'call', 'couldn', 'take', 'think', 'complained', 'follow', 'body', 'things', 'somebody', 'staring', 'year', 'giving', 'reported', 'last', 'traveling', 'cs', 'out', 'literally', 'coaching', 'point', 'feels', 'stop', 'contact', 'seat', 'this', 'man', 'they', 'assault', 'that', 'doesn', 'people', 'do', 'bus', 'raped', 'saw', 'took', 'friends', 'by', 'd'}
#
# After nostop filter :
#  ['na', 'pedicab', 'cyclist', 'follows', 'behind', 'pedestrian', 'blocks', 'way', 'grabs', 'expecting', 'quietly', 'give', 'works', 'field', 'coordinator', 'around', 'year', 'back', 'man', 'followed', 'asked', 'contact', 'details', 'student', 'feels', 'safe', 'station', 'faces', 'assault', 'almost', 'daily', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'tried', 'get', 'hold', 'pallu', 'bike', 'scolded', 'let', 'go', 'unfortunately', 'stalked', 'man', 'cs', 'metro', 'station', 'followed', 'till', 'new', 'delhi', 'metro', 'station', 'soon', 'sat', 'airport', 'metro', 'man', 'came', 'sat', 'seat', 'right', 'next', 'mine', 'sensed', 'something', 'wrong', 'rushed', 'last', 'compartment', 'metro', 'okay', 'incident', 'happened', 'last', 'year', 'e', 'finished', 'classes', 'vashi', 'heading', 'towards', 'vashi', 'depot', 'take', 'bus', 'place', 'kharghar', 'navi', 'mumbai', 'boarded', 'numbered', 'bus', 'took', 'ladies', 'seat', 'window', 'side', 'phone', 'call', 'minutes', 'realised', 'touched', 'near', 'boobs', 'behind', 'instance', 'thought', 'might', 'rod', 'seat', 'later', 'realised', 'somebody', 'hand', 'trying', 'grab', 'caught', 'hold', 'man', 'hand', 'right', 'turned', 'turned', 'abused', 'asking', 'upto', 'quite', 'shocked', 'sure', 'expecting', 'girl', 'react', 'way', 'men', 'think', 'scared', 'speaking', 'way', 'fear', 'bus', 'conductor', 'came', 'site', 'pulled', 'shirt', 'put', 'bus', 'well', 'later', 'minutes', 'man', 'sat', 'beside', 'started', 'touching', 'thigh', 'bursted', 'even', 'madly', 'minutes', 'back', 'first', 'one', 'happened', 'turned', 'towards', 'without', 'giving', 'second', 'thought', 'literally', 'slapped', 'abused', 'angry', 'angry', 'happening', 'people', 'bus', 'hit', 'even', 'put', 'happened', 'hesitate', 'whatever', 'necessary', 'thought', 'misery', 'ended', 'another', 'lecher', 'staring', 'time', 'complained', 'conductor', 'forced', 'bus', 'followed', 'tailed', 'partially', 'bald', 'middle', 'aged', 'man', 'wearing', 'army', 'shirt', 'might', 'police', 'sepoy', 'purposely', 'jogged', 'behind', 'stopped', 'sly', 'part', 'even', 'confirmed', 'ed', 'stopping', 'randomly', 'coaching', 'classmates', 'used', 'follow', 'us', 'everywhere', 'used', 'go', 'pass', 'comments', 'dressing', 'body', 'language', 'felt', 'uncomfortable', 'year', 'old', 'girl', 'playing', 'temple', 'friends', 'time', 'disappeared', 'hours', 'got', 'raped', 'people', 'following', 'way', 'back', 'home', 'returning', 'job', 'place', 'market', 'barnala', 'punjab', 'could', 'report', 'area', 'survive', 'whole', 'area', 'reported', 'might', 'gone', 'away', 'later', 'created', 'problem', 'us', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'neighbour', 'always', 'seek', 'chance', 'get', 'close', 'victim', 'stalked', 'bus', 'stop', 'home', 'accused', 'going', 'school', 'someone', 'commented', 'indecent', 'things', 'victim', 'also', 'stalked', 'later', 'boys', 'drunk', 'following', 'near', 'bus', 'stop', 'kirori', 'mal', 'college', 'returning', 'pg', 'attending', 'function', 'ramjas', 'college']
#
# Top 20 most used words after non_stop:
#  [('bus', 8), ('man', 7), ('metro', 5), ('way', 4), ('later', 4), ('behind', 3), ('year', 3), ('back', 3), ('followed', 3), ('station', 3), ('last', 3), ('victim', 3), ('take', 3), ('near', 3), ('stalked', 3), ('sat', 3), ('seat', 3), ('happened', 3), ('minutes', 3), ('thought', 3)]
#
#  Others.txt
# HBox(children=(IntProgress(value=0, max=136), HTML(value='')))
# Words and digits eng :
#  ['i', 'got', 'this', 'issue', 'known', 'from', 'my', 'senior', 'in', 'my', 'college', 'one', 'of', 'the', 'adhoc', 'professors', 'used', 'to', 'ask', 'his', 'girl', 'students', 'why', 'they', 'are', 'not', 'accepting', 'their', 'friend', 'request', 'in', 'fb', 'and', 'sometimes', 'to', 'go', 'out', 'for', 'coffee', 'and', 'asks', 'to', 'come', 'alone', 'in', 'his', 'cabin', 'to', 'discuss', 'things', 'during', 'holi', 'celebration', 'a', 'male', 'employee', 'applied', 'colour', 'inside', 'a', 'female', 'employees', 'mouth', 'and', 'poured', 'water', 'over', 'her', 'within', 'the', 'office', 'premises', 'she', 'was', 'not', 'okay', 'with', 'it', 'and', 'reported', 'the', 'matter', 'i', 'saw', 'a', 'man', 'who', 'does', 'nothing', 'but', 'due', 'to', 'some', 'kind', 'of', 'misunderstanding', 'regarding', 'atm', 'a', 'lot', 'of', 'people', 'hit', 'him', 'he', 'was', 'following', 'me', 'since', 'days', 'i', 'was', 'on', 'a', 'rickshaw', 'with', 'my', 'friend', 'two', 'boys', 'on', 'a', 'bike', 'came', 'near', 'our', 'rickshaw', 'and', 'tried', 'to', 'snatch', 'my', 'phone', 'from', 'my', 'hand']
#
# Set() unique words and digits eng :
#  {'in', 'are', 'and', 'employees', 'a', 'it', 'following', 'matter', 'celebration', 'some', 'college', 'coffee', 'students', 'of', 'colour', 'our', 'hand', 'their', 'alone', 'got', 'mouth', 'days', 'employee', 'bike', 'the', 'she', 'one', 'to', 'for', 'since', 'who', 'premises', 'boys', 'used', 'during', 'snatch', 'hit', 'with', 'cabin', 'due', 'i', 'but', 'misunderstanding', 'phone', 'friend', 'adhoc', 'accepting', 'issue', 'his', 'fb', 'regarding', 'applied', 'on', 'office', 'why', 'within', 'request', 'tried', 'he', 'me', 'water', 'over', 'not', 'my', 'girl', 'sometimes', 'was', 'senior', 'from', 'come', 'okay', 'male', 'does', 'two', 'nothing', 'came', 'known', 'him', 'go', 'poured', 'lot', 'kind', 'her', 'asks', 'near', 'professors', 'atm', 'ask', 'things', 'reported', 'holi', 'rickshaw', 'out', 'this', 'man', 'they', 'people', 'discuss', 'inside', 'saw', 'female'}
#
# After nostop filter :
#  ['got', 'issue', 'known', 'senior', 'college', 'one', 'adhoc', 'professors', 'used', 'ask', 'girl', 'students', 'accepting', 'friend', 'request', 'fb', 'sometimes', 'go', 'coffee', 'asks', 'come', 'alone', 'cabin', 'discuss', 'things', 'holi', 'celebration', 'male', 'employee', 'applied', 'colour', 'inside', 'female', 'employees', 'mouth', 'poured', 'water', 'within', 'office', 'premises', 'okay', 'reported', 'matter', 'saw', 'man', 'nothing', 'due', 'kind', 'misunderstanding', 'regarding', 'atm', 'lot', 'people', 'hit', 'following', 'since', 'days', 'rickshaw', 'friend', 'two', 'boys', 'bike', 'came', 'near', 'rickshaw', 'tried', 'snatch', 'phone', 'hand']
#
# Top 20 most used words after non_stop:
#  [('friend', 2), ('rickshaw', 2), ('got', 1), ('issue', 1), ('known', 1), ('senior', 1), ('college', 1), ('one', 1), ('adhoc', 1), ('professors', 1), ('used', 1), ('ask', 1), ('girl', 1), ('students', 1), ('accepting', 1), ('request', 1), ('fb', 1), ('sometimes', 1), ('go', 1), ('coffee', 1)]
#
#  Commenting.txt
# HBox(children=(IntProgress(value=0, max=497), HTML(value='')))
# Words and digits eng :
#  ['sexually', 'assaulting', 'we', 'were', 'going', 'back', 'to', 'our', 'place', 'after', 'visiting', 'our', 'friend', 'so', 'as', 'we', 'were', 'going', 'to', 'the', 'ticket', 'counter', 'on', 'the', 'way', 'there', 'were', 'some', 'goons', 'kind', 'of', 'people', 'sitting', 'on', 'their', 'bikes', 'passed', 'comments', 'at', 'us', 'she', 'does', 'not', 'feels', 'safe', 'during', 'night', 'journeys', 'she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'she', 'works', 'as', 'a', 'field', 'coordinator', 'and', 'around', 'an', 'year', 'back', 'a', 'man', 'followed', 'her', 'and', 'asked', 'her', 'contact', 'details', 'she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'she', 'is', 'and', 'from', 'last', 'so', 'many', 'years', 'almost', 'everyday', 'she', 'has', 'been', 'a', 'victim', 'of', 'sexual', 'assault', 'while', 'traveling', 'unfortunately', 'she', 'never', 'couldn', 't', 'take', 'any', 'action', 'so', 'far', 'molesters', 'saw', 'my', 'friend', 'on', 'her', 'vehicle', 'near', 'babari', 'mandi', 'and', 'while', 'they', 'were', 'about', 'to', 'leave', 'they', 'tried', 'to', 'get', 'hold', 'of', 'her', 'pallu', 'while', 'she', 'was', 'on', 'the', 'bike', 'she', 'scolded', 'them', 'but', 'let', 'them', 'go', 'unfortunately', 'it', 'was', 'during', 'my', 'coaching', 'our', 'classmates', 'used', 'to', 'follow', 'us', 'everywhere', 'we', 'used', 'to', 'go', 'and', 'pass', 'comments', 'on', 'our', 'dressing', 'and', 'our', 'body', 'language', 'it', 'felt', 'very', 'uncomfortable', 'during', 'holi', 'celebration', 'a', 'male', 'employee', 'applied', 'colour', 'inside', 'a', 'female', 'employees', 'mouth', 'and', 'poured', 'water', 'over', 'her', 'within', 'the', 'office', 'premises', 'she', 'was', 'not', 'okay', 'with', 'it', 'and', 'reported', 'the', 'matter', 'i', 'was', 'travelling', 'in', 'the', 'delhi', 'metro', 'and', 'a', 'man', 'was', 'staring', 'at', 'a', 'girl', 'with', 'the', 'intention', 'full', 'of', 'lust', 'after', 'a', 'decent', 'amount', 'of', 'time', 'i', 'couldn', 't', 'take', 'it', 'and', 'i', 'stood', 'in', 'his', 'point', 'of', 'view', 'and', 'gave', 'him', 'a', 'casual', 'look', 'fortunately', 'that', 'sent', 'the', 'message', 'my', 'neighbour', 'always', 'seek', 'a', 'chance', 'to', 'get', 'close', 'i', 'was', 'waiting', 'for', 'the', 'bus', 'a', 'man', 'came', 'on', 'a', 'bike', 'and', 'was', 'offering', 'liftvto', 'young', 'girls', 'while', 'coming', 'from', 'classes', 'i', 'saw', 'a', 'group', 'of', 'boys', 'were', 'teasing', 'a', 'girl', 'i', 'witnessed', 'a', 'chain', 'robbery', 'a', 'man', 'thought', 'i', 'was', 'a', 'prostitute', 'and', 'was', 'offering', 'money', 'for', 'one', 'night', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'few', 'people', 'followed', 'me', 'to', 'my', 'home', 'and', 'also', 'pelted', 'stone', 'at', 'me', 'and', 'comments', 'continuously', 'comments', 'on', 'my', 'look', 'and', 'body', 'parts', 'a', 'girl', 'was', 'sitting', 'beside', 'me', 'few', 'boys', 'were', 'following', 'her', 'from', 'last', 'few', 'metro', 'stations', 'and', 'were', 'passing', 'weird', 'comments', 'returning', 'from', 'classes', 'a', 'guy', 'said', 'some', 'indecent', 'words', 'to', 'the', 'victim', 'when', 'i', 'was', 'crossing', 'the', 'crowd', 'a', 'guy', 'came', 'and', 'hit', 'me', 'badly', 'and', 'commented', 'me', 'that', 'was', 'unbearable', 'while', 'going', 'to', 'school', 'someone', 'commented', 'indecent', 'things', 'to', 'the', 'victim', 'and', 'also', 'stalked', 'her', 'later', 'was', 'walking', 'towards', 'home', 'from', 'market', 'someone', 'made', 'rude', 'omments', 'victim', 'was', 'on', 'hr', 'way', 'to', 'the', 'metro', 'station', 'when', 'a', 'group', 'of', 'boys', 'catcalled', 'and', 'whistled', 'to', 'grab', 'her', 'attention', 'victim', 'w ...
#
# Set() unique words and digits eng :
#  {'delhi', 'waiting', 'coming', 'in', 'and', 'visiting', 'are', 'amount', 'employees', 'words', 'unsafe', 'classes', 'a', 'as', 'it', 'following', 'student', 'matter', 'attention', 'official', 'going', 'returning', 'taking', 'victim', 'celebration', 'stone', 'girls', 'some', 'back', 'group', 'sexual', 'action', 'rude', 'obscene', 'night', 'badly', 'walking', 'bikes', 'towards', 'works', 'ticket', 'of', 'later', 'seek', 'offering', 'school', 'colour', 'hold', 'lust', 'our', 'sexually', 'their', 'neighbour', 'around', 'unfortunately', 'catcalled', 'is', 'many', 'mouth', 'regular', 'when', 'an', 't', 'none', 'fortunately', 'there', 'at', 'everyday', 'employee', 'so', 'bike', 'the', 'she', 'witnessed', 'one', 'to', 'for', 'crossing', 'who', 'field', 'while', 'language', 'way', 'premises', 'sitting', 'years', 'after', 'boys', 'place', 'comments', 'always', 'about', 'faces', 'used', 'area', 'everywhere', 'during', 'chance', 'time', 'hit', 'with', 'someone', 'due', 'them', 'full', 'i', 'message', 'look', 'stood', 'robbery', 'but', 'counter', 'made', 'friend', 'dressing', 'pictures', 'parts', 'times', 'whistled', 'traveller', 'get', 'were', 'journeys', 'pelted', 'safe', 'been', 'market', 'his', 'beside', 'pass', 'applied', 'on', 'details', 'grab', 'office', 'never', 'within', 'young', 'govt', 'said', 'tried', 'gave', 'any', 'casual', 'unbearable', 'goons', 'let', 'we', 'passing', 'expressions', 'me', 'leave', 'far', 'pallu', 'water', 'sent', 'close', 'over', 'not', 'coordinator', 'passed', 'my', 'mandi', 'was', 'girl', 'decent', 'few', 'home', 'vehicle', 'omments', 'metro', 'crowd', 'from', 'okay', 'stations', 'babari', 'male', 'travelling', 'stalked', 'molesters', 'station', 'indecent', 'assaulting', 'also', 'uncomfortable', 'does', 'prostitute', 'followed', 'very', 'came', 'us', 'hr', 'has', 'him', 'go', 'asked', 'poured', 'chain', 'thought', 'felt', 'almost', 'view', 'kind', 'her', 'commented', 'classmates', 'intention', 'near', 'scolded', 'couldn', 'take', 'follow', 'body', 'things', 'facial', 'staring', 'year', 'reported', 'holi', 'liftvto', 'continuously', 'last', 'traveling', 'money', 'guy', 'coaching', 'point', 'feels', 'contact', 'that', 'man', 'they', 'assault', 'weird', 'overcrowded', 'teasing', 'people', 'inside', 'bus', 'saw', 'female', 'by'}
#
# After nostop filter :
#  ['sexually', 'assaulting', 'going', 'back', 'place', 'visiting', 'friend', 'going', 'ticket', 'counter', 'way', 'goons', 'kind', 'people', 'sitting', 'bikes', 'passed', 'comments', 'us', 'feels', 'safe', 'night', 'journeys', 'student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'works', 'field', 'coordinator', 'around', 'year', 'back', 'man', 'followed', 'asked', 'contact', 'details', 'govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'last', 'many', 'years', 'almost', 'everyday', 'victim', 'sexual', 'assault', 'traveling', 'unfortunately', 'never', 'take', 'action', 'far', 'molesters', 'saw', 'friend', 'vehicle', 'near', 'babari', 'mandi', 'leave', 'tried', 'get', 'hold', 'pallu', 'bike', 'scolded', 'let', 'go', 'unfortunately', 'coaching', 'classmates', 'used', 'follow', 'us', 'everywhere', 'used', 'go', 'pass', 'comments', 'dressing', 'body', 'language', 'felt', 'uncomfortable', 'holi', 'celebration', 'male', 'employee', 'applied', 'colour', 'inside', 'female', 'employees', 'mouth', 'poured', 'water', 'within', 'office', 'premises', 'okay', 'reported', 'matter', 'travelling', 'delhi', 'metro', 'man', 'staring', 'girl', 'intention', 'full', 'lust', 'decent', 'amount', 'time', 'take', 'stood', 'point', 'view', 'gave', 'casual', 'look', 'fortunately', 'sent', 'message', 'neighbour', 'always', 'seek', 'chance', 'get', 'close', 'waiting', 'bus', 'man', 'came', 'bike', 'offering', 'liftvto', 'young', 'girls', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'witnessed', 'chain', 'robbery', 'man', 'thought', 'prostitute', 'offering', 'money', 'one', 'night', 'taking', 'pictures', 'taking', 'pictures', 'taking', 'pictures', 'people', 'followed', 'home', 'also', 'pelted', 'stone', 'comments', 'continuously', 'comments', 'look', 'body', 'parts', 'girl', 'sitting', 'beside', 'boys', 'following', 'last', 'metro', 'stations', 'passing', 'weird', 'comments', 'returning', 'classes', 'guy', 'said', 'indecent', 'words', 'victim', 'crossing', 'crowd', 'guy', 'came', 'hit', 'badly', 'commented', 'unbearable', 'going', 'school', 'someone', 'commented', 'indecent', 'things', 'victim', 'also', 'stalked', 'later', 'walking', 'towards', 'home', 'market', 'someone', 'made', 'rude', 'omments', 'victim', 'hr', 'way', 'metro', 'station', 'group', 'boys', 'catcalled', 'whistled', 'grab', 'attention', 'victim', 'followed', 'group', 'boys', 'also', 'made', 'indecent', 'facial', 'expressions', 'passed', 'obscene', 'comments', 'none']
#
# Top 20 most used words after non_stop:
#  [('comments', 6), ('victim', 5), ('man', 4), ('boys', 4), ('going', 3), ('followed', 3), ('metro', 3), ('girl', 3), ('group', 3), ('taking', 3), ('pictures', 3), ('also', 3), ('indecent', 3), ('back', 2), ('friend', 2), ('way', 2), ('people', 2), ('sitting', 2), ('passed', 2), ('us', 2)]
#
#  RapeSexualAssault.txt
# ...
#
# Top 20 most used words after non_stop:
#  [('comments', 5), ('almost', 3), ('man', 3), ('sometimes', 2), ('safe', 2), ('every', 2), ('feels', 2), ('assault', 2), ('times', 2), ('area', 2), ('years', 2), ('victim', 2), ('take', 2), ('passing', 2), ('staring', 2), ('time', 2), ('metro', 2), ('used', 2), ('go', 2), ('group', 2)]
#
#  Takingpictures.txt
# HBox(children=(IntProgress(value=0, max=149), HTML(value='')))
# Words and digits eng :
#  ['she', 'is', 'a', 'govt', 'official', 'and', 'there', 'are', 'times', 'when', 'she', 'feels', 'unsafe', 'due', 'to', 'overcrowded', 'area', 'it', 'was', 'during', 'my', 'coaching', 'our', 'classmates', 'used', 'to', 'follow', 'us', 'everywhere', 'we', 'used', 'to', 'go', 'and', 'pass', 'comments', 'on', 'our', 'dressing', 'and', 'our', 'body', 'language', 'it', 'felt', 'very', 'uncomfortable', 'i', 'was', 'waiting', 'for', 'the', 'bus', 'a', 'man', 'came', 'on', 'a', 'bike', 'and', 'was', 'offering', 'liftvto', 'young', 'girls', 'while', 'coming', 'from', 'classes', 'i', 'saw', 'a', 'group', 'of', 'boys', 'were', 'teasing', 'a', 'girl', 'taking', 'pictures', 'verbal', 'teasing', 'one', 'evening', 'inside', 'the', 'first', 'class', 'compartment', 'a', 'guy', 'was', 'staring', 'at', 'my', 'friend', 'and', 'then', 'tried', 'to', 'touch', 'her', 'a', 'man', 'thought', 'i', 'was', 'a', 'prostitute', 'and', 'was', 'offering', 'money', 'for', 'one', 'night', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'was', 'taking', 'pictures', 'few', 'bad', 'people', 'touched', 'my', 'private', 'parts', 'in', 'ranchi', 'bhagalpur', 'express', 'at', 'andal', 'railway', 'station', 'talking', 'objectionable', 'picture', 'of', 'my', 'friend', 'in', 'bus']
#
# Set() unique words and digits eng :
#  {'coming', 'waiting', 'in', 'and', 'are', 'unsafe', 'classes', 'a', 'it', 'official', 'taking', 'girls', 'group', 'night', 'private', 'bad', 'of', 'offering', 'our', 'is', 'when', 'then', 'there', 'at', 'bike', 'the', 'she', 'one', 'to', 'for', 'language', 'while', 'boys', 'comments', 'used', 'area', 'everywhere', 'during', 'touched', 'due', 'i', 'first', 'bhagalpur', 'picture', 'touch', 'friend', 'dressing', 'pictures', 'parts', 'objectionable', 'times', 'talking', 'were', 'andal', 'pass', 'on', 'young', 'evening', 'govt', 'tried', 'compartment', 'verbal', 'we', 'railway', 'my', 'girl', 'was', 'few', 'from', 'ranchi', 'station', 'uncomfortable', 'prostitute', 'very', 'came', 'us', 'go', 'thought', 'felt', 'her', 'express', 'classmates', 'class', 'follow', 'body', 'staring', 'liftvto', 'money', 'guy', 'coaching', 'feels', 'man', 'overcrowded', 'teasing', 'people', 'inside', 'bus', 'saw'}
#
# After nostop filter :
#  ['govt', 'official', 'times', 'feels', 'unsafe', 'due', 'overcrowded', 'area', 'coaching', 'classmates', 'used', 'follow', 'us', 'everywhere', 'used', 'go', 'pass', 'comments', 'dressing', 'body', 'language', 'felt', 'uncomfortable', 'waiting', 'bus', 'man', 'came', 'bike', 'offering', 'liftvto', 'young', 'girls', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'taking', 'pictures', 'verbal', 'teasing', 'one', 'evening', 'inside', 'first', 'class', 'compartment', 'guy', 'staring', 'friend', 'tried', 'touch', 'man', 'thought', 'prostitute', 'offering', 'money', 'one', 'night', 'taking', 'pictures', 'taking', 'pictures', 'taking', 'pictures', 'bad', 'people', 'touched', 'private', 'parts', 'ranchi', 'bhagalpur', 'express', 'andal', 'railway', 'station', 'talking', 'objectionable', 'picture', 'friend', 'bus']
#
# Top 20 most used words after non_stop:
#  [('taking', 4), ('pictures', 4), ('used', 2), ('bus', 2), ('man', 2), ('offering', 2), ('teasing', 2), ('one', 2), ('friend', 2), ('govt', 1), ('official', 1), ('times', 1), ('feels', 1), ('unsafe', 1), ('due', 1), ('overcrowded', 1), ('area', 1), ('coaching', 1), ('classmates', 1), ('follow', 1)]
#
#  PoorNoStreetLighting.txt
# HBox(children=(IntProgress(value=0, max=163), HTML(value='')))
# Words and digits eng :
#  ['she', 'is', 'a', 'student', 'and', 'she', 'is', 'a', 'regular', 'traveller', 'but', 'she', 'never', 'felt', 'safe', 'she', 'faces', 'assault', 'almost', 'everyday', 'i', 'work', 'in', 'a', 'factory', 'in', 'bengaluru', 'rural', 'area', 'the', 'street', 'which', 'leads', 'to', 'the', 'factory', 'where', 'i', 'work', 'has', 'no', 'street', 'lights', 'at', 'all', 'it', 'becomes', 'extremely', 'difficult', 'for', 'those', 'who', 'have', 'to', 'go', 'to', 'work', 'in', 'the', 'night', 'shift', 'sometimes', 'even', 'robbery', 'also', 'takes', 'place', 'by', 'strangers', 'one', 'day', 'a', 'group', 'of', 'people', 'came', 'onto', 'me', 'and', 'i', 'was', 'mugged', 'they', 'took', 'my', 'phone', 'and', 'wallet', 'in', 'a', 'beer', 'bar', 'after', 'it', 'closed', 'two', 'girls', 'who', 'were', 'there', 'are', 'hit', 'by', 'some', 'men', 'when', 'she', 'refused', 'to', 'go', 'with', 'them', 'i', 'was', 'waiting', 'for', 'the', 'bus', 'a', 'man', 'came', 'on', 'a', 'bike', 'and', 'was', 'offering', 'liftvto', 'young', 'girls', 'while', 'coming', 'from', 'classes', 'i', 'saw', 'a', 'group', 'of', 'boys', 'were', 'teasing', 'a', 'girl', 'i', 'witnessed', 'a', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'a', 'gang', 'of', 'goon', 'looted', 'me', 'outside', 'the', 'raniganj', 'station']
#
# Set() unique words and digits eng :
#  {'coming', 'waiting', 'in', 'and', 'are', 'classes', 'a', 'it', 'even', 'onto', 'student', 'difficult', 'taking', 'lights', 'girls', 'some', 'group', 'night', 'of', 'offering', 'bar', 'gang', 'is', 'regular', 'when', 'refused', 'there', 'have', 'closed', 'at', 'extremely', 'everyday', 'beer', 'bike', 'mugged', 'outside', 'the', 'she', 'witnessed', 'one', 'to', 'for', 'who', 'men', 'while', 'strangers', 'after', 'boys', 'place', 'faces', 'those', 'area', 'all', 'factory', 'hit', 'with', 'them', 'i', 'bengaluru', 'which', 'robbery', 'goon', 'but', 'becomes', 'day', 'phone', 'pictures', 'traveller', 'were', 'safe', 'on', 'never', 'young', 'verbal', 'me', 'sometimes', 'my', 'girl', 'was', 'where', 'from', 'work', 'leads', 'station', 'also', 'street', 'two', 'came', 'takes', 'has', 'go', 'looted', 'chain', 'felt', 'almost', 'shift', 'raniganj', 'wallet', 'liftvto', 'man', 'they', 'assault', 'rural', 'teasing', 'people', 'no', 'bus', 'saw', 'took', 'by'}
#
# After nostop filter :
#  ['student', 'regular', 'traveller', 'never', 'felt', 'safe', 'faces', 'assault', 'almost', 'everyday', 'work', 'factory', 'bengaluru', 'rural', 'area', 'street', 'leads', 'factory', 'work', 'street', 'lights', 'becomes', 'extremely', 'difficult', 'go', 'work', 'night', 'shift', 'sometimes', 'even', 'robbery', 'also', 'takes', 'place', 'strangers', 'one', 'day', 'group', 'people', 'came', 'onto', 'mugged', 'took', 'phone', 'wallet', 'beer', 'bar', 'closed', 'two', 'girls', 'hit', 'men', 'refused', 'go', 'waiting', 'bus', 'man', 'came', 'bike', 'offering', 'liftvto', 'young', 'girls', 'coming', 'classes', 'saw', 'group', 'boys', 'teasing', 'girl', 'witnessed', 'chain', 'robbery', 'taking', 'pictures', 'verbal', 'teasing', 'gang', 'goon', 'looted', 'outside', 'raniganj', 'station']
#
# Top 20 most used words after non_stop:
#  [('work', 3), ('factory', 2), ('street', 2), ('go', 2), ('robbery', 2), ('group', 2), ('came', 2), ('girls', 2), ('teasing', 2), ('student', 1), ('regular', 1), ('traveller', 1), ('never', 1), ('felt', 1), ('safe', 1), ('faces', 1), ('assault', 1), ('almost', 1), ('everyday', 1), ('bengaluru', 1)]
#
#  OnlineHarassment.txt
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Words and digits eng :
#  []
#
# Set() unique words and digits eng :
#  set()
#
# After nostop filter :
#  []
#
# Top 20 most used words after non_stop:
#  []
#
# corpus: 14
# Top_20 after Term Frequency–Inverse Document Frequency
#
#  TouchingGroping
# thinking 0.16166474146868917
# touching 0.1589380963867065
# happened 0.15727563430622873
# behind 0.125820507444983
# touched 0.125820507444983
# bus 0.12110982661184849
# minutes 0.11920357229002987
# private 0.11920357229002987
# put 0.11920357229002987
# stopped 0.11920357229002987
# turned 0.11920357229002987
# change 0.10777649431245945
# cigarettes 0.10777649431245945
# clothes 0.10777649431245945
# harassed 0.10777649431245945
# jeans 0.10777649431245945
# manner 0.10777649431245945
# mean 0.10777649431245945
# modern 0.10777649431245945
# mom 0.10777649431245945
#
#  CatcallsWhistles
# pictures 0.20973415001046217
# taking 0.20973415001046217
# circle 0.16331342014802033
# heavy 0.16331342014802033
# inner 0.16331342014802033
# make 0.16331342014802033
# singing 0.16331342014802033
# song 0.16331342014802033
# three 0.16331342014802033
# tone 0.16331342014802033
# voices 0.16331342014802033
# comments 0.15730061250784663
# group 0.15730061250784663
# used 0.15730061250784663
# victim 0.12743237260039408
# teasing 0.12743237260039408
# boy 0.12041922628080898
# attention 0.12041922628080898
# catcalled 0.12041922628080898
# dancing 0.12041922628080898
#
#  SexualInvites
# like 0.3322907505050169
# punishments 0.2215271670033446
# asked 0.12930769711437953
# ago 0.1107635835016723
# apartment 0.1107635835016723
# approached 0.1107635835016723
# apps 0.1107635835016723
# awareness 0.1107635835016723
# backpack 0.1107635835016723
# bailable 0.1107635835016723
# behaving 0.1107635835016723
# bhilwara 0.1107635835016723
# bhopal 0.1107635835016723
# bi 0.1107635835016723
# bullied 0.1107635835016723
# colony 0.1107635835016723
# death 0.1107635835016723
# directly 0.1107635835016723
# gay 0.1107635835016723
# happen 0.1107635835016723
#
#  Stalking
# bus 0.18276109520528488
# later 0.16613604019865807
# might 0.15739890006769894
# minutes 0.15739890006769894
# sat 0.15739890006769894
# seat 0.15739890006769894
# turned 0.15739890006769894
# stalked 0.15739890006769894
# back 0.12460203014899356
# behind 0.12460203014899356
# even 0.12460203014899356
# happened 0.12460203014899356
# way 0.11104381418044795
# abused 0.1049326000451326
# angry 0.1049326000451326
# conductor 0.1049326000451326
# put 0.1049326000451326
# realised 0.1049326000451326
# right 0.1049326000451326
# shirt 0.1049326000451326
#
#  Others
# rickshaw 0.3371604765510278
# accepting 0.1685802382755139
# adhoc 0.1685802382755139
# alone 0.1685802382755139
# asks 0.1685802382755139
# atm 0.1685802382755139
# cabin 0.1685802382755139
# coffee 0.1685802382755139
# days 0.1685802382755139
# discuss 0.1685802382755139
# fb 0.1685802382755139
# issue 0.1685802382755139
# known 0.1685802382755139
# misunderstanding 0.1685802382755139
# nothing 0.1685802382755139
# professors 0.1685802382755139
# regarding 0.1685802382755139
# request 0.1685802382755139
# senior 0.1685802382755139
# snatch 0.1685802382755139
#
#  Commenting
# going 0.23345292365248996
# sitting 0.21107368860592482
# victim 0.20587423945465494
# comments 0.20330246266295546
# indecent 0.18480884058787503
# commented 0.1556352824349933
# made 0.1556352824349933
# followed 0.12352454367279295
# back 0.12320589372525002
# get 0.12320589372525002
# someone 0.12320589372525002
# passed 0.12320589372525002
# badly 0.10553684430296241
# counter 0.10553684430296241
# goons 0.10553684430296241
# omments 0.10553684430296241
# rude 0.10553684430296241
# ticket 0.10553684430296241
# unbearable 0.10553684430296241
# visiting 0.10553684430296241
#
#  RapeSexualAssault
# raped 0.39482834912770925
# dumped 0.33820572010303945
# minor 0.33820572010303945
# tribal 0.33820572010303945
# pictures 0.32575379829561624
# taking 0.32575379829561624
# disappeared 0.19741417456385463
# friends 0.19741417456385463
# hours 0.19741417456385463
# playing 0.19741417456385463
# temple 0.19741417456385463
# got 0.1605465698390744
# old 0.1605465698390744
# year 0.13194983394718143
# assaulting 0.10858459943187208
# sexually 0.07171699470709185
# men 0.05662262902466973
# time 0.05662262902466973
# girl 0.03951004859977905
#
#  NorthEastIndiaReport
# assaulted 0.2658048894899901
# assignment 0.2658048894899901
# conducted 0.2658048894899901
# construction 0.2658048894899901
# course 0.2658048894899901
# iit 0.2658048894899901
# offered 0.2658048894899901
# sociology 0.2658048894899901
# survey 0.2658048894899901
# women 0.2658048894899901
# workers 0.2658048894899901
# said 0.21041969695935905
# site 0.21041969695935905
# bar 0.14064260651163618
# beer 0.14064260651163618
# closed 0.14064260651163618
# part 0.14064260651163618
# refused 0.14064260651163618
# girls 0.09468161200478806
# two 0.09468161200478806
#
#  Indecentexposure
# ac 0.20611039550902527
# bag 0.20611039550902527
# bellandur 0.20611039550902527
# bmtc 0.20611039550902527
# escape 0.20611039550902527
# hiding 0.20611039550902527
# innocent 0.20611039550902527
# looked 0.20611039550902527
# masturbating 0.20611039550902527
# petrol 0.20611039550902527
# plastic 0.20611039550902527
# pretending 0.20611039550902527
# privates 0.20611039550902527
# pump 0.20611039550902527
# rush 0.20611039550902527
# screamed 0.20611039550902527
# tied 0.20611039550902527
# tying 0.20611039550902527
# started 0.16082656706053364
# aged 0.15197559596224774
#
#  ChainSnatching
# snatched 0.5437806021247064
# chain 0.45173302563218876
# snatching 0.2718903010623532
# road 0.15870517902473524
# two 0.14282372231029927
# biker 0.1359451505311766
# bikers 0.1359451505311766
# flee 0.1359451505311766
# gold 0.1359451505311766
# helmet 0.1359451505311766
# injuring 0.1359451505311766
# morning 0.1359451505311766
# motorbike 0.1359451505311766
# rider 0.1359451505311766
# thus 0.1359451505311766
# today 0.1359451505311766
# woman 0.1359451505311766
# aunt 0.10023921995360179
# guys 0.10023921995360179
# police 0.10023921995360179
#
#  OglingFacialExpressionsStaring
# every 0.29386059250918667
# comments 0.23586779310460174
# sometimes 0.1715294652301328
# andheri 0.14693029625459333
# boarding 0.14693029625459333
# bridge 0.14693029625459333
# cheap 0.14693029625459333
# chest 0.14693029625459333
# connecting 0.14693029625459333
# happens 0.14693029625459333
# multiple 0.14693029625459333
# past 0.14693029625459333
# person 0.14693029625459333
# railways 0.14693029625459333
# reason 0.14693029625459333
# stared 0.14693029625459333
# almost 0.14152067586276104
# passing 0.13949589653260253
# victim 0.1146487302857982
# followed 0.1146487302857982
#
#  Takingpictures
# pictures 0.27592188978471943
# taking 0.27592188978471943
# class 0.21485174213259897
# evening 0.21485174213259897
# objectionable 0.21485174213259897
# picture 0.21485174213259897
# talking 0.21485174213259897
# teasing 0.1676473815346584
# andal 0.15842103195954085
# bad 0.15842103195954085
# bhagalpur 0.15842103195954085
# express 0.15842103195954085
# private 0.15842103195954085
# railway 0.15842103195954085
# ranchi 0.15842103195954085
# touch 0.15842103195954085
# compartment 0.15842103195954085
# bus 0.13796094489235972
# offering 0.13796094489235972
# used 0.13796094489235972
#
#  PoorNoStreetLighting
# work 0.4631895806772548
# factory 0.3087930537848365
# street 0.3087930537848365
# becomes 0.15439652689241826
# bengaluru 0.15439652689241826
# difficult 0.15439652689241826
# extremely 0.15439652689241826
# leads 0.15439652689241826
# lights 0.15439652689241826
# mugged 0.15439652689241826
# onto 0.15439652689241826
# rural 0.15439652689241826
# shift 0.15439652689241826
# strangers 0.15439652689241826
# takes 0.15439652689241826
# wallet 0.15439652689241826
# robbery 0.14658434978623172
# teasing 0.12047458026002222
# gang 0.11384435089276707
# goon 0.11384435089276707
#
#  OnlineHarassment

# %% [markdown]
# ### Word Cloud
# The first resulting Cloud is doesn't describe well the content of each category description, it's too general. tf-idf without lemmatization nor stemming performs better. Maybe if we apply a no_stop words filter without tokenizing it will perform better. The second resulting cloud doesn't carea about the order of the words (weights). Nevertheless, the word maps are unique

# %%
def WordCloud_gen(filename, corpus=corpus, corpus_index=0, dictionary=dictionary, tfidf=tfidf):
  
  stopwords_eng = sw.words("english")
  if filename=='tfidf':
    tfidf_weights = tfidf[corpus[corpus_index]]
    weights = [(dictionary[pair[0]], pair[1]) for pair in tfidf_weights]
    alice_mask = np.array(Image.open('silhouette.png'))
    wc = WordCloud(background_color="white", max_words=400, mask=alice_mask, stopwords=stopwords_eng)
    wc.generate_from_frequencies(dict(weights))
  else:
    category = open(filename +'.txt', 'r')
    content = category.read().lower() 
    alice_mask = np.array(Image.open('silhouette.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color="white", max_words=400, mask=alice_mask, stopwords=stopwords_eng)
    wc.generate(content)

  plt.figure(figsize=(8,6), dpi=120)
  plt.imshow(wc, interpolation='bilinear')
  plt.axis("off")
  plt.show()
  
  return wc

# %%
#Without tfidf
WordCloud_gen('TouchingGroping')

# %%
#Third category WITH tfidf, can you guess it?
WordCloud_gen('tfidf', corpus_index=3)

# %%
#Can you guess it?
WordCloud_gen('tfidf', corpus_index=6)

# %% [markdown]
# ### Name Entity Recognition NER

# %% [markdown]
# The Idea is to try to extract meaningful entities among the categories helping to determine their inter-correlations.
#
# Note: At the end it wasn't necessary due to the good result of the classifier after hyperparameter tuning.

# %%
#Using nltk entities
category = open('TouchingGroping.txt', 'r')
content = category.read()

# Tokenize the article into sentences: sentences
sentences = nltk.sent_tokenize(content)

# Tokenize each sentence into words: token_sentences
token_sentences = [word_tokenize(sent) for sent in sentences]

# Tag each tokenized sentence into parts of speech: pos_sentences
pos_sentences = [nltk.pos_tag(sent) for sent in token_sentences] 

# Create the named entity chunks: chunked_sentences
chunked_sentences = nltk.ne_chunk_sents(pos_sentences , binary=False)

# Test for stems of the tree with tags or NE tag
for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, "label"):# and chunk.label() == "NE":
            print(chunk)

# NNP is proper-noun-singular
# Out:
# (GPE Pedicab/NNP)
# (GPE Gurgaon/NNP)
# (GPE India/NNP)
# (GPE Okay/NNP)
# (ORGANIZATION Vashi/NNP)
# (ORGANIZATION Vashi/NNP)
# (PERSON Kharghar/NNP)
# (PERSON Navi/NNP Mumbai/NNP)
# (ORGANIZATION IIT/NNP)
# (GPE Tirupati/NNP)
# (GPE Holi/NNP)
# (GPE POSH/NNP)
# (ORGANIZATION Delhi/NNP)
# (ORGANIZATION Andal/NNP)

# %%
#Entity type participation
chunked_sentences = nltk.ne_chunk_sents(pos_sentences , binary=False)
ner_categories = defaultdict(int)

for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, 'label'):
            ner_categories[chunk.label()] += 1

labels = list(ner_categories.keys())
print(labels)
values = [ner_categories.get(l) for l in labels]
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)
plt.show()
# Out:
# ['GPE', 'ORGANIZATION', 'PERSON']

# %%
#TODO loop over all categories, think how you are going to use this information
from spacy import displacy

#Using Spacy
category = open('TouchingGroping.txt', 'r')
content = category.read()

nlp = spacy.load('en')
nlp.entity
doc = nlp(content)
items = [x.text for x in doc.ents]
labels = [x.label_ for x in doc.ents]
labels_type =  np.unique(np.array(labels))
entity_dict = dict((k, []) for k in labels_type)

for item, label in zip(items, labels):
  entity_dict[label].append(item)
  
for ent_type in labels_type:
  counter_ = Counter(entity_dict[ent_type])
  counter = Counter(entity_dict[ent_type]).most_common(5)
  top5_list = []
  top5 = ''
  for word_count in counter:
    word = word_count[0]
    if type(word) is str:
      top5 += ', ' + word if word.isalpha() else ''
      top5_list.append(word) if word.isalpha() else ''
  top5_dict = dict((k, ['#']) for k in top5_list)
  html = displacy.render(nlp('; '.join(top5_list)), style="ent", jupyter=True, manual=False) if len(top5_list)>0 else None
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Vashi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# ;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Pedicab
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Gurgaon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Vashi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     IIT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tirupati
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kharghar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Holi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>

# %% [markdown]
# ## Supervised Text Classification
# Using tf-idf feautures (weights) and word count. And a binary output where usually there is the target variables are a binary encoding of the SH category.

# %%
#First I want to pass the list in CATEGORY to a vector of 1s and 0s
categories_bool = [[]]
category_bool = [0]*len(categories)

for index, row in report_1.iterrows():
  row_category = row['CATEGORY']
  for category in row_category:
    index_match = list(filter(lambda x: categories[x][0] == category.lstrip(), range(len(categories))))
    if len(index_match) == 1:
      category_bool[index_match[0]] = 1 if len(index_match) != 0 else None
  categories_bool.append(category_bool)
  category_bool = [0]*len(categories)
del(categories_bool[0])

#Expand the column CATEGORY by its boolean representation
category_list = [cat[0] for cat in categories]
df_categories = pd.DataFrame.from_records(categories_bool)
df_categories.columns = category_list
df_ready = pd.concat([report_1, df_categories], axis=1)

# %%
df_ready.head()
# Out:
#          # INCIDENT TITLE  ... Poor / No Street Lighting Online Harassment
# 0  12152.0       touching  ...                       0.0               0.0
# 1  12149.0      whistling  ...                       0.0               0.0
# 2  12213.0  sexual invite  ...                       0.0               0.0
# 3  12199.0  sexual invite  ...                       0.0               0.0
# 4  12206.0  sexual invite  ...                       0.0               0.0
#
# [5 rows x 23 columns]

# %% [markdown]
# After this point we created the second version of our dataset: safecity_reports_07082019

# %%
#Load the database version
report_1 = pd.read_csv('safecity_reports_07082019.csv')
report_1 = report_1[pd.notna(report_1['DESCRIPTION'])]

#Select x and Y (without HumanTrafficking or PettyRobbery is til column 28)
x_report_1 = report_1[report_1.columns[4]]
y_report_1 = report_1[report_1.columns[14:28]]
X_train, X_test, y_train, y_test = train_test_split(x_report_1, y_report_1, test_size=0.2, random_state=17)
categories = y_train.columns

# %%
#CountVectorizer
count_vectorizer = CountVectorizer(stop_words='english')
X_train = X_train[pd.notna(X_train)]
count_train = count_vectorizer.fit_transform(X_train.values)
X_test = X_test[pd.notna(X_test)]
count_test = count_vectorizer.transform(X_test.values)

#TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words="english", max_df=0.7)
tfidf_train = tfidf_vectorizer.fit_transform(X_train.values)
tfidf_test = tfidf_vectorizer.transform(X_test.values)

# %%
print(X_train.values[0])
print(count_train[0])
# Out:
# two boys commented on me and my sister while we were returning home from the market
#   (0, 1144)	1
#   (0, 1687)	1
#   (0, 7208)	1
#   (0, 6563)	1
#   (0, 3616)	1
#   (0, 4839)	1

# %%
#Hyperparameters preprocess

lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

pattern_wd_eng = (r'[A-Za-z]+') 

lowers = [entry.lower() for entry in X_train.values] #1

def no_stopwords(dt_list, option=1):
  tokens = [re.findall(pattern_wd_eng, t) for t in dt_list] if option==1 else [word_tokenize(entry) for entry in dt_list]
  no_stops = [t for t in tokens if t not in sw.words('english')]
  return no_stops

# %%
no_stops = no_stopwords(lowers) #better
alternative = no_stopwords(lowers, option=2)

# %%
lemm = []
stemm = []
for category in tqdm(range(len(no_stops))):
  lemmatized = [lemmatizer.lemmatize(word, pos="v") for word in no_stops[category]] #2
  lemm.append(lemmatized)
  stemmed = [stemmer.stem(word) for word in lemmatized] #3
  stemm.append(stemmed)
# Out:
# HBox(children=(IntProgress(value=0, max=9283), HTML(value='')))

# %%
# Check whether the two vectorizers are equal (They shouldn't be)
count_df = pd.DataFrame(count_train.A, columns=count_vectorizer.get_feature_names())
tfidf_df = pd.DataFrame(tfidf_train.A, columns=tfidf_vectorizer.get_feature_names())
difference = set(count_df.columns) - set(tfidf_df.columns)
print('Equality Test output: ', count_df.equals(tfidf_df))
# Out:
# Equality Test output:  False

# %% [markdown]
# Explain difference between OneVsRestClassifier and MultiOutputClassifier

# %% [markdown]
# ####Naive Bayes
# Next: SVM or linear models for tf-idf; create a function to iterate over the alphas from 0 to 1 with steps 0.1 with np.arange()

# %%
print(count_train.shape)
print(y_train.shape)
y_train.head()
# Out:
# (8844, 8894)
# (8844, 14)
#       Touching /Groping  ...  Online Harassment
# 3742                  0  ...                  0
# 2876                  0  ...                  0
# 7655                  0  ...                  0
# 6048                  0  ...                  0
# 4403                  0  ...                  0
#
# [5 rows x 14 columns]

# %%
#Initial test for one category, CountVectorizer()
nb_classifier = MultinomialNB()
nb_classifier.fit(count_train, y_train.iloc[:,0])
pred = nb_classifier.predict(count_test)
score = metrics.accuracy_score(y_test.iloc[:,0], pred)
print('Test accuracy is {}'.format(score))
metrics.confusion_matrix(y_test.iloc[:,0], pred)
# Out:
# Test accuracy is 0.8611488014473089
# array([[1497,   80],
#        [ 227,  407]])

# %%
#Initial test for one category, TfidfVectorizer()
nb_classifier = MultinomialNB()
nb_classifier.fit(tfidf_train, y_train.iloc[:,0])
pred = nb_classifier.predict(tfidf_test)
score = metrics.accuracy_score(y_test.iloc[:,0], pred)
print('Test accuracy is {}'.format(score))
metrics.confusion_matrix(y_test.iloc[:,0], pred, labels=[0,1])
# Out:
# Test accuracy is 0.80958842152872
# array([[1552,   25],
#        [ 396,  238]])

# %%
#Inspecting the model
# Get the class labels: class_labels
class_labels = nb_classifier.classes_
# Extract the features: feature_names
feature_names = tfidf_vectorizer.get_feature_names()
# Zip the feature names together with the coefficient array and sort by weights: feat_with_weights
feat_with_weights = sorted(zip(nb_classifier.coef_[0], feature_names))
print(class_labels, feat_with_weights[300:350])
# Out:
# [0 1] [(-9.687577285651056, 'aren'), (-9.687577285651056, 'arena'), (-9.687577285651056, 'ares'), (-9.687577285651056, 'arested'), (-9.687577285651056, 'arguing'), (-9.687577285651056, 'arival'), (-9.687577285651056, 'armbushed'), (-9.687577285651056, 'armed'), (-9.687577285651056, 'army'), (-9.687577285651056, 'arre'), (-9.687577285651056, 'arrest'), (-9.687577285651056, 'arrested'), (-9.687577285651056, 'arrival'), (-9.687577285651056, 'arrives'), (-9.687577285651056, 'arriving'), (-9.687577285651056, 'arterial'), (-9.687577285651056, 'article'), (-9.687577285651056, 'artid'), (-9.687577285651056, 'artificial'), (-9.687577285651056, 'arts'), (-9.687577285651056, 'aruvathimuvar'), (-9.687577285651056, 'asgarali'), (-9.687577285651056, 'ashok'), (-9.687577285651056, 'asians'), (-9.687577285651056, 'aside'), (-9.687577285651056, 'asif'), (-9.687577285651056, 'aso'), (-9.687577285651056, 'aspx'), (-9.687577285651056, 'assassinating'), (-9.687577285651056, 'assaulter'), (-9.687577285651056, 'assaulters'), (-9.687577285651056, 'assclown'), (-9.687577285651056, 'asset'), (-9.687577285651056, 'asshole'), (-9.687577285651056, 'assing'), (-9.687577285651056, 'assist'), (-9.687577285651056, 'assistance'), (-9.687577285651056, 'assisting'), (-9.687577285651056, 'associate'), (-9.687577285651056, 'associated'), (-9.687577285651056, 'assualting'), (-9.687577285651056, 'assume'), (-9.687577285651056, 'assumed'), (-9.687577285651056, 'assuming'), (-9.687577285651056, 'assured'), (-9.687577285651056, 'astray'), (-9.687577285651056, 'ata'), (-9.687577285651056, 'atas'), (-9.687577285651056, 'atau'), (-9.687577285651056, 'atlast')]

# %% [markdown]
# #####Pipeline definition
# Using OneVsRestClassifier and MiltiOutputClassifier strategies.

# %%
#Pipelines
NB_pipeline_CountV = Pipeline([('count', CountVectorizer(stop_words='english')), 
                        ('clf', OneVsRestClassifier(MultinomialNB())),])
NB_pipeline_TfidfV = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')),
                        ('clf', OneVsRestClassifier(MultinomialNB())),])
NB_pipeline_CountV2 = Pipeline([('count2', CountVectorizer(stop_words='english')), 
                        ('clf', MultiOutputClassifier(MultinomialNB())),]) #do tuning for this one as well

# %%
#For OneVsRestClasifier strategy
from sklearn.metrics import precision_recall_fscore_support
import joblib

category_list_save_model = ['TouchingGroping','CatcallsWhistles', 'SexualInvites', 'Stalking', 'Others', 'Commenting',
                 'RapeSexualAssault', 'NorthEastIndiaReport', 'IndecentExposure', 'ChainSnatching', 
                 'OglingFacialExpressionsStaring', 'TakingPictures', 'PoorNoStreetLighting', 'OnlineHarassment']

def execute(pipeline, X_train=X_train, X_test=X_test, confusion_matrix=False, verbose=True):

  accuracies=[]
  
  for category, cat_name in (tqdm(zip(categories, category_list_save_model)) if verbose else zip(categories, category_list_save_model)):
    pipeline.fit(X_train, y_train[category])
    prediction = pipeline.predict(X_test)
    
    if len(X_test) == 1:
      print('Prediction for {} is {}'.format(category, prediction)) if verbose else None
    else:
      print('Test accuracy for {} is {}'.format(category, metrics.accuracy_score(y_test[category], prediction))) if verbose else None
      accuracies.append(metrics.accuracy_score(y_test[category], prediction))
      print(metrics.confusion_matrix(y_test[category], prediction, labels=[0,1])) if confusion_matrix else None
      print('precision_recall_fscore_support_weighted', precision_recall_fscore_support(y_test[category], prediction, average='weighted')) if verbose else None

    filename = 'model_'+cat_name+'.sav'
    joblib.dump(pipeline, filename)
  print('mean: ', sum(accuracies)/len(accuracies)) if verbose and len(accuracies)!=0 else None
  return accuracies

def execute_mean(pipeline, X_train=X_train, X_test=X_test, confusion_matrix=False, verbose=True):

  accuracies=[]
  for category in (tqdm(categories) if verbose else categories):
    pipeline.fit(X_train, y_train[category])
    prediction = pipeline.predict(X_test)
    
    if len(X_test) == 1:
      print('Prediction for {} is {}'.format(category, prediction)) if verbose else None
    else:
      print('Test accuracy for {} is {}'.format(category, metrics.accuracy_score(y_test[category], prediction))) if verbose else None
      accuracies.append(metrics.accuracy_score(y_test[category], prediction))
      print(metrics.confusion_matrix(y_test[category], prediction, labels=[0,1])) if confusion_matrix else None
      print('precision_recall_fscore_support_weighted', precision_recall_fscore_support(y_test[category], prediction, average='weighted')) if verbose else None
  
  mean = sum(accuracies)/len(accuracies)
  print('mean: ', mean) if verbose else None
  return accuracies, mean

# %%
#For MultOutputClasifier strategy
def execute2(pipeline, X_train=X_train, X_test=X_test, confusion_matrix=False, verbose=True):
  
  accuracies=[]
  pipeline.fit(X_train, y_train)
  y_pred = pipeline.predict(X_test)
      
  if confusion_matrix:
    y_test_list = y_test.values.tolist()
    y_test_array = np.array(y_test_list)
    y_pred_list = y_pred.tolist()
    y_pred_array = np.array(y_pred_list)
    conf_mat = metrics.multilabel_confusion_matrix(y_test_array, y_pred_array)
    print('Test accuracy is {}'.format(metrics.accuracy_score(y_test_array, y_pred_array)))
    print(conf_mat)
      
  return accuracies

# %%
acc = execute(NB_pipeline_CountV, confusion_matrix=False)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.6958207669108143
# precision_recall_fscore_support_weighted (0.6251873584329182, 0.6958207669108143, 0.6209957673938231, None)
# Test accuracy for Catcalls/Whistles is 0.7492460146488582
# precision_recall_fscore_support_weighted (0.6360229652415259, 0.7492460146488582, 0.6724469893862954, None)
# Test accuracy for Sexual Invites is 0.8914261094355881
# precision_recall_fscore_support_weighted (0.857508284451787, 0.8914261094355881, 0.861071776313176, None)
# Test accuracy for Stalking is 0.9086600603188281
# precision_recall_fscore_support_weighted (0.864591430771543, 0.9086600603188281, 0.8780745004871262, None)
# Test accuracy for Others is 0.8892718655751831
# precision_recall_fscore_support_weighted (0.817625787338214, 0.8892718655751831, 0.8451475966663493, None)
# Test accuracy for Commenting is 0.6174062903920724
# precision_recall_fscore_support_weighted (0.5878821183823171, 0.6174062903920724, 0.5806318482092814, None)
# Test accuracy for Rape / Sexual Assault is 0.9401120206807411
# precision_recall_fscore_support_weighted (0.8997826985625715, 0.9401120206807411, 0.9185118428381839, None)
# Test accuracy for North East India Report is 0.993106419646704
# precision_recall_fscore_support_weighted (0.993106419646704, 0.993106419646704, 0.993106419646704, None)
# Test accuracy for Indecent exposure is 0.9314950452391211
# precision_recall_fscore_support_weighted (0.883392058038568, 0.9314950452391211, 0.9054467901635095, None)
# Test accuracy for Chain Snatching is 0.9551917277035761
# precision_recall_fscore_support_weighted (0.9245394346202871, 0.9551917277035761, 0.9396156616281982, None)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.7884532529082292
# precision_recall_fscore_support_weighted (0.7173422103352283, 0.7884532529082292, 0.7176789868163568, None)
# Test accuracy for Taking pictures is 0.919000430848772
# precision_recall_fscore_support_weighted (0.8544952013004614, 0.919000430848772, 0.8855747304002987, None)
# Test accuracy for Poor / No Street Lighting is 0.965101249461439
# precision_recall_fscore_support_weighted (0.941276749149918, 0.965101249461439, 0.9530401288257665, None)
# /usr/local/lib/python3.6/dist-packages/sklearn/multiclass.py:76: UserWarning: Label not 0.0 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test accuracy for Online Harassment is 0.999569151227919
# precision_recall_fscore_support_weighted (0.9991384880865023, 0.999569151227919, 0.9993537732595441, None)
#
# mean:  0.874561457499846

# %%
acc = execute2(NB_pipeline_CountV2, confusion_matrix=True) #the sme onevsrest
# Out:
# Test accuracy is 0.05040930633347695
# [[[1553   92]
#   [ 614   62]]
#
#  [[1724   70]
#   [ 512   15]]
#
#  [[2039   32]
#   [ 220   30]]
#
#  [[2099   24]
#   [ 188   10]]
#
#  [[2061   17]
#   [ 240    3]]
#
#  [[1213  231]
#   [ 657  220]]
#
#  [[2181   17]
#   [ 122    1]]
#
#  [[2305    8]
#   [   8    0]]
#
#  [[2161   16]
#   [ 143    1]]
#
#  [[2217   15]
#   [  89    0]]
#
#  [[1805   37]
#   [ 454   25]]
#
#  [[2133   13]
#   [ 175    0]]
#
#  [[2240   12]
#   [  69    0]]
#
#  [[2320    0]
#   [   1    0]]]

# %%
acc = execute(NB_pipeline_TfidfV)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.7109004739336493
# precision_recall_fscore_support_weighted (0.6847423783030625, 0.7109004739336493, 0.5990610506339752, None)
# Test accuracy for Catcalls/Whistles is 0.7729426971133132
# precision_recall_fscore_support_weighted (0.7113332751926129, 0.7729426971133132, 0.6755675343198938, None)
# Test accuracy for Sexual Invites is 0.8931495045239121
# precision_recall_fscore_support_weighted (0.8692783112465179, 0.8931495045239121, 0.8452006948787151, None)
# Test accuracy for Stalking is 0.9159844894442051
# precision_recall_fscore_support_weighted (0.8956034044507124, 0.9159844894442051, 0.8794197663853947, None)
# Test accuracy for Others is 0.8948728996122362
# precision_recall_fscore_support_weighted (0.8015283988768219, 0.8948728996122362, 0.8456325081374382, None)
# Test accuracy for Commenting is 0.6311934510986643
# precision_recall_fscore_support_weighted (0.618508055586394, 0.6311934510986643, 0.5268819835097435, None)
# Test accuracy for Rape / Sexual Assault is 0.9465747522619561
# precision_recall_fscore_support_weighted (0.8967979764964567, 0.9465747522619561, 0.9210143007843201, None)
# Test accuracy for North East India Report is 0.996553209823352
# precision_recall_fscore_support_weighted (0.993118300009226, 0.996553209823352, 0.9948327899531347, None)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test accuracy for Indecent exposure is 0.9375269280482551
# precision_recall_fscore_support_weighted (0.8797397079142463, 0.9375269280482551, 0.9077145307365139, None)
# Test accuracy for Chain Snatching is 0.961654459284791
# precision_recall_fscore_support_weighted (0.9247792990623238, 0.961654459284791, 0.942856469634814, None)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.7966393795777682
# precision_recall_fscore_support_weighted (0.7839013026231204, 0.7966393795777682, 0.712508062192824, None)
# Test accuracy for Taking pictures is 0.9241706161137441
# precision_recall_fscore_support_weighted (0.8548578199052131, 0.9241706161137441, 0.888163968732689, None)
# Test accuracy for Poor / No Street Lighting is 0.96984058595433
# precision_recall_fscore_support_weighted (0.9414142239522204, 0.96984058595433, 0.955416010310215, None)
# /usr/local/lib/python3.6/dist-packages/sklearn/multiclass.py:76: UserWarning: Label not 0.0 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test accuracy for Online Harassment is 0.999569151227919
# precision_recall_fscore_support_weighted (0.9991384880865023, 0.999569151227919, 0.9993537732595441, None)
#
# mean:  0.8822551855727211

# %% [markdown]
# #####Testing

# %%
test_string = [""""He started rubbing my shoulders, telling me I looked stressed. Then he went down in my shirt. 
                  He walked around the living room area and he came back. That is when he touched my breast.
                  Then he grabbed my waist of my pants and also grabbed my hair as I tried to leave. I made it to the door and left.
                  It happened so quickly. I was just trying to get out of the townhouse"""]

acc = execute(NB_pipeline_CountV, X_test = test_string)
acc = execute(NB_pipeline_TfidfV,  X_test = test_string)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Prediction for Touching /Groping is [1]
# Prediction for Catcalls/Whistles is [0]
# Prediction for Sexual Invites is [0]
# Prediction for Stalking is [0]
# Prediction for Others is [0]
# Prediction for Commenting is [0]
# Prediction for Rape / Sexual Assault is [0]
# Prediction for North East India Report is [0]
# Prediction for Indecent Exposure/Masturbation in public is [0]
# Prediction for Chain Snatching is [0]
# Prediction for Ogling/Facial Expressions/Staring is [0]
# Prediction for Taking pictures is [0]
# Prediction for Poor / No Street Lighting is [0]
# Prediction for Online Harassment is [0]
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Prediction for Touching /Groping is [1]
# Prediction for Catcalls/Whistles is [0]
# Prediction for Sexual Invites is [0]
# Prediction for Stalking is [0]
# Prediction for Others is [0]
# Prediction for Commenting is [0]
# Prediction for Rape / Sexual Assault is [0]
# Prediction for North East India Report is [0]
# Prediction for Indecent Exposure/Masturbation in public is [0]
# Prediction for Chain Snatching is [0]
# Prediction for Ogling/Facial Expressions/Staring is [0]
# Prediction for Taking pictures is [0]
# Prediction for Poor / No Street Lighting is [0]
# Prediction for Online Harassment is [0]

# %% [markdown]
# #####Hyperparameter Tuning
# alpha : Increase the probablities of all bigrams in your non-maximum likelihood equation (Since we are changing the counts from what they occurred in hopes to make it better) by 1 to make everything non-zero. That increase by 1 is called adding the pseudocount or as you know it as α. Now, α=1 may not always give the most accurate probablities and hence they could attain any finite non-negative integer. The way to know what α gives the most accurate responses is through iterating over all values of α on the training set unfortunately

# %%
#Hyperparameter Tuning CountVectorizer
alphas_out = []

for alpha in tqdm(np.arange(0,1,0.05)):
  NB_pipeline_CountV = Pipeline([('count', CountVectorizer(stop_words='english')),
                                 ('clf', OneVsRestClassifier(MultinomialNB(fit_prior=True, class_prior=None, alpha=alpha))),])
  acc = execute(NB_pipeline_CountV, verbose=False)
  alphas_out.append(acc)
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)

# %%
cycol = cycle('bgrcmk')
accuracies = []
plt.figure(figsize=(12,7))

for category in range(len(categories)):
  for alpha in alphas_out:
    accuracies.append(alpha[category])

  alpha_array = np.arange(0.0,1.0,0.05)
  plt.plot(alpha_array, accuracies, c=next(cycol))
  plt.xlabel('alpha')
  plt.ylabel('Accuracy')
  plt.title('TUNING ALPHA CountVectorizer')
  accuracies = []
  
plt.gca().legend(categories, loc='upper right')  
plt.grid()  
plt.show()

# %%
#Hyperparameter Tuning TfidfVectorizer
alphas_out = []

for alpha in tqdm(np.arange(0,1,0.05)):
  NB_pipeline_TfidfV = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')),
                                 ('clf', OneVsRestClassifier(MultinomialNB(fit_prior=True, class_prior=None, alpha=alpha))),])
  acc = execute(NB_pipeline_TfidfV, verbose=False)
  alphas_out.append(acc)
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:485: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)

# %%
cycol = cycle('bgrcmk')
accuracies = []
plt.figure(figsize=(12,7))

for category in range(len(categories)):
  for alpha in alphas_out:
    accuracies.append(alpha[category])

  alpha_array = np.arange(0.0,1.0,0.05)
  plt.plot(alpha_array, accuracies, c=next(cycol))
  plt.xlabel('alpha')
  plt.ylabel('Accuracy')
  plt.title('TUNING ALPHA TfidfVectorizer')
  accuracies = []

plt.gca().legend(categories, loc='upper right') 
plt.grid()  
plt.show()

# %% [markdown]
# So for 'tf-idf' alpha optimal (smoothing) = 0.3; for 'count' alpha is 1 (as expected). SVM could work better for tf-idf.

# %% [markdown]
# ####Support Vector Machine

# %%
SVM_pipeline = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                         ('tfidf', TfidfTransformer()),
                         ('clf', OneVsRestClassifier(LinearSVC()))])

acc = execute(SVM_pipeline, verbose=True)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.8593396653098145
# precision_recall_fscore_support_weighted (0.8566603480443372, 0.8593396653098145, 0.8536494587125382, None)
# Test accuracy for Catcalls/Whistles is 0.8299412030755314
# precision_recall_fscore_support_weighted (0.8197035704736576, 0.8299412030755314, 0.8118214367345652, None)
# Test accuracy for Sexual Invites is 0.9054726368159204
# precision_recall_fscore_support_weighted (0.8870760016606434, 0.9054726368159204, 0.8853861580346564, None)
# Test accuracy for Stalking is 0.9280868385345997
# precision_recall_fscore_support_weighted (0.9154630313488049, 0.9280868385345997, 0.9175483142616552, None)
# Test accuracy for Others is 0.8860244233378561
# precision_recall_fscore_support_weighted (0.8590918657153478, 0.8860244233378561, 0.8616267965434834, None)
# Test accuracy for Commenting is 0.7919493441881501
# precision_recall_fscore_support_weighted (0.7898503863905422, 0.7919493441881501, 0.7878419508506026, None)
# Test accuracy for Rape / Sexual Assault is 0.9592944369063772
# precision_recall_fscore_support_weighted (0.9536861311082837, 0.9592944369063772, 0.954639580145693, None)
# Test accuracy for North East India Report is 0.9968340117593849
# precision_recall_fscore_support_weighted (0.9968440397764365, 0.9968340117593849, 0.9956053050911865, None)
# Test accuracy for Indecent Exposure/Masturbation in public is 0.9479873360470376
# precision_recall_fscore_support_weighted (0.9392856933077907, 0.9479873360470376, 0.9371741993798494, None)
# Test accuracy for Chain Snatching is 0.9868837630031659
# precision_recall_fscore_support_weighted (0.9862776939589704, 0.9868837630031659, 0.9861715352735232, None)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.8208955223880597
# precision_recall_fscore_support_weighted (0.8027527062630321, 0.8208955223880597, 0.7960063391154959, None)
# Test accuracy for Taking pictures is 0.9565807327001357
# precision_recall_fscore_support_weighted (0.9546528242178525, 0.9565807327001357, 0.9506221973078208, None)
# Test accuracy for Poor / No Street Lighting is 0.9751243781094527
# precision_recall_fscore_support_weighted (0.9735755738288822, 0.9751243781094527, 0.9698724282256078, None)
# Test accuracy for Online Harassment is 1.0
# precision_recall_fscore_support_weighted (1.0, 1.0, 1.0, None)
#
# mean:  0.9174581637268204

# %% [markdown]
# #####Hyperparameter Tuning

# %%
#Hyperparameter Tuning SVM 1 (This cell takes to much to run)
#Save results name and score in a dictionary

from sklearn import svm

acc_dict = {}
kernels = ['linear', 'rbf', 'poly']
gammas = ['scale', 0.1, 1, 10, 100]
cs = [0.1, 1] #, 10, 100, 1000]
degrees = [0, 1, 2, 3, 4, 5, 6]

for c in cs:
  for kernel in tqdm(kernels):
    print('\nSVC with kernel = {}, gamma = auto, c = {}'.format(kernel, c))
    SVM_pipeline_kernel = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                                    ('tfidf', TfidfTransformer()),
                                    ('clf', OneVsRestClassifier(svm.SVC(kernel=kernel, gamma='auto', C=c)))])
    acc_k, m_k = execute_mean(SVM_pipeline_kernel, verbose=False)
    acc_dict.update({kernel+'_auto_'+str(c):m_k})

    if kernel != 'linear':
      for gamma in gammas: 
        if kernel == 'poly':
          for degree in degrees:
            print('\nSVC with kernel = {}, gamma = {}, c = {} and degree = {}'.format(kernel, gamma, c, degree))
            SVM_pipeline_kernel = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                                          ('tfidf', TfidfTransformer()),
                                          ('clf', OneVsRestClassifier(svm.SVC(kernel=kernel, gamma=gamma, C=c, degree=degree)))])
            acc_kgd, m_kgd = execute_mean(SVM_pipeline_kernel, verbose=False)
            acc_dict.update({kernel+'_'+str(gamma)+'_'+str(c)+'_'+str(degree):m_kgd})

        else:
          print('\nSVC with kernel = {}, c = {} and gamma = {}'.format(kernel, c, gamma))
          SVM_pipeline_kernel = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                                          ('tfidf', TfidfTransformer()),
                                          ('clf', OneVsRestClassifier(svm.SVC(kernel=kernel, C=c, gamma=gamma)))])
          acc_kg, m_kg = execute_mean(SVM_pipeline_kernel, verbose=False)
          acc_dict.update({kernel+'_'+str(gamma)+'_'+str(c):m_kg})

# %%
np.save('hyper_results_2.npy', acc_dict)

# %%
#Hyperparameter Tuning SVM 2 (This cell takes to much to run)

from sklearn import svm

kernels = ['linear', 'rbf', 'poly']
gammas = ['scale', 0.1, 1, 10, 100]
cs = [10, 100] #1000]
degrees = [0, 1, 2, 3, 4, 5, 6]

for c in cs:
  for kernel in tqdm(kernels):
    print('\nSVC with kernel = {}, gamma = auto, c = {}'.format(kernel, c))
    SVM_pipeline_kernel = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                                    ('tfidf', TfidfTransformer()),
                                    ('clf', OneVsRestClassifier(svm.SVC(kernel=kernel, gamma='auto', C=c)))])
    acc_k, m_k = execute_mean(SVM_pipeline_kernel, verbose=False)
    acc_dict.update({kernel+'_auto_'+str(c):m_k})

    if kernel != 'linear':
      for gamma in gammas: 
        if kernel == 'poly':
          for degree in degrees:
            print('\nSVC with kernel = {}, gamma = {}, c = {} and degree = {}'.format(kernel, gamma, c, degree))
            SVM_pipeline_kernel = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                                          ('tfidf', TfidfTransformer()),
                                          ('clf', OneVsRestClassifier(svm.SVC(kernel=kernel, gamma=gamma, C=c, degree=degree)))])
            acc_kgd, m_kgd = execute_mean(SVM_pipeline_kernel, verbose=False)
            acc_dict.update({kernel+'_'+str(gamma)+'_'+str(c)+'_'+str(degree):m_kgd})

        else:
          print('\nSVC with kernel = {}, c = {} and gamma = {}'.format(kernel, c, gamma))
          SVM_pipeline_kernel = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                                          ('tfidf', TfidfTransformer()),
                                          ('clf', OneVsRestClassifier(svm.SVC(kernel=kernel, C=c, gamma=gamma)))])
          acc_kg, m_kg = execute_mean(SVM_pipeline_kernel, verbose=False)
          acc_dict.update({kernel+'_'+str(gamma)+'_'+str(c):m_kg})

np.save('hyper_results_2.npy', acc_dict)

# %% [markdown]
# #####Choosing the best model

# %%
# Load
read_dictionary = np.load('hyper_results_2.npy', allow_pickle=True).item()
print(read_dictionary)

# %%
SVM_pipeline = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                         ('tfidf', TfidfTransformer()),
                         ('clf', OneVsRestClassifier(svm.SVC(kernel='linear', gamma='auto', C=1.0)))])

acc = execute(SVM_pipeline, verbose=True)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.8683853459972863
# precision_recall_fscore_support_weighted (0.8684271467151216, 0.8683853459972863, 0.8616125545209374, None)
# Test accuracy for Catcalls/Whistles is 0.8403437358661239
# precision_recall_fscore_support_weighted (0.8428692901583692, 0.8403437358661239, 0.8160778364089479, None)
# Test accuracy for Sexual Invites is 0.9054726368159204
# precision_recall_fscore_support_weighted (0.8929826717402044, 0.9054726368159204, 0.8759274231155673, None)
# Test accuracy for Stalking is 0.9357756671189507
# precision_recall_fscore_support_weighted (0.9270302368734259, 0.9357756671189507, 0.9237332189256853, None)
# Test accuracy for Others is 0.8959746720940751
# precision_recall_fscore_support_weighted (0.898105709696034, 0.8959746720940751, 0.8594374979294781, None)
# Test accuracy for Commenting is 0.8136589778380823
# precision_recall_fscore_support_weighted (0.8158081874009054, 0.8136589778380823, 0.807631176621091, None)
# Test accuracy for Rape / Sexual Assault is 0.9638172772501131
# precision_recall_fscore_support_weighted (0.9595873850559501, 0.9638172772501131, 0.9592193888213962, None)
# Test accuracy for North East India Report is 0.9963817277250113
# precision_recall_fscore_support_weighted (0.9950334749561793, 0.9963817277250113, 0.9952987063364459, None)
# Test accuracy for Indecent Exposure/Masturbation in public is 0.9502487562189055
# precision_recall_fscore_support_weighted (0.9454049131779539, 0.9502487562189055, 0.9378336583083718, None)
# Test accuracy for Chain Snatching is 0.9855269109000452
# precision_recall_fscore_support_weighted (0.9847583443241517, 0.9855269109000452, 0.9846890166125449, None)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.8326549072817729
# precision_recall_fscore_support_weighted (0.8263903516632959, 0.8326549072817729, 0.8022459578549891, None)
# Test accuracy for Taking pictures is 0.9565807327001357
# precision_recall_fscore_support_weighted (0.9549370421125277, 0.9565807327001357, 0.9504197496056385, None)
# Test accuracy for Poor / No Street Lighting is 0.9755766621438263
# precision_recall_fscore_support_weighted (0.9741114113878392, 0.9755766621438263, 0.9705709699692285, None)
# Test accuracy for Online Harassment is 1.0
# precision_recall_fscore_support_weighted (1.0, 1.0, 1.0, None)
#
# mean:  0.9228855721393036

# %%
#load models
#Use this function to load the pretrained model
clf = joblib.load('filename.joblib')

# %% [markdown]
# ####Logistic Regression

# %%
#Edit...
logit_pipeline = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')),
                          ('clf', OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=1)),])
acc_logit = execute(logit_pipeline, verbose=True)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.8611488014473089
# precision_recall_fscore_support_weighted (0.8646360721354098, 0.8611488014473089, 0.8514041284501833, None)
# Test accuracy for Catcalls/Whistles is 0.8344640434192673
# precision_recall_fscore_support_weighted (0.835283565692548, 0.8344640434192673, 0.8083733797370136, None)
# Test accuracy for Sexual Invites is 0.9072817729534147
# precision_recall_fscore_support_weighted (0.9007699463202034, 0.9072817729534147, 0.8772184411916784, None)
# Test accuracy for Stalking is 0.9194934418815016
# precision_recall_fscore_support_weighted (0.8970543821705647, 0.9194934418815016, 0.8993950987183286, None)
# Test accuracy for Others is 0.8900949796472184
# precision_recall_fscore_support_weighted (0.8798268569401684, 0.8900949796472184, 0.8492423848713796, None)
# Test accuracy for Commenting is 0.8086838534599728
# precision_recall_fscore_support_weighted (0.8123728564984402, 0.8086838534599728, 0.8013955468117723, None)
# Test accuracy for Rape / Sexual Assault is 0.9570330167345092
# precision_recall_fscore_support_weighted (0.9509511622907302, 0.9570330167345092, 0.9471465288449873, None)
# Test accuracy for North East India Report is 0.9963817277250113
# precision_recall_fscore_support_weighted (0.9927765473442786, 0.9963817277250113, 0.9945758704930674, None)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test accuracy for Indecent Exposure/Masturbation in public is 0.9412030755314338
# precision_recall_fscore_support_weighted (0.9307309764607938, 0.9412030755314338, 0.9199819659435003, None)
# Test accuracy for Chain Snatching is 0.9828132066938037
# precision_recall_fscore_support_weighted (0.981876422569708, 0.9828132066938037, 0.9811507195879123, None)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.8281320669380371
# precision_recall_fscore_support_weighted (0.8270337928845045, 0.8281320669380371, 0.790906921888323, None)
# Test accuracy for Taking pictures is 0.9502487562189055
# precision_recall_fscore_support_weighted (0.949328082976112, 0.9502487562189055, 0.9406492246643327, None)
# Test accuracy for Poor / No Street Lighting is 0.9696969696969697
# precision_recall_fscore_support_weighted (0.9687435286808862, 0.9696969696969697, 0.9597716031659181, None)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Test accuracy for Online Harassment is 1.0
# precision_recall_fscore_support_weighted (1.0, 1.0, 1.0, None)
#
# mean:  0.9176196937390966

# %% [markdown]
# So this model's performance is on averga no better than the SVM model. So we consider logistic regression for comparisson but doing hyperparameter tuning is not a priority.

# %% [markdown]
# ##Models Comparison

# %%
#Naive Bayes best model
NB_pipeline_CountV = Pipeline([('count', CountVectorizer(stop_words='english')), 
                        ('clf', OneVsRestClassifier(MultinomialNB())),])

acc_NB = execute(NB_pipeline_CountV, verbose=True)

#SVM base and after hyperparameter tuning
SVM_pipeline = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                         ('tfidf', TfidfTransformer()),
                         ('clf', OneVsRestClassifier(LinearSVC()))])

acc_SVM = execute(SVM_pipeline, verbose=True)

SVM_pipeline_hyper = Pipeline([('vectorizer', CountVectorizer(stop_words='english')),
                         ('tfidf', TfidfTransformer()),
                         ('clf', OneVsRestClassifier(svm.SVC(kernel='linear', gamma='auto', C=1.0)))])

acc_SVM_hyper = execute(SVM_pipeline_hyper, verbose=True)

#Logistic Regression
logit_pipeline = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')),
                          ('clf', OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=1)),])
acc_logit = execute(logit_pipeline, verbose=True)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.8611488014473089
# precision_recall_fscore_support_weighted (0.8589813317516827, 0.8611488014473089, 0.855136478107857, None)
# Test accuracy for Catcalls/Whistles is 0.8132066938037087
# precision_recall_fscore_support_weighted (0.7995591486149929, 0.8132066938037087, 0.8016860392788738, None)
# Test accuracy for Sexual Invites is 0.8941655359565808
# precision_recall_fscore_support_weighted (0.8645159629160971, 0.8941655359565808, 0.8690519930007954, None)
# Test accuracy for Stalking is 0.9199457259158752
# precision_recall_fscore_support_weighted (0.8983651218820121, 0.9199457259158752, 0.9006944884433291, None)
# Test accuracy for Others is 0.8891904115784712
# precision_recall_fscore_support_weighted (0.864232728825344, 0.8891904115784712, 0.8591009864459133, None)
# Test accuracy for Commenting is 0.7815468113975577
# precision_recall_fscore_support_weighted (0.7790976814997338, 0.7815468113975577, 0.7794759101031481, None)
# Test accuracy for Rape / Sexual Assault is 0.9493441881501583
# precision_recall_fscore_support_weighted (0.9381778361903392, 0.9493441881501583, 0.9407916951874039, None)
# Test accuracy for North East India Report is 0.9950248756218906
# precision_recall_fscore_support_weighted (0.9927716490013699, 0.9950248756218906, 0.9938969852618567, None)
# Test accuracy for Indecent Exposure/Masturbation in public is 0.942107643600181
# precision_recall_fscore_support_weighted (0.9304191158479042, 0.942107643600181, 0.9235722911280244, None)
# Test accuracy for Chain Snatching is 0.9787426503844414
# precision_recall_fscore_support_weighted (0.976823699079254, 0.9787426503844414, 0.9769465883427506, None)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.8227046585255541
# precision_recall_fscore_support_weighted (0.8050635319087249, 0.8227046585255541, 0.8000566168270118, None)
# Test accuracy for Taking pictures is 0.9434644957033017
# precision_recall_fscore_support_weighted (0.9381559271980473, 0.9434644957033017, 0.9323985357663979, None)
# Test accuracy for Poor / No Street Lighting is 0.9701492537313433
# precision_recall_fscore_support_weighted (0.9647363520545906, 0.9701492537313433, 0.9647364431700737, None)
# Test accuracy for Online Harassment is 0.9990954319312528
# precision_recall_fscore_support_weighted (1.0, 0.9990954319312528, 0.9995475113122173, None)
#
# mean:  0.9114169412676875
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.8593396653098145
# precision_recall_fscore_support_weighted (0.8566603480443372, 0.8593396653098145, 0.8536494587125382, None)
# Test accuracy for Catcalls/Whistles is 0.8299412030755314
# precision_recall_fscore_support_weighted (0.8197035704736576, 0.8299412030755314, 0.8118214367345652, None)
# Test accuracy for Sexual Invites is 0.9054726368159204
# precision_recall_fscore_support_weighted (0.8870760016606434, 0.9054726368159204, 0.8853861580346564, None)
# Test accuracy for Stalking is 0.9280868385345997
# precision_recall_fscore_support_weighted (0.9154630313488049, 0.9280868385345997, 0.9175483142616552, None)
# Test accuracy for Others is 0.8860244233378561
# precision_recall_fscore_support_weighted (0.8590918657153478, 0.8860244233378561, 0.8616267965434834, None)
# Test accuracy for Commenting is 0.7919493441881501
# precision_recall_fscore_support_weighted (0.7898503863905422, 0.7919493441881501, 0.7878419508506026, None)
# Test accuracy for Rape / Sexual Assault is 0.9592944369063772
# precision_recall_fscore_support_weighted (0.9536861311082837, 0.9592944369063772, 0.954639580145693, None)
# Test accuracy for North East India Report is 0.9968340117593849
# precision_recall_fscore_support_weighted (0.9968440397764365, 0.9968340117593849, 0.9956053050911865, None)
# Test accuracy for Indecent Exposure/Masturbation in public is 0.9479873360470376
# precision_recall_fscore_support_weighted (0.9392856933077907, 0.9479873360470376, 0.9371741993798494, None)
# Test accuracy for Chain Snatching is 0.9868837630031659
# precision_recall_fscore_support_weighted (0.9862776939589704, 0.9868837630031659, 0.9861715352735232, None)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.8208955223880597
# precision_recall_fscore_support_weighted (0.8027527062630321, 0.8208955223880597, 0.7960063391154959, None)
# Test accuracy for Taking pictures is 0.9565807327001357
# precision_recall_fscore_support_weighted (0.9546528242178525, 0.9565807327001357, 0.9506221973078208, None)
# Test accuracy for Poor / No Street Lighting is 0.9751243781094527
# precision_recall_fscore_support_weighted (0.9735755738288822, 0.9751243781094527, 0.9698724282256078, None)
# Test accuracy for Online Harassment is 1.0
# precision_recall_fscore_support_weighted (1.0, 1.0, 1.0, None)
#
# mean:  0.9174581637268204
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.8683853459972863
# precision_recall_fscore_support_weighted (0.8684271467151216, 0.8683853459972863, 0.8616125545209374, None)
# Test accuracy for Catcalls/Whistles is 0.8403437358661239
# precision_recall_fscore_support_weighted (0.8428692901583692, 0.8403437358661239, 0.8160778364089479, None)
# Test accuracy for Sexual Invites is 0.9054726368159204
# precision_recall_fscore_support_weighted (0.8929826717402044, 0.9054726368159204, 0.8759274231155673, None)
# Test accuracy for Stalking is 0.9357756671189507
# precision_recall_fscore_support_weighted (0.9270302368734259, 0.9357756671189507, 0.9237332189256853, None)
# Test accuracy for Others is 0.8959746720940751
# precision_recall_fscore_support_weighted (0.898105709696034, 0.8959746720940751, 0.8594374979294781, None)
# Test accuracy for Commenting is 0.8136589778380823
# precision_recall_fscore_support_weighted (0.8158081874009054, 0.8136589778380823, 0.807631176621091, None)
# Test accuracy for Rape / Sexual Assault is 0.9638172772501131
# precision_recall_fscore_support_weighted (0.9595873850559501, 0.9638172772501131, 0.9592193888213962, None)
# Test accuracy for North East India Report is 0.9963817277250113
# precision_recall_fscore_support_weighted (0.9950334749561793, 0.9963817277250113, 0.9952987063364459, None)
# Test accuracy for Indecent Exposure/Masturbation in public is 0.9502487562189055
# precision_recall_fscore_support_weighted (0.9454049131779539, 0.9502487562189055, 0.9378336583083718, None)
# Test accuracy for Chain Snatching is 0.9855269109000452
# precision_recall_fscore_support_weighted (0.9847583443241517, 0.9855269109000452, 0.9846890166125449, None)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.8326549072817729
# precision_recall_fscore_support_weighted (0.8263903516632959, 0.8326549072817729, 0.8022459578549891, None)
# Test accuracy for Taking pictures is 0.9565807327001357
# precision_recall_fscore_support_weighted (0.9549370421125277, 0.9565807327001357, 0.9504197496056385, None)
# Test accuracy for Poor / No Street Lighting is 0.9755766621438263
# precision_recall_fscore_support_weighted (0.9741114113878392, 0.9755766621438263, 0.9705709699692285, None)
# Test accuracy for Online Harassment is 1.0
# precision_recall_fscore_support_weighted (1.0, 1.0, 1.0, None)
#
# mean:  0.9228855721393036
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Test accuracy for Touching /Groping is 0.8611488014473089
# precision_recall_fscore_support_weighted (0.8646360721354098, 0.8611488014473089, 0.8514041284501833, None)
# Test accuracy for Catcalls/Whistles is 0.8344640434192673
# precision_recall_fscore_support_weighted (0.835283565692548, 0.8344640434192673, 0.8083733797370136, None)
# Test accuracy for Sexual Invites is 0.9072817729534147
# precision_recall_fscore_support_weighted (0.9007699463202034, 0.9072817729534147, 0.8772184411916784, None)
# Test accuracy for Stalking is 0.9194934418815016
# precision_recall_fscore_support_weighted (0.8970543821705647, 0.9194934418815016, 0.8993950987183286, None)
# Test accuracy for Others is 0.8900949796472184
# precision_recall_fscore_support_weighted (0.8798268569401684, 0.8900949796472184, 0.8492423848713796, None)
# Test accuracy for Commenting is 0.8086838534599728
# precision_recall_fscore_support_weighted (0.8123728564984402, 0.8086838534599728, 0.8013955468117723, None)
# Test accuracy for Rape / Sexual Assault is 0.9570330167345092
# precision_recall_fscore_support_weighted (0.9509511622907302, 0.9570330167345092, 0.9471465288449873, None)
# Test accuracy for North East India Report is 0.9963817277250113
# precision_recall_fscore_support_weighted (0.9927765473442786, 0.9963817277250113, 0.9945758704930674, None)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test accuracy for Indecent Exposure/Masturbation in public is 0.9412030755314338
# precision_recall_fscore_support_weighted (0.9307309764607938, 0.9412030755314338, 0.9199819659435003, None)
# Test accuracy for Chain Snatching is 0.9828132066938037
# precision_recall_fscore_support_weighted (0.981876422569708, 0.9828132066938037, 0.9811507195879123, None)
# Test accuracy for Ogling/Facial Expressions/Staring is 0.8281320669380371
# precision_recall_fscore_support_weighted (0.8270337928845045, 0.8281320669380371, 0.790906921888323, None)
# Test accuracy for Taking pictures is 0.9502487562189055
# precision_recall_fscore_support_weighted (0.949328082976112, 0.9502487562189055, 0.9406492246643327, None)
# Test accuracy for Poor / No Street Lighting is 0.9696969696969697
# precision_recall_fscore_support_weighted (0.9687435286808862, 0.9696969696969697, 0.9597716031659181, None)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Test accuracy for Online Harassment is 1.0
# precision_recall_fscore_support_weighted (1.0, 1.0, 1.0, None)
#
# mean:  0.9176196937390966

# %%
#Helper function for coloring negatives in pandas DataFrame

def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
df_acc_NB = pd.DataFrame.from_dict(dict(zip(categories.to_list(),acc_NB)), orient='index')
df_acc_SVM = pd.DataFrame.from_dict(dict(zip(categories.to_list(),acc_SVM)), orient='index')
df_acc_SVM_hyper = pd.DataFrame.from_dict(dict(zip(categories.to_list(),acc_SVM_hyper)), orient='index')
df_acc_LG = pd.DataFrame.from_dict(dict(zip(categories.to_list(),acc_logit)), orient='index')

compare = pd.concat([df_acc_NB, df_acc_SVM], axis=1)
compare = pd.concat([compare, df_acc_LG], axis=1)
compare = pd.concat([compare, df_acc_SVM_hyper], axis=1)
compare.columns = ['Acc NB', 'Acc SVM', 'Acc LG', 'Acc SVM_hyper']
compare['SVM advantage to NB'] = compare['Acc SVM'] - compare['Acc NB']
compare['SVM advantage to LG'] = compare['Acc SVM'] - compare['Acc LG']
compare['SVM_hyper advantage to SVM(1)'] = compare['Acc SVM_hyper'] - compare['Acc SVM']
compare['SVM_hyper advantage to LG(2)'] = compare['Acc SVM_hyper'] - compare['Acc LG']
compare['%(1)'] = (compare['SVM_hyper advantage to SVM(1)']*100).round(1)
compare['%(2)'] = (compare['SVM_hyper advantage to LG(2)']*100).round(1)
compare.to_csv('model_comparison.csv')
compare.style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col4 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col5 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col5 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col5 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col7 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row2_col9 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col4 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col5 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col5 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row6_col9 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col4 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col5 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col6 {
#             color:  red;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col7 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col8 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row7_col9 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row8_col0 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row8_col1 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row8_col2 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row8_col3 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row8_col4 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row8_col5 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row8_col6 {
#             color:  black;
#         }    #T_716ddbae_dc65_11e9_911a_0242ac1c0002row8_col7 {
#             color:  bl

# %% [markdown]
# ##N-grams

# %% [markdown]
# This part is not complete but is another improvement direction

# %%
#We can use sklearn.feature_selection.chi2 to find the terms that are the most correlated with each of the products:
#source: https://datascienceplus.com/multi-class-text-classification-with-scikit-learn/

from sklearn.feature_selection import chi2
import numpy as np
N = 2
for Product, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(Product))
  print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:]
